# %% [markdown]
# # Make Pareto Plots of forget loss vs maintain/side effect loss

# %%
# acdcpp_edge_paths = ["masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.9"]
# acdcpp_edge_paths_dict = {
#     "edges_localize=acdcpp_mask_k=10": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=10",
#     "edges_localize=acdcpp_mask_k=25": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=25",
#     "edges_localize=acdcpp_mask_k=50": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=50",
#     "edges_localize=acdcpp_mask_k=100": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=100",
#     "edges_localize=acdcpp_mask_k=200": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=200",
#     "edges_localize=acdcpp_threshold=0.1": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.1",
#     "edges_localize=acdcpp_threshold=0.2": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.2",
#     "edges_localize=acdcpp_threshold=0.5": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.5",
#     "edges_localize=acdcpp_threshold=0.75": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.75",
#     "edges_localize=acdcpp_threshold=0.9": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.9"
# }

# ct_edge_paths = ["masks/threshold_sweep_ioi/edge_masks/ct/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.9"]
# ct_edge_paths_dict = {
#     "edges_localize=ct_mask_k=10": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=10",
#     "edges_localize=ct_mask_k=25": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=25",
#     "edges_localize=ct_mask_k=50": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=50",
#     "edges_localize=ct_mask_k=100": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=100",
#     "edges_localize=ct_mask_k=200": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=200",
#     "edges_localize=ct_threshold=0.1": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.1",
#     "edges_localize=ct_threshold=0.2": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.2",
#     "edges_localize=ct_threshold=0.5": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.5",
#     "edges_localize=ct_threshold=0.75": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.75",
#     "edges_localize=ct_threshold=0.9": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.9"
# }

# none_edge_paths = [
#     "masks/threshold_sweep_ioi/edge_masks/none/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.9"
# ]
# none_edge_paths_dict = {
#     "edges_localize=none_mask_k=10": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=10",
#     "edges_localize=none_mask_k=25": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=25",
#     "edges_localize=none_mask_k=50": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=50",
#     "edges_localize=none_mask_k=100": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=100",
#     "edges_localize=none_mask_k=200": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=200",
#     "edges_localize=none_threshold=0.1": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.1",
#     "edges_localize=none_threshold=0.2": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.2",
#     "edges_localize=none_threshold=0.5": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.5",
#     "edges_localize=none_threshold=0.75": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.75",
#     "edges_localize=none_threshold=0.9": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.9"
# }

# acdcpp_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.9"]
# acdcpp_weight_paths_dict = {
#     "weights_localize=acdcpp_mask_k=5000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=5000",
#     "weights_localize=acdcpp_mask_k=10000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=10000",
#     "weights_localize=acdcpp_mask_k=20000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=20000",
#     "weights_localize=acdcpp_mask_k=50000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=50000",
#     "weights_localize=acdcpp_mask_k=100000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=100000",
#     "weights_localize=acdcpp_threshold=0.1": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.1",
#     "weights_localize=acdcpp_threshold=0.2": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.2",
#     "weights_localize=acdcpp_threshold=0.5": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.5",
#     "weights_localize=acdcpp_threshold=0.75": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.75",
#     "weights_localize=acdcpp_threshold=0.9": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.9"
# }

# ct_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/ct/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.9"]
# ct_weight_paths_dict = {
#     "weights_localize=ct_mask_k=5000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=5000",
#     "weights_localize=ct_mask_k=10000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=10000",
#     "weights_localize=ct_mask_k=20000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=20000",
#     "weights_localize=ct_mask_k=50000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=50000",
#     "weights_localize=ct_mask_k=100000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=100000",
#     "weights_localize=ct_threshold=0.1": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.1",
#     "weights_localize=ct_threshold=0.2": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.2",
#     "weights_localize=ct_threshold=0.5": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.5",
#     "weights_localize=ct_threshold=0.75": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.75",
#     "weights_localize=ct_threshold=0.9": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.9"
# }

# none_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/none/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.9"]
# none_weight_paths_dict = {
#     "weights_localize=none_mask_k=5000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=5000",
#     "weights_localize=none_mask_k=10000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=10000",
#     "weights_localize=none_mask_k=20000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=20000",
#     "weights_localize=none_mask_k=50000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=50000",
#     "weights_localize=none_mask_k=100000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=100000",
#     "weights_localize=none_threshold=0.1": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.1",
#     "weights_localize=none_threshold=0.2": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.2",
#     "weights_localize=none_threshold=0.5": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.5",
#     "weights_localize=none_threshold=0.75": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.75",
#     "weights_localize=none_threshold=0.9": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.9"
# }

# acdcpp_edge_paths_dict_reversed = {v: k for k, v in acdcpp_edge_paths_dict.items()}
# ct_edge_paths_dict_reversed = {v: k for k, v in ct_edge_paths_dict.items()}
# none_edge_paths_dict_reversed = {v: k for k, v in none_edge_paths_dict.items()}
# acdcpp_weight_paths_dict_reversed = {v: k for k, v in acdcpp_weight_paths_dict.items()}
# ct_weight_paths_dict_reversed = {v: k for k, v in ct_weight_paths_dict.items()}
# none_weight_paths_dict_reversed = {v: k for k, v in none_weight_paths_dict.items()}

# %%
acdcpp_edge_paths = ["masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.9"]
acdcpp_edge_paths_dict = {
    "e_acdcpp_k=10": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=10",
    "e_acdcpp_k=25": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=25",
    "e_acdcpp_k=50": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=50",
    "e_acdcpp_k=100": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=100",
    "e_acdcpp_k=200": "masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=200",
    "e_acdcpp_thr=0.1": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.1",
    "e_acdcpp_thr=0.2": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.2",
    "e_acdcpp_thr=0.5": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.5",
    "e_acdcpp_thr=0.75": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.75",
    "e_acdcpp_thr=0.9": "masks/threshold_sweep_ioi/edge_masks/acdcpp/threshold=0.9"
}

ct_edge_paths = ["masks/threshold_sweep_ioi/edge_masks/ct/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.9"]
ct_edge_paths_dict = {
    "e_ct_k=10": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=10",
    "e_ct_k=25": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=25",
    "e_ct_k=50": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=50",
    "e_ct_k=100": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=100",
    "e_ct_k=200": "masks/threshold_sweep_ioi/edge_masks/ct/mask_k=200",
    "e_ct_thr=0.1": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.1",
    "e_ct_thr=0.2": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.2",
    "e_ct_thr=0.5": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.5",
    "e_ct_thr=0.75": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.75",
    "e_ct_thr=0.9": "masks/threshold_sweep_ioi/edge_masks/ct/threshold=0.9"
}

none_edge_paths = [
    "masks/threshold_sweep_ioi/edge_masks/none/mask_k=10", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=25", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=50", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=100", "masks/threshold_sweep_ioi/edge_masks/none/mask_k=200", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.1", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.2", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.5", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.75", "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.9"
]
none_edge_paths_dict = {
    "e_none_k=10": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=10",
    "e_none_k=25": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=25",
    "e_none_k=50": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=50",
    "e_none_k=100": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=100",
    "e_none_k=200": "masks/threshold_sweep_ioi/edge_masks/none/mask_k=200",
    "e_none_thr=0.1": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.1",
    "e_none_thr=0.2": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.2",
    "e_none_thr=0.5": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.5",
    "e_none_thr=0.75": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.75",
    "e_none_thr=0.9": "masks/threshold_sweep_ioi/edge_masks/none/threshold=0.9"
}

acdcpp_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.9"]
acdcpp_weight_paths_dict = {
    "w_acdcpp_k=5000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=5000",
    "w_acdcpp_k=10000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=10000",
    "w_acdcpp_k=20000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=20000",
    "w_acdcpp_k=50000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=50000",
    "w_acdcpp_k=100000": "masks/threshold_sweep_ioi/weight_masks/acdcpp/mask_k=100000",
    "w_acdcpp_thr=0.1": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.1",
    "w_acdcpp_thr=0.2": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.2",
    "w_acdcpp_thr=0.5": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.5",
    "w_acdcpp_thr=0.75": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.75",
    "w_acdcpp_thr=0.9": "masks/threshold_sweep_ioi/weight_masks/acdcpp/threshold=0.9"
}

ct_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/ct/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.9"]
ct_weight_paths_dict = {
    "w_ct_k=5000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=5000",
    "w_ct_k=10000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=10000",
    "w_ct_k=20000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=20000",
    "w_ct_k=50000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=50000",
    "w_ct_k=100000": "masks/threshold_sweep_ioi/weight_masks/ct/mask_k=100000",
    "w_ct_thr=0.1": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.1",
    "w_ct_thr=0.2": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.2",
    "w_ct_thr=0.5": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.5",
    "w_ct_thr=0.75": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.75",
    "w_ct_thr=0.9": "masks/threshold_sweep_ioi/weight_masks/ct/threshold=0.9"
}

none_weight_paths = ["masks/threshold_sweep_ioi/weight_masks/none/mask_k=5000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=10000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=20000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=50000", "masks/threshold_sweep_ioi/weight_masks/none/mask_k=100000", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.1", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.2", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.5", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.75", "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.9"]
none_weight_paths_dict = {
    "w_none_k=5000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=5000",
    "w_none_k=10000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=10000",
    "w_none_k=20000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=20000",
    "w_none_k=50000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=50000",
    "w_none_k=100000": "masks/threshold_sweep_ioi/weight_masks/none/mask_k=100000",
    "w_none_thr=0.1": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.1",
    "w_none_thr=0.2": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.2",
    "w_none_thr=0.5": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.5",
    "w_none_thr=0.75": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.75",
    "w_none_thr=0.9": "masks/threshold_sweep_ioi/weight_masks/none/threshold=0.9"
}

acdcpp_edge_paths_dict_reversed = {v: k for k, v in acdcpp_edge_paths_dict.items()}
ct_edge_paths_dict_reversed = {v: k for k, v in ct_edge_paths_dict.items()}
none_edge_paths_dict_reversed = {v: k for k, v in none_edge_paths_dict.items()}
acdcpp_weight_paths_dict_reversed = {v: k for k, v in acdcpp_weight_paths_dict.items()}
ct_weight_paths_dict_reversed = {v: k for k, v in ct_weight_paths_dict.items()}
none_weight_paths_dict_reversed = {v: k for k, v in none_weight_paths_dict.items()}

# %%
import pickle
def get_losses(path):
    with open(f"{path}/ckpts/final_losses.pkl", "rb") as f:
        _, test_losses = pickle.load(f)
    test_losses_dict = {}
    for loss_type, loss_list in test_losses.items():
        try:
            test_losses_dict[loss_type] = loss_list[-1].item()
        except AttributeError:
            test_losses_dict[loss_type] = loss_list[-1]
    return test_losses_dict

get_losses(none_edge_paths[0])
# Out:
# {'ioi': 10.723661422729492,
#  'ioi_acc': 0.5875,
#  'ioi_logit_diff': -0.02429046668112278,
#  'induction': 2.8037641048431396,
#  'induction_acc': 0.9625,
#  'induction_logit_diff': 9.748269081115723,
#  'owt': 3.910714864730835,
#  'owt_acc': 0.0,
#  'owt_logit_diff': 0.0,
#  'ioi_2': 10.935879707336426,
#  'ioi_2_acc': 0.26875,
#  'ioi_2_logit_diff': -1.3786935806274414,
#  'ioi_3': 10.053925514221191,
#  'ioi_3_acc': 0.45625,
#  'ioi_3_logit_diff': -0.7945499420166016,
#  'greaterthan': 3.740792989730835,
#  'greaterthan_acc': 0.975,
#  'greaterthan_logit_diff': 2.19398832321167}

# %%
# make pareto plots
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import matplotlib.pyplot as plt
import pickle

# Assuming get_losses function is defined as in your snippet

def plot_pareto(x_axis_loss, y_axis_loss, x_range=None, y_range=None, include_text=False, plot_thresholds=True, plot_mask_ks=True, ):
    fig, ax = plt.subplots(figsize=(6, 6))  # Adjusted for better visibility of labels
    
    # Custom legend items
    custom_legend_items = [
        Line2D([0], [0], marker='^', color='w', label='Edge', markerfacecolor='k', markersize=10),
        Line2D([0], [0], marker='o', color='w', label='Weight', markerfacecolor='k', markersize=10),
        Line2D([0], [0], marker='s', color='w', label='Threshold', markerfacecolor='none', markeredgecolor='k', markersize=10),
        Line2D([0], [0], marker='s', color='w', label='Mask_k', markerfacecolor='k', markersize=10),
        Patch(facecolor='tab:blue', label='ACDCPP'),
        Patch(facecolor='tab:orange', label='CT'),
        Patch(facecolor='tab:green', label='None'),
    ]
    
    # Combine all paths for iteration
    all_paths = acdcpp_edge_paths + none_edge_paths + ct_edge_paths + acdcpp_weight_paths + none_weight_paths + ct_weight_paths
    all_dicts_reversed = {**acdcpp_edge_paths_dict_reversed, **ct_edge_paths_dict_reversed, **none_edge_paths_dict_reversed, **acdcpp_weight_paths_dict_reversed, **ct_weight_paths_dict_reversed, **none_weight_paths_dict_reversed}
    
    x_axis_losses = {}
    y_axis_losses = {}
    for path in all_paths:
        if 'acdcpp' in path:
            color = 'tab:blue'
        elif 'ct' in path:
            color = 'tab:orange'
        elif 'none' in path:
            color = 'tab:green'
        
        shape = '^' if 'edge' in path else 'o'  # square for edge models, circle for weight models
        fill_style = 'full' if "mask_k=" in path else 'none'
        losses = get_losses(path)
        label = all_dicts_reversed[path]

        if plot_thresholds and 'threshold=' in path:
            ax.scatter(losses[x_axis_loss], losses[y_axis_loss], color=color, marker=shape, facecolors=('none' if fill_style == 'none' else color))

            x_axis_losses[label] = losses[x_axis_loss]
            y_axis_losses[label] = losses[y_axis_loss]

            if include_text and (x_range is None or (losses[x_axis_loss] < x_range[1] and losses[x_axis_loss] > x_range[0])) and (y_range is None or (losses[y_axis_loss] < y_range[1] and losses[y_axis_loss] > y_range[0])):
                ax.text(losses[x_axis_loss], losses[y_axis_loss], ' ' + label, fontsize=7, ha='left', va='center', alpha=0.7)
        
        elif plot_mask_ks and "mask_k=" in path:
            ax.scatter(losses[x_axis_loss], losses[y_axis_loss], color=color, marker=shape, facecolors=('none' if fill_style == 'none' else color))

            x_axis_losses[label] = losses[x_axis_loss]
            y_axis_losses[label] = losses[y_axis_loss]

            if include_text and (x_range is None or (losses[x_axis_loss] < x_range[1] and losses[x_axis_loss] > x_range[0])) and (y_range is None or (losses[y_axis_loss] < y_range[1] and losses[y_axis_loss] > y_range[0])):
                ax.text(losses[x_axis_loss], losses[y_axis_loss], ' ' + label, fontsize=7, ha='left', va='center', alpha=0.7)
    
    # Adjusting x and y axis limits if ranges are provided
    if x_range is not None:
        ax.set_xlim(x_range)
    if y_range is not None:
        ax.set_ylim(y_range)
    
    # Setting labels, title
    ax.set_xlabel(x_axis_loss)
    ax.set_ylabel(y_axis_loss)
    ax.set_title(f'Pareto Plot of Models of {x_axis_loss} vs {y_axis_loss}')
    
    # Adding custom legend for color, shape, and fill style
    ax.legend(handles=custom_legend_items, loc='best', title="Legend")
    
    plt.show()
    return x_axis_losses, y_axis_losses

# %%
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="owt", y_range=[3.3, 5.2], include_text=False)
# Out:
# ({'e_acdcpp_k=10': 0.6875,
#   'e_acdcpp_k=25': 0.7125,
#   'e_acdcpp_k=50': 0.2625,
#   'e_acdcpp_k=100': 0.8125,
#   'e_acdcpp_k=200': 0.4625,
#   'e_acdcpp_thr=0.1': 0.5375,
#   'e_acdcpp_thr=0.2': 0.4375,
#   'e_acdcpp_thr=0.5': 0.7375,
#   'e_acdcpp_thr=0.75': 0.775,
#   'e_acdcpp_thr=0.9': 0.4625,
#   'e_none_k=10': 0.5875,
#   'e_none_k=25': 0.4,
#   'e_none_k=50': 0.2625,
#   'e_none_k=100': 0.325,
#   'e_none_k=200': 0.3375,
#   'e_none_thr=0.1': 0.7,
#   'e_none_thr=0.2': 0.3875,
#   'e_none_thr=0.5': 0.5375,
#   'e_none_thr=0.75': 0.525,
#   'e_none_thr=0.9': 0.4125,
#   'e_ct_k=10': 0.0,
#   'e_ct_k=25': 0.0,
#   'e_ct_k=50': 0.0,
#   'e_ct_k=100': 0.0125,
#   'e_ct_k=200': 0.0375,
#   'e_ct_thr=0.1': 0.0,
#   'e_ct_thr=0.2': 0.0,
#   'e_ct_thr=0.5': 0.0,
#   'e_ct_thr=0.75': 0.0,
#   'e_ct_thr=0.9': 0.0125,
#   'w_acdcpp_k=5000': 1.0,
#   'w_acdcpp_k=10000': 1.0,
#   'w_acdcpp_k=20000': 1.0,
#   'w_acdcpp_k=50000': 1.0,
#   'w_acdcpp_k=100000': 1.0,
# ...

# %%
plot_pareto(x_axis_loss = "ioi_logit_diff", y_axis_loss = "owt", plot_thresholds=False)
plot_pareto(x_axis_loss = "ioi_logit_diff", y_axis_loss = "owt", plot_mask_ks=False)
plot_pareto(x_axis_loss = "ioi_logit_diff", y_axis_loss = "owt")
# Out:
# ({'e_acdcpp_k=10': 0.318784236907959,
#   'e_acdcpp_k=25': 0.4491453170776367,
#   'e_acdcpp_k=50': -0.9127159118652344,
#   'e_acdcpp_k=100': 0.877297580242157,
#   'e_acdcpp_k=200': -0.6604413390159607,
#   'e_acdcpp_thr=0.1': -0.44925984740257263,
#   'e_acdcpp_thr=0.2': -0.12806501984596252,
#   'e_acdcpp_thr=0.5': 0.5152228474617004,
#   'e_acdcpp_thr=0.75': 0.5729684233665466,
#   'e_acdcpp_thr=0.9': -0.6107663512229919,
#   'e_none_k=10': -0.02429046668112278,
#   'e_none_k=25': -1.7080940008163452,
#   'e_none_k=50': -2.082536458969116,
#   'e_none_k=100': -2.273088216781616,
#   'e_none_k=200': -0.7381191849708557,
#   'e_none_thr=0.1': 0.15500736236572266,
#   'e_none_thr=0.2': -0.6637812256813049,
#   'e_none_thr=0.5': 0.06302380561828613,
#   'e_none_thr=0.75': -1.0569632053375244,
#   'e_none_thr=0.9': 0.3822769820690155,
#   'e_ct_k=10': -6.65505838394165,
#   'e_ct_k=25': -9.339333534240723,
#   'e_ct_k=50': -9.13809871673584,
#   'e_ct_k=100': -9.590556144714355,
# ...

# %%
plot_pareto(x_axis_loss="ioi", y_axis_loss="owt", x_range=[0, 15], y_range=[3.3, 5.2], plot_thresholds=False, include_text=True)
plot_pareto(x_axis_loss="ioi", y_axis_loss="owt", x_range=[0, 15], y_range=[3.3, 5.2], plot_mask_ks=False, include_text=True)
plot_pareto(x_axis_loss="ioi", y_axis_loss="owt", x_range=[0, 15], y_range=[3.3, 5.2])
# Out:
# ({'e_acdcpp_k=10': 5.0759758949279785,
#   'e_acdcpp_k=25': 4.672160625457764,
#   'e_acdcpp_k=50': 7.22006368637085,
#   'e_acdcpp_k=100': 3.168363332748413,
#   'e_acdcpp_k=200': 6.917697906494141,
#   'e_acdcpp_thr=0.1': 6.270052909851074,
#   'e_acdcpp_thr=0.2': 7.2142791748046875,
#   'e_acdcpp_thr=0.5': 4.156489372253418,
#   'e_acdcpp_thr=0.75': 3.067915439605713,
#   'e_acdcpp_thr=0.9': 6.8816237449646,
#   'e_none_k=10': 10.723661422729492,
#   'e_none_k=25': 10.626611709594727,
#   'e_none_k=50': 14.138816833496094,
#   'e_none_k=100': 10.107786178588867,
#   'e_none_k=200': 15.404955863952637,
#   'e_none_thr=0.1': 8.27932357788086,
#   'e_none_thr=0.2': 10.273629188537598,
#   'e_none_thr=0.5': 11.016276359558105,
#   'e_none_thr=0.75': 19.676185607910156,
#   'e_none_thr=0.9': 28.8245792388916,
#   'e_ct_k=10': 6.380495548248291,
#   'e_ct_k=25': 8.981364250183105,
#   'e_ct_k=50': 8.741881370544434,
#   'e_ct_k=100': 9.267546653747559,
# ...

# %%
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="owt", y_range=[3.3, 5.2], plot_thresholds=False)
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="owt", y_range=[3.3, 5.2], plot_mask_ks=False)
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="owt", y_range=[3.3, 5.2])
# Out:
# ({'e_acdcpp_k=10': 0.6875,
#   'e_acdcpp_k=25': 0.7125,
#   'e_acdcpp_k=50': 0.2625,
#   'e_acdcpp_k=100': 0.8125,
#   'e_acdcpp_k=200': 0.4625,
#   'e_acdcpp_thr=0.1': 0.5375,
#   'e_acdcpp_thr=0.2': 0.4375,
#   'e_acdcpp_thr=0.5': 0.7375,
#   'e_acdcpp_thr=0.75': 0.775,
#   'e_acdcpp_thr=0.9': 0.4625,
#   'e_none_k=10': 0.5875,
#   'e_none_k=25': 0.4,
#   'e_none_k=50': 0.2625,
#   'e_none_k=100': 0.325,
#   'e_none_k=200': 0.3375,
#   'e_none_thr=0.1': 0.7,
#   'e_none_thr=0.2': 0.3875,
#   'e_none_thr=0.5': 0.5375,
#   'e_none_thr=0.75': 0.525,
#   'e_none_thr=0.9': 0.4125,
#   'e_ct_k=10': 0.0,
#   'e_ct_k=25': 0.0,
#   'e_ct_k=50': 0.0,
#   'e_ct_k=100': 0.0125,
#   'e_ct_k=200': 0.0375,
#   'e_ct_thr=0.1': 0.0,
#   'e_ct_thr=0.2': 0.0,
#   'e_ct_thr=0.5': 0.0,
#   'e_ct_thr=0.75': 0.0,
#   'e_ct_thr=0.9': 0.0125,
#   'w_acdcpp_k=5000': 1.0,
#   'w_acdcpp_k=10000': 1.0,
#   'w_acdcpp_k=20000': 1.0,
#   'w_acdcpp_k=50000': 1.0,
#   'w_acdcpp_k=100000': 1.0,
# ...

# %%
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="greaterthan_acc", plot_thresholds=False, include_text=True)
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="greaterthan_acc", plot_mask_ks=False, include_text=True)
plot_pareto(x_axis_loss="ioi_acc", y_axis_loss="greaterthan_acc")
# Out:
# ({'e_acdcpp_k=10': 0.6875,
#   'e_acdcpp_k=25': 0.7125,
#   'e_acdcpp_k=50': 0.2625,
#   'e_acdcpp_k=100': 0.8125,
#   'e_acdcpp_k=200': 0.4625,
#   'e_acdcpp_thr=0.1': 0.5375,
#   'e_acdcpp_thr=0.2': 0.4375,
#   'e_acdcpp_thr=0.5': 0.7375,
#   'e_acdcpp_thr=0.75': 0.775,
#   'e_acdcpp_thr=0.9': 0.4625,
#   'e_none_k=10': 0.5875,
#   'e_none_k=25': 0.4,
#   'e_none_k=50': 0.2625,
#   'e_none_k=100': 0.325,
#   'e_none_k=200': 0.3375,
#   'e_none_thr=0.1': 0.7,
#   'e_none_thr=0.2': 0.3875,
#   'e_none_thr=0.5': 0.5375,
#   'e_none_thr=0.75': 0.525,
#   'e_none_thr=0.9': 0.4125,
#   'e_ct_k=10': 0.0,
#   'e_ct_k=25': 0.0,
#   'e_ct_k=50': 0.0,
#   'e_ct_k=100': 0.0125,
#   'e_ct_k=200': 0.0375,
#   'e_ct_thr=0.1': 0.0,
#   'e_ct_thr=0.2': 0.0,
#   'e_ct_thr=0.5': 0.0,
#   'e_ct_thr=0.75': 0.0,
#   'e_ct_thr=0.9': 0.0125,
#   'w_acdcpp_k=5000': 1.0,
#   'w_acdcpp_k=10000': 1.0,
#   'w_acdcpp_k=20000': 1.0,
#   'w_acdcpp_k=50000': 1.0,
#   'w_acdcpp_k=100000': 1.0,
# ...

# %%
with open("masks/threshold_sweep_ioi/edge_masks/acdcpp/mask_k=10/ckpts/final_losses.pkl", "rb") as f:
    losses = pickle.load(f)
losses[0]['edge_mask_reg']
# len(losses[1]['greaterthan_logit_diff'])
# Out:
# []
