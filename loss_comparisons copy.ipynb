# %% [markdown]
# ## Compare different losses and test tasks

# %%
# %load_ext autoreload
# %autoreload 2
from transformer_lens import HookedTransformer, ActivationCache
import torch
import numpy as np
import pandas as pd
import datasets
import transformers
import pickle

from tasks import OWTTask, InductionTask, GreaterThanTask
from tasks.ioi.IOITask import IOITask, IOITask_NPO, IOITask_Uniform
from tasks.induction.InductionTask import InductionTask, InductionTask_NPO, InductionTask_Uniform
from tqdm.auto import tqdm

# %%
from transformers import GPT2Tokenizer, GPTNeoXTokenizerFast, AutoModelForCausalLM
reference_gpt2 = AutoModelForCausalLM.from_pretrained("gpt2").cuda()
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token_id = tokenizer.eos_token_id

# %% [markdown]
# ## Train with different losses

# %%
# compare Gradient Ascent (-IOITask[CE] + OWT), HarmBench Loss (IOITask[1MP] + OWT), NPO Loss (IOITask_NPO), NPO+SFT Loss (IOITask_NPO + OWT), Uniform_all Loss (IOITask_Uniform[all_tokens] + OWT), Uniform_exclude Loss (IOITask_Uniform[exclude_correct] + OWT)

batch_size = 80
device = "cuda"
train_loss_type = "induction"

if train_loss_type == "ioi":
    ioi_ce = IOITask(batch_size=batch_size, tokenizer=tokenizer, device=device, prep_acdcpp=False, nb_templates=4, prompt_type="ABBA", criterion="cross_entropy")
    ioi_1mp = IOITask(batch_size=batch_size, tokenizer=tokenizer, device=device, prep_acdcpp=False, nb_templates=4, prompt_type="ABBA", criterion="log_1_minus_p")
    ioi_npo = IOITask_NPO(batch_size=batch_size, tokenizer=tokenizer, device=device, prep_acdcpp=False, nb_templates=4, prompt_type="ABBA", ref_model=reference_gpt2, beta=1)
    ioi_uniform = IOITask_Uniform(batch_size=batch_size, tokenizer=tokenizer, device=device, uniform_over="all_tokens", nb_templates=4, prompt_type="ABBA", exclude_correct=False)
    ioi_uniform_exclude = IOITask_Uniform(batch_size=batch_size, tokenizer=tokenizer, device=device, uniform_over="all_tokens", nb_templates=4, prompt_type="ABBA", exclude_correct=True)
    ioi_uniform_specific = IOITask_Uniform(batch_size=batch_size, tokenizer=tokenizer, device=device, uniform_over="IO_S", nb_templates=4, prompt_type="ABBA", exclude_correct=False)

elif train_loss_type == "induction":
    induction_ce = InductionTask(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, criterion="cross_entropy")
    induction_1mp = InductionTask(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, criterion="log_1_minus_p")
    induction_npo = InductionTask_NPO(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, criterion="npo", ref_model=reference_gpt2, beta=1)
    induction_uniform = InductionTask_Uniform(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, uniform_over="all_tokens", exclude_correct=False)
    induction_uniform_exclude = InductionTask_Uniform(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, uniform_over="all_tokens", exclude_correct=True)
    induction_uniform_specific = InductionTask_Uniform(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, uniform_over="rep_tokens", exclude_correct=False)
    induction_uniform_specific_exclude = InductionTask_Uniform(batch_size=batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device, uniform_over="rep_tokens", exclude_correct=True)

owt = OWTTask(batch_size=batch_size, tokenizer=tokenizer, device=device, ctx_length=100)

eval_batch_size=160
greaterthan_eval = GreaterThanTask(batch_size=eval_batch_size, tokenizer=tokenizer, device=device)
ioi_eval = IOITask(batch_size=eval_batch_size, tokenizer=tokenizer, device=device, prep_acdcpp=False, nb_templates=4, prompt_type="ABBA")
induction_eval = InductionTask(batch_size=eval_batch_size, tokenizer=tokenizer, prep_acdcpp=False, seq_len=15, device=device)
eval_tasks = {"ioi": ioi_eval, "induction": induction_eval, "owt": owt, "greaterthan": greaterthan_eval}
# Out:
# /data/phillip_guo/miniconda3/envs/unlrn/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %% [markdown]
# ## Test ioi_1mp

# %%
test_model = AutoModelForCausalLM.from_pretrained("gpt2").cuda()
if train_loss_type == "ioi":
    print(ioi_eval.get_test_loss(test_model))
    print(ioi_1mp.get_test_loss(test_model))
    print(ioi_npo.get_test_loss(test_model))

# %%
from cb_utils.learn_mask import evaluate_model
def train_loop(model, optimizer, num_epochs, train_tasks, train_task_weights, eval_tasks, eval_every=1, num_steps_per_epoch=100, eval_iters=4):
    train_losses = []
    test_losses = []
    for epoch in tqdm(range(num_epochs)):
        for step in range(num_steps_per_epoch):
            optimizer.zero_grad()
            train_loss = {}
            for task_name in train_tasks:
                task = train_tasks[task_name]
                task_weight = train_task_weights[task_name]
                loss = task.get_train_loss(model)
                train_loss[task_name] = loss.item()
                loss = loss * task_weight
                loss.backward()
            optimizer.step()
            train_losses.append(train_loss)

        if epoch % eval_every == 0:
            test_loss = evaluate_model(model, eval_tasks, num_eval_steps=eval_iters)
            test_losses.append(test_loss)
    return train_losses, test_losses
# Out:
# Using device: cuda:0

# %%
num_epochs = 50
steps_per_epoch = 10
lr = 1e-4
wd = 0
if train_loss_type == "ioi":
    loss_types = {
        "Cross Entropy": ({'ioi': ioi_ce, 'owt': owt}, {'ioi': -.2, 'owt': 1}), 
        "Log 1 Minus P": ({'ioi_1mp': ioi_1mp, 'owt': owt}, {'ioi_1mp': .2, 'owt': 1}), 
        "NPO": ({'ioi_npo': ioi_npo}, {'ioi_npo': .2}), 
        "NPO SFT": ({'ioi_npo': ioi_npo, 'owt': owt}, {'ioi_npo': .2, 'owt': 1}), 
        "Uniform Over All": ({'ioi_uniform': ioi_uniform, 'owt': owt}, {'ioi_uniform': .2, 'owt': 1}), 
        "Uniform Excluding Correct": ({'ioi_uniform_exclude': ioi_uniform_exclude, 'owt': owt}, {'ioi_uniform_exclude': .2, 'owt': 1}), 
        "Uniform Over Specific": ({'ioi_uniform_specific': ioi_uniform_specific, 'owt': owt}, {'ioi_uniform_specific': .2, 'owt': 1}),
    }
elif train_loss_type == "induction":
    loss_types = {
        "Cross Entropy": ({'induction_ce': induction_ce, 'owt': owt}, {'induction_ce': -.2, 'owt': 1}), 
        "Log 1 Minus P": ({'induction_1mp': induction_1mp, 'owt': owt}, {'induction_1mp': .2, 'owt': 1}), 
        "NPO": ({'induction_npo': induction_npo}, {'induction_npo': .2}), 
        "NPO SFT": ({'induction_npo': induction_npo, 'owt': owt}, {'induction_npo': .2, 'owt': 1}), 
        "Uniform Over All": ({'induction_uniform': induction_uniform, 'owt': owt}, {'induction_uniform': .2, 'owt': 1}), 
        "Uniform Excluding Correct": ({'induction_uniform_exclude': induction_uniform_exclude, 'owt': owt}, {'induction_uniform_exclude': .2, 'owt': 1}), 
        "Uniform Over Specific": ({'induction_uniform_specific': induction_uniform_specific, 'owt': owt}, {'induction_uniform_specific': .2, 'owt': 1}),
        "Uniform Over Specific Excluding Correct": ({'induction_uniform_specific_exclude': induction_uniform_specific_exclude, 'owt': owt}, {'induction_uniform_specific_exclude': .2, 'owt': 1}),
    }

all_train_losses = {}
all_test_losses = {}
for loss_name in tqdm(loss_types):
    train_tasks, task_weights = loss_types[loss_name]
    model = AutoModelForCausalLM.from_pretrained("gpt2")
    model.cuda()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
    train_losses, test_losses = train_loop(model, optimizer, num_epochs, train_tasks, task_weights, eval_tasks, num_steps_per_epoch=steps_per_epoch)
    all_train_losses[loss_name] = train_losses
    all_test_losses[loss_name] = test_losses
    model.cpu()

with open(f"results/{train_loss_type}_{lr=}_loss_type_sweep_losses.pkl", "wb") as f:
    pickle.dump((all_train_losses, all_test_losses), f)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ## Analyze Losses

# %%
# import pickle
# with open(f"results/ioi_loss_type_sweep_losses.pkl", "rb") as f:
#     all_train_losses, all_test_losses = pickle.load(f)

# with open("results/ioi_npo_loss_type_sweep_losses.pkl", "rb") as f:
#     all_train_losses_npo, all_test_losses_npo = pickle.load(f)

# # update all_train_losses with items from all_train_losses_npo, all_test_losses with items from all_test_losses_npo
# for loss_name in all_train_losses_npo:
#     all_train_losses[loss_name] = all_train_losses_npo[loss_name]
#     all_test_losses[loss_name] = all_test_losses_npo[loss_name]

# with open("results/ioi_lr=0.001_loss_type_sweep_losses.pkl", "wb") as f:
#     pickle.dump((all_train_losses, all_test_losses), f)

# %%
import pickle
lr=1e-4
with open(f"results/{train_loss_type}_{lr=}_loss_type_sweep_losses.pkl", "rb") as f:
    all_train_losses, all_test_losses = pickle.load(f)

# %%
lr
# Out:
# 0.0001

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for loss_name in all_train_losses:
    loss_types = all_train_losses[loss_name][0].keys()
    for loss_type in loss_types:
        if "owt" in loss_type:
            plt.plot([x[loss_type] for x in all_train_losses[loss_name]], label=f"{loss_name} - {loss_type}")
plt.ylim(2, 5)
plt.title(f"Train OWT Losses with Learning Rate {lr}")
plt.xlabel("Step")
plt.ylabel("OWT Cross Entropy Loss")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for loss_name in all_test_losses:
    # loss_types = ['ioi', 'induction', 'owt', 'greaterthan']
    loss_types = ['ioi_acc']
    for loss_type in loss_types:
        losses = []
        for x in all_test_losses[loss_name]:
            try:
                losses.append(x[loss_type].item())
            except:
                losses.append(x[loss_type])
        plt.plot(losses, label=f"{loss_name}-{loss_type}")
plt.legend()

plt.title("IOI Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# only plot y range from 0 to 3
plt.ylim(-.1, 1.1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for loss_name in all_test_losses:
    # loss_types = ['ioi', 'induction', 'owt', 'greaterthan']
    loss_types = ['induction_acc']
    for loss_type in loss_types:
        losses = []
        for x in all_test_losses[loss_name]:
            try:
                losses.append(x[loss_type].item())
            except:
                losses.append(x[loss_type])
        plt.plot(losses, label=f"{loss_name}-{loss_type}")
plt.legend()

plt.title("Induction Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# only plot y range from 0 to 3
plt.ylim(-.1, 1.1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for loss_name in all_test_losses:
    # loss_types = ['ioi', 'induction', 'owt', 'greaterthan']
    loss_types = ['greaterthan_acc']
    for loss_type in loss_types:
        losses = []
        for x in all_test_losses[loss_name]:
            try:
                losses.append(x[loss_type].item())
            except:
                losses.append(x[loss_type])
        plt.plot(losses, label=f"{loss_name}-{loss_type}")
plt.legend()

plt.title("Greater Than Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# only plot y range from 0 to 3
plt.ylim(-.1, 1.1)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
for loss_name in all_test_losses:
    # loss_types = ['ioi', 'induction', 'owt', 'greaterthan']
    loss_types = ['induction']
    for loss_type in loss_types:
        losses = []
        for x in all_test_losses[loss_name]:
            try:
                losses.append(x[loss_type].item())
            except:
                losses.append(x[loss_type])
        plt.plot(losses, label=f"{loss_name}-{loss_type}")
plt.legend()

plt.title("Induction Cross Entropy")
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy")
# only plot y range from 0 to 3
plt.ylim(0, 400)

plt.show()

# %%
all_test_losses
# Out:
# {'Cross Entropy': [defaultdict(float,
#               {'ioi': tensor(3.0114, device='cuda:0'),
#                'ioi_acc': 0.928125,
#                'ioi_logit_diff': tensor(2.0898, device='cuda:0'),
#                'induction': tensor(67.2492, device='cuda:0'),
#                'induction_acc': 0.0703125,
#                'induction_logit_diff': tensor(-0.2365),
#                'owt': tensor(3.3258, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1855, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4275)}),
#   defaultdict(float,
#               {'ioi': tensor(2.1852, device='cuda:0'),
#                'ioi_acc': 0.8875000000000001,
#                'ioi_logit_diff': tensor(1.7681, device='cuda:0'),
#                'induction': tensor(80.6829, device='cuda:0'),
#                'induction_acc': 0.08906250000000002,
#                'induction_logit_diff': tensor(-0.3443),
#                'owt': tensor(3.2938, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2384, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2907)}),
#   defaultdict(float,
#               {'ioi': tensor(1.6167, device='cuda:0'),
#                'ioi_acc': 0.95,
#                'ioi_logit_diff': tensor(2.0382, device='cuda:0'),
#                'induction': tensor(86.1301, device='cuda:0'),
#                'induction_acc': 0.0703125,
#                'induction_logit_diff': tensor(-0.0283),
#                'owt': tensor(3.2768, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2712, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1878)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4565, device='cuda:0'),
#                'ioi_acc': 0.9484375,
#                'ioi_logit_diff': tensor(2.5238, device='cuda:0'),
#                'induction': tensor(90.5822, device='cuda:0'),
#                'induction_acc': 0.0703125,
#                'induction_logit_diff': tensor(-0.1407),
#                'owt': tensor(3.1732, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2921, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3982)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3192, device='cuda:0'),
#                'ioi_acc': 0.9734375,
#                'ioi_logit_diff': tensor(2.6129, device='cuda:0'),
#                'induction': tensor(93.1676, device='cuda:0'),
#                'induction_acc': 0.0765625,
#                'induction_logit_diff': tensor(-2.1517),
#                'owt': tensor(3.1659, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2864, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.5776)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5132, device='cuda:0'),
#                'ioi_acc': 0.9515625000000001,
#                'ioi_logit_diff': tensor(2.8093, device='cuda:0'),
#                'induction': tensor(95.8416, device='cuda:0'),
#                'induction_acc': 0.03125,
#                'induction_logit_diff': tensor(-3.3388),
#                'owt': tensor(3.1388, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2444, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.7575)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4580, device='cuda:0'),
#                'ioi_acc': 0.9578125000000001,
#                'ioi_logit_diff': tensor(2.7841, device='cuda:0'),
#                'induction': tensor(98.5048, device='cuda:0'),
#                'induction_acc': 0.0078125,
#                'induction_logit_diff': tensor(-6.3450),
#                'owt': tensor(3.1474, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1677, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.8155)}),
#   defaultdict(float,
#               {'ioi': tensor(1.6413, device='cuda:0'),
#                'ioi_acc': 0.9593750000000001,
#                'ioi_logit_diff': tensor(2.4780, device='cuda:0'),
#                'induction': tensor(102.9504, device='cuda:0'),
#                'induction_acc': 0.021875,
#                'induction_logit_diff': tensor(-11.3100),
#                'owt': tensor(3.0991, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0858, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.5693)}),
#   defaultdict(float,
#               {'ioi': tensor(1.6234, device='cuda:0'),
#                'ioi_acc': 0.9546875,
#                'ioi_logit_diff': tensor(2.3310, device='cuda:0'),
#                'induction': tensor(105.3851, device='cuda:0'),
#                'induction_acc': 0.01875,
#                'induction_logit_diff': tensor(-12.7667),
#                'owt': tensor(3.1056, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0568, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.5305)}),
#   defaultdict(float,
#               {'ioi': tensor(1.7134, device='cuda:0'),
#                'ioi_acc': 0.9296875,
#                'ioi_logit_diff': tensor(2.3458, device='cuda:0'),
#                'induction': tensor(108.6029, device='cuda:0'),
#                'induction_acc': 0.009375000000000001,
#                'induction_logit_diff': tensor(-15.8041),
#                'owt': tensor(3.1201, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0769, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.5618)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5802, device='cuda:0'),
#                'ioi_acc': 0.9359374999999999,
#                'ioi_logit_diff': tensor(2.1726, device='cuda:0'),
#                'induction': tensor(110.8690, device='cuda:0'),
#                'induction_acc': 0.010937500000000001,
#                'induction_logit_diff': tensor(-18.1507),
#                'owt': tensor(3.0969, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0730, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4302)}),
#   defaultdict(float,
#               {'ioi': tensor(1.6674, device='cuda:0'),
#                'ioi_acc': 0.9421875000000001,
#                'ioi_logit_diff': tensor(2.3559, device='cuda:0'),
#                'induction': tensor(111.7634, device='cuda:0'),
#                'induction_acc': 0.0078125,
#                'induction_logit_diff': tensor(-19.1167),
#                'owt': tensor(3.1307, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1281, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2037)}),
#   defaultdict(float,
#               {'ioi': tensor(1.7119, device='cuda:0'),
#                'ioi_acc': 0.9421875000000001,
#                'ioi_logit_diff': tensor(2.3022, device='cuda:0'),
#                'induction': tensor(113.3958, device='cuda:0'),
#                'induction_acc': 0.014062500000000002,
#                'induction_logit_diff': tensor(-19.1742),
#                'owt': tensor(3.1172, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1355, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1446)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4834, device='cuda:0'),
#                'ioi_acc': 0.9671875,
#                'ioi_logit_diff': tensor(2.3766, device='cuda:0'),
#                'induction': tensor(116.4856, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-20.8060),
#                'owt': tensor(3.1303, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1869, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2363)}),
#   defaultdict(float,
#               {'ioi': tensor(1.6229, device='cuda:0'),
#                'ioi_acc': 0.959375,
#                'ioi_logit_diff': tensor(2.6341, device='cuda:0'),
#                'induction': tensor(117.4959, device='cuda:0'),
#                'induction_acc': 0.0109375,
#                'induction_logit_diff': tensor(-21.2235),
#                'owt': tensor(3.1145, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2061, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1517)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5611, device='cuda:0'),
#                'ioi_acc': 0.9421875000000001,
#                'ioi_logit_diff': tensor(2.5548, device='cuda:0'),
#                'induction': tensor(119.2837, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-21.9682),
#                'owt': tensor(3.1587, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2179, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4080)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5888, device='cuda:0'),
#                'ioi_acc': 0.9406249999999999,
#                'ioi_logit_diff': tensor(2.2424, device='cuda:0'),
#                'induction': tensor(121.4618, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-22.6655),
#                'owt': tensor(3.1603, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2154, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2541)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4543, device='cuda:0'),
#                'ioi_acc': 0.9609375,
#                'ioi_logit_diff': tensor(2.5210, device='cuda:0'),
#                'induction': tensor(122.7103, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-22.6667),
#                'owt': tensor(3.0905, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2315, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2128)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4569, device='cuda:0'),
#                'ioi_acc': 0.9515625000000001,
#                'ioi_logit_diff': tensor(2.6600, device='cuda:0'),
#                'induction': tensor(123.9222, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-23.9178),
#                'owt': tensor(3.0886, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2504, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2198)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4290, device='cuda:0'),
#                'ioi_acc': 0.9671875,
#                'ioi_logit_diff': tensor(2.7992, device='cuda:0'),
#                'induction': tensor(125.9637, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-24.3907),
#                'owt': tensor(3.0957, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2750, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2023)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4171, device='cuda:0'),
#                'ioi_acc': 0.9671875,
#                'ioi_logit_diff': tensor(2.8326, device='cuda:0'),
#                'induction': tensor(127.0603, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-24.7180),
#                'owt': tensor(3.1092, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2600, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2217)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5200, device='cuda:0'),
#                'ioi_acc': 0.96875,
#                'ioi_logit_diff': tensor(2.9318, device='cuda:0'),
#                'induction': tensor(128.5698, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-25.2880),
#                'owt': tensor(3.1341, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2551, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2457)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5054, device='cuda:0'),
#                'ioi_acc': 0.9609375,
#                'ioi_logit_diff': tensor(2.9363, device='cuda:0'),
#                'induction': tensor(130.5020, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-24.9245),
#                'owt': tensor(3.1750, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2757, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2187)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4063, device='cuda:0'),
#                'ioi_acc': 0.9593750000000001,
#                'ioi_logit_diff': tensor(2.8606, device='cuda:0'),
#                'induction': tensor(131.3505, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-25.6565),
#                'owt': tensor(3.1181, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2711, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1980)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3782, device='cuda:0'),
#                'ioi_acc': 0.9859374999999999,
#                'ioi_logit_diff': tensor(2.8111, device='cuda:0'),
#                'induction': tensor(133.3498, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-26.1907),
#                'owt': tensor(3.0833, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2552, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1805)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4358, device='cuda:0'),
#                'ioi_acc': 0.975,
#                'ioi_logit_diff': tensor(2.9908, device='cuda:0'),
#                'induction': tensor(134.6645, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-26.8297),
#                'owt': tensor(3.1560, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2315, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1464)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3016, device='cuda:0'),
#                'ioi_acc': 0.9703124999999999,
#                'ioi_logit_diff': tensor(3.0408, device='cuda:0'),
#                'induction': tensor(135.7458, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-26.1316),
#                'owt': tensor(3.1232, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2457, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1022)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3432, device='cuda:0'),
#                'ioi_acc': 0.984375,
#                'ioi_logit_diff': tensor(2.9916, device='cuda:0'),
#                'induction': tensor(137.7704, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-25.4535),
#                'owt': tensor(3.0863, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2740, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1460)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4291, device='cuda:0'),
#                'ioi_acc': 0.9703125,
#                'ioi_logit_diff': tensor(3.1117, device='cuda:0'),
#                'induction': tensor(139.3035, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-25.9873),
#                'owt': tensor(3.1619, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3094, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2273)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4001, device='cuda:0'),
#                'ioi_acc': 0.975,
#                'ioi_logit_diff': tensor(3.1398, device='cuda:0'),
#                'induction': tensor(140.9004, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-26.2961),
#                'owt': tensor(3.1463, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3135, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1864)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2447, device='cuda:0'),
#                'ioi_acc': 0.9796875,
#                'ioi_logit_diff': tensor(3.3017, device='cuda:0'),
#                'induction': tensor(142.8183, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-25.8443),
#                'owt': tensor(3.0990, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3599, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1727)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3820, device='cuda:0'),
#                'ioi_acc': 0.9890625,
#                'ioi_logit_diff': tensor(3.2779, device='cuda:0'),
#                'induction': tensor(143.7993, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-25.9150),
#                'owt': tensor(3.1410, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3511, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.1048)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4568, device='cuda:0'),
#                'ioi_acc': 0.9875,
#                'ioi_logit_diff': tensor(3.2823, device='cuda:0'),
#                'induction': tensor(144.5217, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-26.3137),
#                'owt': tensor(3.0930, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3407, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1446)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2928, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.2091, device='cuda:0'),
#                'induction': tensor(146.8852, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-25.8799),
#                'owt': tensor(3.1439, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3422, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.0807)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3820, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.1193, device='cuda:0'),
#                'induction': tensor(147.7994, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-25.9900),
#                'owt': tensor(3.1155, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3494, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.0727)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2570, device='cuda:0'),
#                'ioi_acc': 0.9875,
#                'ioi_logit_diff': tensor(3.1554, device='cuda:0'),
#                'induction': tensor(149.7079, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-26.0407),
#                'owt': tensor(3.1512, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3852, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.0849)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1803, device='cuda:0'),
#                'ioi_acc': 0.984375,
#                'ioi_logit_diff': tensor(3.1026, device='cuda:0'),
#                'induction': tensor(150.9170, device='cuda:0'),
#                'induction_acc': 0.0078125,
#                'induction_logit_diff': tensor(-26.0565),
#                'owt': tensor(3.0809, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4335, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0601)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4270, device='cuda:0'),
#                'ioi_acc': 0.9953124999999999,
#                'ioi_logit_diff': tensor(3.1655, device='cuda:0'),
#                'induction': tensor(152.9597, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-26.0339),
#                'owt': tensor(3.0393, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4392, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0505)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3554, device='cuda:0'),
#                'ioi_acc': 0.9875,
#                'ioi_logit_diff': tensor(2.9615, device='cuda:0'),
#                'induction': tensor(154.8821, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-26.5420),
#                'owt': tensor(3.1548, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3843, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0085)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4063, device='cuda:0'),
#                'ioi_acc': 0.9953124999999999,
#                'ioi_logit_diff': tensor(2.9198, device='cuda:0'),
#                'induction': tensor(156.7050, device='cuda:0'),
#                'induction_acc': 0.0046875,
#                'induction_logit_diff': tensor(-25.7969),
#                'owt': tensor(3.1569, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4221, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0635)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3559, device='cuda:0'),
#                'ioi_acc': 0.9828125000000001,
#                'ioi_logit_diff': tensor(2.9637, device='cuda:0'),
#                'induction': tensor(157.3272, device='cuda:0'),
#                'induction_acc': 0.0109375,
#                'induction_logit_diff': tensor(-25.7018),
#                'owt': tensor(3.1532, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4183, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0737)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3619, device='cuda:0'),
#                'ioi_acc': 0.9843749999999999,
#                'ioi_logit_diff': tensor(2.8210, device='cuda:0'),
#                'induction': tensor(159.7414, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-25.1003),
#                'owt': tensor(3.0996, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4218, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.1058)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2813, device='cuda:0'),
#                'ioi_acc': 0.96875,
#                'ioi_logit_diff': tensor(2.9293, device='cuda:0'),
#                'induction': tensor(160.9924, device='cuda:0'),
#                'induction_acc': 0.00625,
#                'induction_logit_diff': tensor(-26.1909),
#                'owt': tensor(3.0995, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4132, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.0991)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5093, device='cuda:0'),
#                'ioi_acc': 0.9812500000000001,
#                'ioi_logit_diff': tensor(2.8773, device='cuda:0'),
#                'induction': tensor(162.2815, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-25.8437),
#                'owt': tensor(3.0604, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4322, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.1335)}),
#   defaultdict(float,
#               {'ioi': tensor(1.5074, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.1983, device='cuda:0'),
#                'induction': tensor(163.6559, device='cuda:0'),
#                'induction_acc': 0.010937500000000001,
#                'induction_logit_diff': tensor(-25.2908),
#                'owt': tensor(3.0809, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4201, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1825)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2781, device='cuda:0'),
#                'ioi_acc': 0.9781249999999999,
#                'ioi_logit_diff': tensor(3.1945, device='cuda:0'),
#                'induction': tensor(165.9440, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-25.1713),
#                'owt': tensor(3.0798, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3911, device='cuda:0'),
#                'greaterthan_acc': 0.9875,
#                'greaterthan_logit_diff': tensor(2.1753)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3703, device='cuda:0'),
#                'ioi_acc': 0.9796875,
#                'ioi_logit_diff': tensor(3.1042, device='cuda:0'),
#                'induction': tensor(166.7568, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-25.3566),
#                'owt': tensor(3.0905, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3795, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1455)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3672, device='cuda:0'),
#                'ioi_acc': 0.9765625,
#                'ioi_logit_diff': tensor(3.1213, device='cuda:0'),
#                'induction': tensor(170.7579, device='cuda:0'),
#                'induction_acc': 0.0078125,
#                'induction_logit_diff': tensor(-24.6995),
#                'owt': tensor(3.1552, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3795, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.0935)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2931, device='cuda:0'),
#                'ioi_acc': 0.9562499999999999,
#                'ioi_logit_diff': tensor(3.1082, device='cuda:0'),
#                'induction': tensor(171.3459, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-25.0423),
#                'owt': tensor(3.1262, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4206, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1443)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2649, device='cuda:0'),
#                'ioi_acc': 0.9625,
#                'ioi_logit_diff': tensor(3.0576, device='cuda:0'),
#                'induction': tensor(171.6391, device='cuda:0'),
#                'induction_acc': 0.0078125,
#                'induction_logit_diff': tensor(-24.9543),
#                'owt': tensor(3.1175, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4129, device='cuda:0'),
#                'greaterthan_acc': 0.99375,
#                'greaterthan_logit_diff': tensor(2.1452)})],
#  'Log 1 Minus P': [defaultdict(float,
#               {'ioi': tensor(1.2729, device='cuda:0'),
#                'ioi_acc': 0.978125,
#                'ioi_logit_diff': tensor(2.7700, device='cuda:0'),
#                'induction': tensor(9.9008, device='cuda:0'),
#                'induction_acc': 0.28125,
#                'induction_logit_diff': tensor(1.6106),
#                'owt': tensor(3.2635, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3214, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4999)}),
#   defaultdict(float,
#               {'ioi': tensor(1.4697, device='cuda:0'),
#                'ioi_acc': 0.95625,
#                'ioi_logit_diff': tensor(2.5939, device='cuda:0'),
#                'induction': tensor(9.9650, device='cuda:0'),
#                'induction_acc': 0.1765625,
#                'induction_logit_diff': tensor(1.5304),
#                'owt': tensor(3.1908, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4910, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4346)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0678, device='cuda:0'),
#                'ioi_acc': 0.9578125000000001,
#                'ioi_logit_diff': tensor(2.9853, device='cuda:0'),
#                'induction': tensor(9.6569, device='cuda:0'),
#                'induction_acc': 0.2296875,
#                'induction_logit_diff': tensor(1.7383),
#                'owt': tensor(3.2190, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.6328, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3506)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9468, device='cuda:0'),
#                'ioi_acc': 0.9781249999999999,
#                'ioi_logit_diff': tensor(3.2383, device='cuda:0'),
#                'induction': tensor(9.5314, device='cuda:0'),
#                'induction_acc': 0.23593750000000002,
#                'induction_logit_diff': tensor(1.8409),
#                'owt': tensor(3.1626, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.6441, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2937)}),
#   defaultdict(float,
#               {'ioi': tensor(0.8479, device='cuda:0'),
#                'ioi_acc': 0.9781249999999999,
#                'ioi_logit_diff': tensor(3.4006, device='cuda:0'),
#                'induction': tensor(9.3819, device='cuda:0'),
#                'induction_acc': 0.28437500000000004,
#                'induction_logit_diff': tensor(1.9921),
#                'owt': tensor(3.1898, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.6003, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1315)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9293, device='cuda:0'),
#                'ioi_acc': 0.9593750000000001,
#                'ioi_logit_diff': tensor(3.2668, device='cuda:0'),
#                'induction': tensor(9.1740, device='cuda:0'),
#                'induction_acc': 0.24062500000000003,
#                'induction_logit_diff': tensor(1.9187),
#                'owt': tensor(3.2268, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.6654, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(1.9828)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9923, device='cuda:0'),
#                'ioi_acc': 0.971875,
#                'ioi_logit_diff': tensor(3.3980, device='cuda:0'),
#                'induction': tensor(9.1271, device='cuda:0'),
#                'induction_acc': 0.2953125,
#                'induction_logit_diff': tensor(2.0603),
#                'owt': tensor(3.1952, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4991, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.0593)}),
#   defaultdict(float,
#               {'ioi': tensor(0.7614, device='cuda:0'),
#                'ioi_acc': 0.9890625,
#                'ioi_logit_diff': tensor(3.6673, device='cuda:0'),
#                'induction': tensor(8.9458, device='cuda:0'),
#                'induction_acc': 0.27812499999999996,
#                'induction_logit_diff': tensor(2.1209),
#                'owt': tensor(3.2066, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.5028, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1755)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9933, device='cuda:0'),
#                'ioi_acc': 0.9765625,
#                'ioi_logit_diff': tensor(3.3664, device='cuda:0'),
#                'induction': tensor(8.6926, device='cuda:0'),
#                'induction_acc': 0.30625,
#                'induction_logit_diff': tensor(1.9282),
#                'owt': tensor(3.1575, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4422, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.0820)}),
#   defaultdict(float,
#               {'ioi': tensor(0.7808, device='cuda:0'),
#                'ioi_acc': 0.9781249999999999,
#                'ioi_logit_diff': tensor(3.7031, device='cuda:0'),
#                'induction': tensor(8.6000, device='cuda:0'),
#                'induction_acc': 0.30624999999999997,
#                'induction_logit_diff': tensor(2.4259),
#                'owt': tensor(3.1828, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4425, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(1.9469)}),
#   defaultdict(float,
#               {'ioi': tensor(0.7550, device='cuda:0'),
#                'ioi_acc': 0.9859374999999999,
#                'ioi_logit_diff': tensor(3.6107, device='cuda:0'),
#                'induction': tensor(8.8909, device='cuda:0'),
#                'induction_acc': 0.3125,
#                'induction_logit_diff': tensor(2.2363),
#                'owt': tensor(3.2279, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3199, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(1.9023)}),
#   defaultdict(float,
#               {'ioi': tensor(0.7881, device='cuda:0'),
#                'ioi_acc': 0.9890625,
#                'ioi_logit_diff': tensor(3.9622, device='cuda:0'),
#                'induction': tensor(9.0564, device='cuda:0'),
#                'induction_acc': 0.28750000000000003,
#                'induction_logit_diff': tensor(1.9544),
#                'owt': tensor(3.2216, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4003, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(1.9231)}),
#   defaultdict(float,
#               {'ioi': tensor(0.8834, device='cuda:0'),
#                'ioi_acc': 0.98125,
#                'ioi_logit_diff': tensor(3.7258, device='cuda:0'),
#                'induction': tensor(8.9622, device='cuda:0'),
#                'induction_acc': 0.303125,
#                'induction_logit_diff': tensor(1.9959),
#                'owt': tensor(3.1992, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4318, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.0799)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9035, device='cuda:0'),
#                'ioi_acc': 0.9921875,
#                'ioi_logit_diff': tensor(3.5723, device='cuda:0'),
#                'induction': tensor(8.8487, device='cuda:0'),
#                'induction_acc': 0.28593750000000007,
#                'induction_logit_diff': tensor(2.0106),
#                'owt': tensor(3.1936, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3852, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.0549)}),
#   defaultdict(float,
#               {'ioi': tensor(0.8691, device='cuda:0'),
#                'ioi_acc': 0.9828125000000001,
#                'ioi_logit_diff': tensor(3.4539, device='cuda:0'),
#                'induction': tensor(8.8319, device='cuda:0'),
#                'induction_acc': 0.2828125,
#                'induction_logit_diff': tensor(2.2058),
#                'owt': tensor(3.1712, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2665, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1455)}),
#   defaultdict(float,
#               {'ioi': tensor(0.7744, device='cuda:0'),
#                'ioi_acc': 0.996875,
#                'ioi_logit_diff': tensor(3.4088, device='cuda:0'),
#                'induction': tensor(8.5566, device='cuda:0'),
#                'induction_acc': 0.296875,
#                'induction_logit_diff': tensor(2.5194),
#                'owt': tensor(3.1732, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2633, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3275)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9295, device='cuda:0'),
#                'ioi_acc': 0.9859374999999999,
#                'ioi_logit_diff': tensor(3.4670, device='cuda:0'),
#                'induction': tensor(8.6320, device='cuda:0'),
#                'induction_acc': 0.365625,
#                'induction_logit_diff': tensor(2.2808),
#                'owt': tensor(3.1604, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.2689, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2963)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0561, device='cuda:0'),
#                'ioi_acc': 0.9953125,
#                'ioi_logit_diff': tensor(3.3962, device='cuda:0'),
#                'induction': tensor(8.5655, device='cuda:0'),
#                'induction_acc': 0.31093750000000003,
#                'induction_logit_diff': tensor(2.4214),
#                'owt': tensor(3.2039, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3718, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1836)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2500, device='cuda:0'),
#                'ioi_acc': 0.9781249999999999,
#                'ioi_logit_diff': tensor(3.3364, device='cuda:0'),
#                'induction': tensor(8.7600, device='cuda:0'),
#                'induction_acc': 0.3453125,
#                'induction_logit_diff': tensor(2.4824),
#                'owt': tensor(3.1644, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3733, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3021)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1187, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.0872, device='cuda:0'),
#                'induction': tensor(8.5161, device='cuda:0'),
#                'induction_acc': 0.35624999999999996,
#                'induction_logit_diff': tensor(2.5150),
#                'owt': tensor(3.1429, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3715, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2806)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0925, device='cuda:0'),
#                'ioi_acc': 0.9859374999999999,
#                'ioi_logit_diff': tensor(3.3219, device='cuda:0'),
#                'induction': tensor(8.4926, device='cuda:0'),
#                'induction_acc': 0.3421875,
#                'induction_logit_diff': tensor(2.4242),
#                'owt': tensor(3.1041, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3541, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3311)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0562, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.3831, device='cuda:0'),
#                'induction': tensor(8.5157, device='cuda:0'),
#                'induction_acc': 0.26875,
#                'induction_logit_diff': tensor(2.4199),
#                'owt': tensor(3.1435, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4160, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3590)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2785, device='cuda:0'),
#                'ioi_acc': 0.9718749999999999,
#                'ioi_logit_diff': tensor(3.2691, device='cuda:0'),
#                'induction': tensor(8.4599, device='cuda:0'),
#                'induction_acc': 0.3265625,
#                'induction_logit_diff': tensor(2.5208),
#                'owt': tensor(3.1507, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3929, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2423)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3524, device='cuda:0'),
#                'ioi_acc': 0.9734375000000001,
#                'ioi_logit_diff': tensor(3.0013, device='cuda:0'),
#                'induction': tensor(8.5534, device='cuda:0'),
#                'induction_acc': 0.2859375,
#                'induction_logit_diff': tensor(2.3295),
#                'owt': tensor(3.1734, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.3564, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1664)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9153, device='cuda:0'),
#                'ioi_acc': 0.9640624999999999,
#                'ioi_logit_diff': tensor(3.4747, device='cuda:0'),
#                'induction': tensor(8.3264, device='cuda:0'),
#                'induction_acc': 0.346875,
#                'induction_logit_diff': tensor(2.6473),
#                'owt': tensor(3.1287, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4174, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1720)}),
#   defaultdict(float,
#               {'ioi': tensor(0.8742, device='cuda:0'),
#                'ioi_acc': 0.965625,
#                'ioi_logit_diff': tensor(3.2782, device='cuda:0'),
#                'induction': tensor(8.5113, device='cuda:0'),
#                'induction_acc': 0.32343750000000004,
#                'induction_logit_diff': tensor(2.4496),
#                'owt': tensor(3.1243, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.4158, device='cuda:0'),
#                'greaterthan_acc': 1.0,
# ...
#                'induction_logit_diff': tensor(-4.2847),
#                'owt': tensor(3.1634, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1384, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2718)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0654, device='cuda:0'),
#                'ioi_acc': 0.984375,
#                'ioi_logit_diff': tensor(3.2224, device='cuda:0'),
#                'induction': tensor(12.3038, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.4797),
#                'owt': tensor(3.1536, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0951, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2406)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9912, device='cuda:0'),
#                'ioi_acc': 0.9734375,
#                'ioi_logit_diff': tensor(3.2229, device='cuda:0'),
#                'induction': tensor(12.3844, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.3186),
#                'owt': tensor(3.1007, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0832, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3265)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1996, device='cuda:0'),
#                'ioi_acc': 0.96875,
#                'ioi_logit_diff': tensor(3.0984, device='cuda:0'),
#                'induction': tensor(12.4210, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.4321),
#                'owt': tensor(3.1726, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0818, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2742)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0028, device='cuda:0'),
#                'ioi_acc': 0.9671875,
#                'ioi_logit_diff': tensor(3.1970, device='cuda:0'),
#                'induction': tensor(12.5287, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.3247),
#                'owt': tensor(3.1904, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1044, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3485)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3305, device='cuda:0'),
#                'ioi_acc': 0.9640625,
#                'ioi_logit_diff': tensor(3.1018, device='cuda:0'),
#                'induction': tensor(12.4470, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.5445),
#                'owt': tensor(3.1742, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0490, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3129)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0435, device='cuda:0'),
#                'ioi_acc': 0.984375,
#                'ioi_logit_diff': tensor(3.1622, device='cuda:0'),
#                'induction': tensor(12.3694, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.8116),
#                'owt': tensor(3.1505, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0989, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2669)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0009, device='cuda:0'),
#                'ioi_acc': 0.9812500000000001,
#                'ioi_logit_diff': tensor(3.2017, device='cuda:0'),
#                'induction': tensor(12.3542, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.2766),
#                'owt': tensor(3.1981, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0951, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2918)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1935, device='cuda:0'),
#                'ioi_acc': 0.978125,
#                'ioi_logit_diff': tensor(3.0783, device='cuda:0'),
#                'induction': tensor(12.8986, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.5897),
#                'owt': tensor(3.1741, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.1301, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3756)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2787, device='cuda:0'),
#                'ioi_acc': 0.9671875,
#                'ioi_logit_diff': tensor(3.3229, device='cuda:0'),
#                'induction': tensor(12.1916, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.4075),
#                'owt': tensor(3.1503, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0944, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4118)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1390, device='cuda:0'),
#                'ioi_acc': 0.965625,
#                'ioi_logit_diff': tensor(3.1307, device='cuda:0'),
#                'induction': tensor(12.4265, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.0734),
#                'owt': tensor(3.1633, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0339, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4969)}),
#   defaultdict(float,
#               {'ioi': tensor(0.9833, device='cuda:0'),
#                'ioi_acc': 0.9734375000000001,
#                'ioi_logit_diff': tensor(3.2272, device='cuda:0'),
#                'induction': tensor(12.1763, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.4040),
#                'owt': tensor(3.1962, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0002, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.5530)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0024, device='cuda:0'),
#                'ioi_acc': 0.9875,
#                'ioi_logit_diff': tensor(3.2450, device='cuda:0'),
#                'induction': tensor(12.4941, device='cuda:0'),
#                'induction_acc': 0.009375,
#                'induction_logit_diff': tensor(-4.3756),
#                'owt': tensor(3.1908, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0194, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.4358)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1793, device='cuda:0'),
#                'ioi_acc': 0.9796875,
#                'ioi_logit_diff': tensor(3.2026, device='cuda:0'),
#                'induction': tensor(12.1415, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-4.6195),
#                'owt': tensor(3.0945, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0181, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3114)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2169, device='cuda:0'),
#                'ioi_acc': 0.971875,
#                'ioi_logit_diff': tensor(3.1364, device='cuda:0'),
#                'induction': tensor(12.3102, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.3143),
#                'owt': tensor(3.1861, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(3.9897, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2329)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2923, device='cuda:0'),
#                'ioi_acc': 0.971875,
#                'ioi_logit_diff': tensor(3.0003, device='cuda:0'),
#                'induction': tensor(12.4446, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.3617),
#                'owt': tensor(3.1103, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(3.9292, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3709)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2249, device='cuda:0'),
#                'ioi_acc': 0.971875,
#                'ioi_logit_diff': tensor(3.2620, device='cuda:0'),
#                'induction': tensor(12.4010, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-4.5041),
#                'owt': tensor(3.1350, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(3.9402, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1919)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1746, device='cuda:0'),
#                'ioi_acc': 0.9703125,
#                'ioi_logit_diff': tensor(2.9574, device='cuda:0'),
#                'induction': tensor(12.2407, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.2794),
#                'owt': tensor(3.1216, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(3.9700, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.3526)}),
#   defaultdict(float,
#               {'ioi': tensor(1.0944, device='cuda:0'),
#                'ioi_acc': 0.978125,
#                'ioi_logit_diff': tensor(3.1159, device='cuda:0'),
#                'induction': tensor(12.3131, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.5107),
#                'owt': tensor(3.1576, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0162, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2604)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3192, device='cuda:0'),
#                'ioi_acc': 0.9765625,
#                'ioi_logit_diff': tensor(3.1785, device='cuda:0'),
#                'induction': tensor(12.0784, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.2669),
#                'owt': tensor(3.1630, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0068, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2942)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3852, device='cuda:0'),
#                'ioi_acc': 0.96875,
#                'ioi_logit_diff': tensor(3.1142, device='cuda:0'),
#                'induction': tensor(12.4386, device='cuda:0'),
#                'induction_acc': 0.0015625,
#                'induction_logit_diff': tensor(-4.4633),
#                'owt': tensor(3.1479, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0263, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2294)}),
#   defaultdict(float,
#               {'ioi': tensor(1.3793, device='cuda:0'),
#                'ioi_acc': 0.9765625,
#                'ioi_logit_diff': tensor(3.0948, device='cuda:0'),
#                'induction': tensor(12.2317, device='cuda:0'),
#                'induction_acc': 0.004687500000000001,
#                'induction_logit_diff': tensor(-4.3922),
#                'owt': tensor(3.1154, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0793, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1791)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1458, device='cuda:0'),
#                'ioi_acc': 0.9796875,
#                'ioi_logit_diff': tensor(3.0343, device='cuda:0'),
#                'induction': tensor(12.6394, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.5265),
#                'owt': tensor(3.1302, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0707, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2234)}),
#   defaultdict(float,
#               {'ioi': tensor(1.1684, device='cuda:0'),
#                'ioi_acc': 0.984375,
#                'ioi_logit_diff': tensor(3.1682, device='cuda:0'),
#                'induction': tensor(12.3473, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.5959),
#                'owt': tensor(3.1701, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0381, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2221)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2407, device='cuda:0'),
#                'ioi_acc': 0.9828125,
#                'ioi_logit_diff': tensor(3.2878, device='cuda:0'),
#                'induction': tensor(12.8099, device='cuda:0'),
#                'induction_acc': 0.003125,
#                'induction_logit_diff': tensor(-4.4868),
#                'owt': tensor(3.1426, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0503, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.2398)}),
#   defaultdict(float,
#               {'ioi': tensor(1.2575, device='cuda:0'),
#                'ioi_acc': 0.9750000000000001,
#                'ioi_logit_diff': tensor(3.1155, device='cuda:0'),
#                'induction': tensor(12.1841, device='cuda:0'),
#                'induction_acc': 0.0,
#                'induction_logit_diff': tensor(-4.2972),
#                'owt': tensor(3.1497, device='cuda:0'),
#                'owt_acc': 0.0,
#                'owt_logit_diff': 0.0,
#                'greaterthan': tensor(4.0436, device='cuda:0'),
#                'greaterthan_acc': 1.0,
#                'greaterthan_logit_diff': tensor(2.1801)})]}
