# %%
import re
import random as rd

# %%
# IOI Dataset

NAMES = [
    "Michael",
    "Christopher",
    "Jessica",
    "Matthew",
    "Ashley",
    "Jennifer",
    "Joshua",
    "Amanda",
    "Daniel",
    "David",
    "James",
    "Robert",
    "John",
    "Joseph",
    "Andrew",
    "Ryan",
    "Brandon",
    "Jason",
    "Justin",
    "Sarah",
    "William",
    "Jonathan",
    "Stephanie",
    "Brian",
    "Nicole",
    "Nicholas",
    "Anthony",
    "Heather",
    "Eric",
    "Elizabeth",
    "Adam",
    "Megan",
    "Melissa",
    "Kevin",
    "Steven",
    "Thomas",
    "Timothy",
    "Christina",
    "Kyle",
    "Rachel",
    "Laura",
    "Lauren",
    "Amber",
    "Brittany",
    "Danielle",
    "Richard",
    "Kimberly",
    "Jeffrey",
    "Amy",
    "Crystal",
    "Michelle",
    "Tiffany",
    "Jeremy",
    "Benjamin",
    "Mark",
    "Emily",
    "Aaron",
    "Charles",
    "Rebecca",
    "Jacob",
    "Stephen",
    "Patrick",
    "Sean",
    "Erin",
    "Jamie",
    "Kelly",
    "Samantha",
    "Nathan",
    "Sara",
    "Dustin",
    "Paul",
    "Angela",
    "Tyler",
    "Scott",
    "Katherine",
    "Andrea",
    "Gregory",
    "Erica",
    "Mary",
    "Travis",
    "Lisa",
    "Kenneth",
    "Bryan",
    "Lindsey",
    "Kristen",
    "Jose",
    "Alexander",
    "Jesse",
    "Katie",
    "Lindsay",
    "Shannon",
    "Vanessa",
    "Courtney",
    "Christine",
    "Alicia",
    "Cody",
    "Allison",
    "Bradley",
    "Samuel",
]

ABC_TEMPLATES = [
    "Then, [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "Afterwards [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
    "When [A], [B] and [C] arrived at the [PLACE], [B] and [C] gave a [OBJECT] to [A]",
    "Friends [A], [B] and [C] went to the [PLACE]. [B] and [C] gave a [OBJECT] to [A]",
]

BAC_TEMPLATES = [
    template.replace("[B]", "[A]", 1).replace("[A]", "[B]", 1)
    for template in ABC_TEMPLATES
]

BABA_TEMPLATES = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LONG_TEMPLATES = [
    "Then in the morning, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then in the morning, [B] and [A] had a long argument, and afterwards [B] said to [A]",
    "After taking a long break [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]",
    "When soon afterwards [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]",
    "While spending time together [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]",
    "While spending time together [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]",
    "After the lunch in the afternoon, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, while spending time together [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then in the morning afterwards, [B] and [A] had a long argument. Afterwards [B] said to [A]",
    "The local big [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]",
    "Friends separated at birth [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]",
]

BABA_LATE_IOS = [
    "Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]",
    "Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument and after that [B] said to [A]",
    "After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]",
    "Then, [B] and [A] had a long argument. Afterwards [B] said to [A]",
]

BABA_EARLY_IOS = [
    "Then [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a lot of fun at the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] were working at the [PLACE], and [B] decided to give a [OBJECT] to [A]",
    "Then [B] and [A] were thinking about going to the [PLACE], and [B] wanted to give a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and after that [B] said to [A]",
    "After the lunch [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Afterwards [B] and [A] went to the [PLACE], and [B] gave a [OBJECT] to [A]",
    "Then [B] and [A] had a long argument, and afterwards [B] said to [A]",
]

TEMPLATES_VARIED_MIDDLE = [
    "",
]

# no end of texts, GPT-2 small wasn't trained this way (ask Arthur)
# warnings.warn("Adding end of text prefixes!")
# for TEMPLATES in [BABA_TEMPLATES, BABA_EARLY_IOS, BABA_LATE_IOS]:
#     for i in range(len(TEMPLATES)):
#         TEMPLATES[i] = "<|endoftext|>" + TEMPLATES[i]

ABBA_TEMPLATES = BABA_TEMPLATES[:]
ABBA_LATE_IOS = BABA_LATE_IOS[:]
ABBA_EARLY_IOS = BABA_EARLY_IOS[:]

# %%
VERBS = [" tried", " said", " decided", " wanted", " gave"]
PLACES = [
    "store",
    "garden",
    "restaurant",
    "school",
    "hospital",
    "office",
    "house",
    "station",
]
OBJECTS = [
    "ring",
    "kiss",
    "bone",
    "basketball",
    "computer",
    "necklace",
    "drink",
    "snack",
]

ANIMALS = [
    "dog",
    "cat",
    "snake",
    "elephant",
    "beetle",
    "hippo",
    "giraffe",
    "tiger",
    "husky",
    "lion",
    "panther",
    "whale",
    "dolphin",
    "beaver",
    "rabbit",
    "fox",
    "lamb",
    "ferret",
]

# %%
for TEMPLATES in [ABBA_TEMPLATES, ABBA_LATE_IOS, ABBA_EARLY_IOS]:
    for i in range(len(TEMPLATES)):
        first_clause = True
        for j in range(1, len(TEMPLATES[i]) - 1):
            if TEMPLATES[i][j - 1 : j + 2] == "[B]" and first_clause:
                TEMPLATES[i] = TEMPLATES[i][:j] + "A" + TEMPLATES[i][j + 1 :]
            elif TEMPLATES[i][j - 1 : j + 2] == "[A]" and first_clause:
                first_clause = False
                TEMPLATES[i] = TEMPLATES[i][:j] + "B" + TEMPLATES[i][j + 1 :]


def multiple_replace(dict, text):
    # from: https://stackoverflow.com/questions/15175142/how-can-i-do-multiple-substitutions-using-regex
    # Create a regular expression from the dictionary keys
    regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

    # For each match, look-up corresponding value in dictionary
    return regex.sub(lambda mo: dict[mo.string[mo.start() : mo.end()]], text)


def iter_sample_fast(iterable, samplesize):
    results = []
    # Fill in the first samplesize elements:
    try:
        for _ in range(samplesize):
            results.append(next(iterable))
    except StopIteration:
        raise ValueError("Sample larger than population.")
    rd.shuffle(results)  # Randomize their positions

    return results


NOUNS_DICT = NOUNS_DICT = {"[PLACE]": PLACES, "[OBJECT]": OBJECTS}


def gen_prompt_uniform(
    templates, names, nouns_dict, N, symmetric=False, prefixes=None, abc=False
):
    nb_gen = 0
    ioi_prompts = []
    while nb_gen < N:
        temp = rd.choice(templates)
        temp_id = templates.index(temp)
        name_1 = ""
        name_2 = ""
        name_3 = ""
        while len(set([name_1, name_2, name_3])) < 3:
            name_1 = rd.choice(names)
            name_2 = rd.choice(names)
            name_3 = rd.choice(names)

        nouns = {}
        ioi_prompt = {}
        for k in nouns_dict:
            nouns[k] = rd.choice(nouns_dict[k])
            ioi_prompt[k] = nouns[k]
        prompt = temp
        for k in nouns_dict:
            prompt = prompt.replace(k, nouns[k])

        if prefixes is not None:
            L = rd.randint(30, 40)
            pref = ".".join(rd.choice(prefixes).split(".")[:L])
            pref += "<|endoftext|>"
        else:
            pref = ""

        prompt1 = prompt.replace("[A]", name_1)
        prompt1 = prompt1.replace("[B]", name_2)
        if abc:
            prompt1 = prompt1.replace("[C]", name_3)
        prompt1 = pref + prompt1
        ioi_prompt["text"] = prompt1
        ioi_prompt["IO"] = name_1
        ioi_prompt["S"] = name_2
        ioi_prompt["TEMPLATE_IDX"] = temp_id
        ioi_prompts.append(ioi_prompt)
        if abc:
            ioi_prompts[-1]["C"] = name_3

        nb_gen += 1

        if symmetric and nb_gen < N:
            prompt2 = prompt.replace("[A]", name_2)
            prompt2 = prompt2.replace("[B]", name_1)
            prompt2 = pref + prompt2
            ioi_prompts.append(
                {"text": prompt2, "IO": name_2, "S": name_1, "TEMPLATE_IDX": temp_id}
            )
            nb_gen += 1
    return ioi_prompts

# %%
ioi_prompts_single_template = gen_prompt_uniform(
    [ABBA_TEMPLATES[0]], NAMES, NOUNS_DICT, 10000, True, abc=False
)
# Make sentences with each template for train and test
ioi_prompts = gen_prompt_uniform(
    BABA_TEMPLATES + ABBA_TEMPLATES, NAMES, NOUNS_DICT, 10000, True, abc=False
)

BABA_TEMPLATES + ABBA_TEMPLATES
# Out:
# ['Then, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [B] and [A] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument, and afterwards [B] said to [A]',
#  'After [B] and [A] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [B] and [A] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [B] and [A] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [B] and [A] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [B] and [A] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [B] and [A] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [B] and [A] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [B] and [A] found a [OBJECT] at the [PLACE]. [B] gave it to [A]',
#  'Then, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a lot of fun at the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] were working at the [PLACE]. [B] decided to give a [OBJECT] to [A]',
#  'Then, [A] and [B] were thinking about going to the [PLACE]. [B] wanted to give a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument, and afterwards [B] said to [A]',
#  'After [A] and [B] went to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give it to [A]',
#  'When [A] and [B] got a [OBJECT] at the [PLACE], [B] decided to give the [OBJECT] to [A]',
#  'While [A] and [B] were working at the [PLACE], [B] gave a [OBJECT] to [A]',
#  'While [A] and [B] were commuting to the [PLACE], [B] gave a [OBJECT] to [A]',
#  'After the lunch, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Afterwards, [A] and [B] went to the [PLACE]. [B] gave a [OBJECT] to [A]',
#  'Then, [A] and [B] had a long argument. Afterwards [B] said to [A]',
#  'The [PLACE] [A] and [B] went to had a [OBJECT]. [B] gave it to [A]',
#  'Friends [A] and [B] found a [OBJECT] at the [PLACE]. [B] gave it to [A]']

# %%
# replace the first occurence of B in BABA and ABBA with C
non_ioi_templates = []
for template in ABBA_TEMPLATES + BABA_TEMPLATES:
    non_ioi_templates.append(template.replace("[B]", "[C]").replace("[C]", "[B]", 1))


ioi_prompts_abc = gen_prompt_uniform(
    non_ioi_templates, NAMES, NOUNS_DICT, 10000, False, abc=True
)

ioi_prompts_single_template_abc = gen_prompt_uniform(
    [non_ioi_templates[0]], NAMES, NOUNS_DICT, 10000, False, abc=True
)

# %%
ioi_prompts_two_template = gen_prompt_uniform(
    [BABA_TEMPLATES[0], ABBA_TEMPLATES[0]], NAMES, NOUNS_DICT, 10000, True, abc=False
)

ioi_prompts_two_template_abc = gen_prompt_uniform(
    [BABA_TEMPLATES[0].replace("[B]", "[C]").replace("[C]", "[B]", 1), ABBA_TEMPLATES[0].replace("[B]", "[C]").replace("[C]", "[B]", 1)], NAMES, NOUNS_DICT, 10000, False, abc=True)

# %%
len(ioi_prompts_two_template_abc)
# Out:
# 10000

# %%
# save sentences in train_test_split
import pickle

prompts_single_template_train = ioi_prompts_single_template[:8000]
prompts_single_template_test = ioi_prompts_single_template[8000:]
with open("data/ioi_prompts_single_template_train.pkl", "wb") as f:
    pickle.dump(prompts_single_template_train, f)
with open("data/ioi_prompts_single_template_test.pkl", "wb") as f:
    pickle.dump(prompts_single_template_test, f)

prompts_single_template_abc_train = ioi_prompts_single_template_abc[:8000]
prompts_single_template_abc_test = ioi_prompts_single_template_abc[8000:]
with open("data/ioi_prompts_single_template_abc_train.pkl", "wb") as f:
    pickle.dump(prompts_single_template_abc_train, f)
with open("data/ioi_prompts_single_template_abc_test.pkl", "wb") as f:
    pickle.dump(prompts_single_template_abc_test, f)

prompts_double_template_train = ioi_prompts_two_template[:8000]
prompts_double_template_test = ioi_prompts_two_template[8000:]
with open("data/ioi_prompts_double_template_train.pkl", "wb") as f:
    pickle.dump(prompts_double_template_train, f)
with open("data/ioi_prompts_double_template_test.pkl", "wb") as f:
    pickle.dump(prompts_double_template_test, f)

prompts_double_template_abc_train = ioi_prompts_two_template_abc[:8000]
prompts_double_template_abc_test = ioi_prompts_two_template_abc[8000:]
with open("data/ioi_prompts_double_template_abc_train.pkl", "wb") as f:
    pickle.dump(prompts_double_template_abc_train, f)
with open("data/ioi_prompts_double_template_abc_test.pkl", "wb") as f:
    pickle.dump(prompts_double_template_abc_test, f)

# %%
ioi_prompts_single_template
# Out:
# [{'[PLACE]': 'garden',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Sarah and Tyler went to the garden. Tyler gave a bone to Sarah',
#   'IO': 'Sarah',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Tyler and Sarah went to the garden. Sarah gave a bone to Tyler',
#   'IO': 'Tyler',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Timothy and Stephen went to the school. Stephen gave a necklace to Timothy',
#   'IO': 'Timothy',
#   'S': 'Stephen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Stephen and Timothy went to the school. Timothy gave a necklace to Stephen',
#   'IO': 'Stephen',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Stephanie and Heather went to the house. Heather gave a kiss to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Heather and Stephanie went to the house. Stephanie gave a kiss to Heather',
#   'IO': 'Heather',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Nicholas and Lindsey went to the station. Lindsey gave a computer to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Lindsey and Nicholas went to the station. Nicholas gave a computer to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Alexander and Amy went to the store. Amy gave a bone to Alexander',
#   'IO': 'Alexander',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Amy and Alexander went to the store. Alexander gave a bone to Amy',
#   'IO': 'Amy',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Christina and Tyler went to the station. Tyler gave a snack to Christina',
#   'IO': 'Christina',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Tyler and Christina went to the station. Christina gave a snack to Tyler',
#   'IO': 'Tyler',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Katie and Christine went to the garden. Christine gave a kiss to Katie',
#   'IO': 'Katie',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Christine and Katie went to the garden. Katie gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Lindsay and Elizabeth went to the office. Elizabeth gave a necklace to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Elizabeth and Lindsay went to the office. Lindsay gave a necklace to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Vanessa and Mary went to the school. Mary gave a drink to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Mary and Vanessa went to the school. Vanessa gave a drink to Mary',
#   'IO': 'Mary',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Aaron and Sarah went to the school. Sarah gave a computer to Aaron',
#   'IO': 'Aaron',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Sarah and Aaron went to the school. Aaron gave a computer to Sarah',
#   'IO': 'Sarah',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Amanda and Nicholas went to the house. Nicholas gave a snack to Amanda',
#   'IO': 'Amanda',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nicholas and Amanda went to the house. Amanda gave a snack to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Samuel and Paul went to the hospital. Paul gave a ring to Samuel',
#   'IO': 'Samuel',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Paul and Samuel went to the hospital. Samuel gave a ring to Paul',
#   'IO': 'Paul',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Rebecca and Amy went to the garden. Amy gave a drink to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Amy and Rebecca went to the garden. Rebecca gave a drink to Amy',
#   'IO': 'Amy',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Andrea and Melissa went to the station. Melissa gave a necklace to Andrea',
#   'IO': 'Andrea',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Melissa and Andrea went to the station. Andrea gave a necklace to Melissa',
#   'IO': 'Melissa',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Richard and Joshua went to the restaurant. Joshua gave a drink to Richard',
#   'IO': 'Richard',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Joshua and Richard went to the restaurant. Richard gave a drink to Joshua',
#   'IO': 'Joshua',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kenneth and Vanessa went to the house. Vanessa gave a necklace to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Vanessa and Kenneth went to the house. Kenneth gave a necklace to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Shannon and Katherine went to the office. Katherine gave a bone to Shannon',
#   'IO': 'Shannon',
#   'S': 'Katherine',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Katherine and Shannon went to the office. Shannon gave a bone to Katherine',
#   'IO': 'Katherine',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Erica and Vanessa went to the restaurant. Vanessa gave a drink to Erica',
#   'IO': 'Erica',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Vanessa and Erica went to the restaurant. Erica gave a drink to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Ashley and Kimberly went to the house. Kimberly gave a basketball to Ashley',
#   'IO': 'Ashley',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kimberly and Ashley went to the house. Ashley gave a basketball to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Samuel and Travis went to the station. Travis gave a basketball to Samuel',
#   'IO': 'Samuel',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Travis and Samuel went to the station. Samuel gave a basketball to Travis',
#   'IO': 'Travis',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kristen and Anthony went to the restaurant. Anthony gave a necklace to Kristen',
#   'IO': 'Kristen',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Anthony and Kristen went to the restaurant. Kristen gave a necklace to Anthony',
#   'IO': 'Anthony',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jamie and Kelly went to the hospital. Kelly gave a snack to Jamie',
#   'IO': 'Jamie',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kelly and Jamie went to the hospital. Jamie gave a snack to Kelly',
#   'IO': 'Kelly',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Jessica and Kyle went to the hospital. Kyle gave a bone to Jessica',
#   'IO': 'Jessica',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kyle and Jessica went to the hospital. Jessica gave a bone to Kyle',
#   'IO': 'Kyle',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jessica and Ryan went to the house. Ryan gave a drink to Jessica',
#   'IO': 'Jessica',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ryan and Jessica went to the house. Jessica gave a drink to Ryan',
#   'IO': 'Ryan',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, David and Travis went to the office. Travis gave a bone to David',
#   'IO': 'David',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Travis and David went to the office. David gave a bone to Travis',
#   'IO': 'Travis',
#   'S': 'David',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Samantha and Ryan went to the garden. Ryan gave a necklace to Samantha',
#   'IO': 'Samantha',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ryan and Samantha went to the garden. Samantha gave a necklace to Ryan',
#   'IO': 'Ryan',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, John and Emily went to the restaurant. Emily gave a kiss to John',
#   'IO': 'John',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Emily and John went to the restaurant. John gave a kiss to Emily',
#   'IO': 'Emily',
#   'S': 'John',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Jesse and Jose went to the restaurant. Jose gave a bone to Jesse',
#   'IO': 'Jesse',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jose and Jesse went to the restaurant. Jesse gave a bone to Jose',
#   'IO': 'Jose',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Kyle and Scott went to the office. Scott gave a computer to Kyle',
#   'IO': 'Kyle',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Scott and Kyle went to the office. Kyle gave a computer to Scott',
#   'IO': 'Scott',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Thomas and Sarah went to the station. Sarah gave a kiss to Thomas',
#   'IO': 'Thomas',
#   'S': 'Sarah',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Sarah and Thomas went to the station. Thomas gave a kiss to Sarah',
#   'IO': 'Sarah',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Michael and Sara went to the restaurant. Sara gave a computer to Michael',
#   'IO': 'Michael',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Sara and Michael went to the restaurant. Michael gave a computer to Sara',
#   'IO': 'Sara',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jesse and Daniel went to the garden. Daniel gave a snack to Jesse',
#   'IO': 'Jesse',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Daniel and Jesse went to the garden. Jesse gave a snack to Daniel',
#   'IO': 'Daniel',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Joseph and Rebecca went to the school. Rebecca gave a drink to Joseph',
#   'IO': 'Joseph',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Rebecca and Joseph went to the school. Joseph gave a drink to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Andrea and Kenneth went to the house. Kenneth gave a bone to Andrea',
#   'IO': 'Andrea',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kenneth and Andrea went to the house. Andrea gave a bone to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Ryan and Emily went to the house. Emily gave a ring to Ryan',
#   'IO': 'Ryan',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Emily and Ryan went to the house. Ryan gave a ring to Emily',
#   'IO': 'Emily',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Amanda and Dustin went to the garden. Dustin gave a basketball to Amanda',
#   'IO': 'Amanda',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Dustin and Amanda went to the garden. Amanda gave a basketball to Dustin',
#   'IO': 'Dustin',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Sean and Courtney went to the house. Courtney gave a drink to Sean',
#   'IO': 'Sean',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Courtney and Sean went to the house. Sean gave a drink to Courtney',
#   'IO': 'Courtney',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Amy and Mary went to the hospital. Mary gave a basketball to Amy',
#   'IO': 'Amy',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Mary and Amy went to the hospital. Amy gave a basketball to Mary',
#   'IO': 'Mary',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Kelly and Samuel went to the school. Samuel gave a necklace to Kelly',
#   'IO': 'Kelly',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Samuel and Kelly went to the school. Kelly gave a necklace to Samuel',
#   'IO': 'Samuel',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Erin and Bryan went to the office. Bryan gave a computer to Erin',
#   'IO': 'Erin',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Bryan and Erin went to the office. Erin gave a computer to Bryan',
#   'IO': 'Bryan',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Lisa and Nathan went to the station. Nathan gave a kiss to Lisa',
#   'IO': 'Lisa',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nathan and Lisa went to the station. Lisa gave a kiss to Nathan',
#   'IO': 'Nathan',
#   'S': 'Lisa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Danielle and Aaron went to the station. Aaron gave a bone to Danielle',
#   'IO': 'Danielle',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Aaron and Danielle went to the station. Danielle gave a bone to Aaron',
#   'IO': 'Aaron',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Thomas and Alicia went to the office. Alicia gave a basketball to Thomas',
#   'IO': 'Thomas',
#   'S': 'Alicia',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Alicia and Thomas went to the office. Thomas gave a basketball to Alicia',
#   'IO': 'Alicia',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Scott and Travis went to the restaurant. Travis gave a basketball to Scott',
#   'IO': 'Scott',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Travis and Scott went to the restaurant. Scott gave a basketball to Travis',
#   'IO': 'Travis',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Richard and Christopher went to the hospital. Christopher gave a drink to Richard',
#   'IO': 'Richard',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Christopher and Richard went to the hospital. Richard gave a drink to Christopher',
#   'IO': 'Christopher',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Samuel and Kyle went to the garden. Kyle gave a computer to Samuel',
#   'IO': 'Samuel',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kyle and Samuel went to the garden. Samuel gave a computer to Kyle',
#   'IO': 'Kyle',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Nicholas and Kyle went to the store. Kyle gave a bone to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kyle and Nicholas went to the store. Nicholas gave a bone to Kyle',
#   'IO': 'Kyle',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Daniel and Anthony went to the restaurant. Anthony gave a bone to Daniel',
#   'IO': 'Daniel',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Anthony and Daniel went to the restaurant. Daniel gave a bone to Anthony',
#   'IO': 'Anthony',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Elizabeth and Timothy went to the hospital. Timothy gave a kiss to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Timothy and Elizabeth went to the hospital. Elizabeth gave a kiss to Timothy',
#   'IO': 'Timothy',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jacob and Katie went to the house. Katie gave a drink to Jacob',
#   'IO': 'Jacob',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Katie and Jacob went to the house. Jacob gave a drink to Katie',
#   'IO': 'Katie',
#   'S': 'Jacob',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Gregory and Cody went to the station. Cody gave a computer to Gregory',
#   'IO': 'Gregory',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Cody and Gregory went to the station. Gregory gave a computer to Cody',
#   'IO': 'Cody',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Nicholas and Kyle went to the hospital. Kyle gave a drink to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Kyle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kyle and Nicholas went to the hospital. Nicholas gave a drink to Kyle',
#   'IO': 'Kyle',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Robert and James went to the house. James gave a basketball to Robert',
#   'IO': 'Robert',
#   'S': 'James',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, James and Robert went to the house. Robert gave a basketball to James',
#   'IO': 'James',
#   'S': 'Robert',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Lindsey and Jamie went to the station. Jamie gave a ring to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jamie and Lindsey went to the station. Lindsey gave a ring to Jamie',
#   'IO': 'Jamie',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Brian and Samuel went to the garden. Samuel gave a drink to Brian',
#   'IO': 'Brian',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Samuel and Brian went to the garden. Brian gave a drink to Samuel',
#   'IO': 'Samuel',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Laura and Michelle went to the garden. Michelle gave a drink to Laura',
#   'IO': 'Laura',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Michelle and Laura went to the garden. Laura gave a drink to Michelle',
#   'IO': 'Michelle',
#   'S': 'Laura',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Tyler and Jennifer went to the house. Jennifer gave a snack to Tyler',
#   'IO': 'Tyler',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jennifer and Tyler went to the house. Tyler gave a snack to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, James and Patrick went to the restaurant. Patrick gave a bone to James',
#   'IO': 'James',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Patrick and James went to the restaurant. James gave a bone to Patrick',
#   'IO': 'Patrick',
#   'S': 'James',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Travis and Mary went to the office. Mary gave a drink to Travis',
#   'IO': 'Travis',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Mary and Travis went to the office. Travis gave a drink to Mary',
#   'IO': 'Mary',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Sara and Gregory went to the house. Gregory gave a computer to Sara',
#   'IO': 'Sara',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Gregory and Sara went to the house. Sara gave a computer to Gregory',
#   'IO': 'Gregory',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jeffrey and Paul went to the house. Paul gave a ring to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Paul and Jeffrey went to the house. Jeffrey gave a ring to Paul',
#   'IO': 'Paul',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Alexander and Eric went to the hospital. Eric gave a bone to Alexander',
#   'IO': 'Alexander',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Eric and Alexander went to the hospital. Alexander gave a bone to Eric',
#   'IO': 'Eric',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Samuel and Tyler went to the garden. Tyler gave a necklace to Samuel',
#   'IO': 'Samuel',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Tyler and Samuel went to the garden. Samuel gave a necklace to Tyler',
#   'IO': 'Tyler',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jeremy and Travis went to the office. Travis gave a ring to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Travis and Jeremy went to the office. Jeremy gave a ring to Travis',
#   'IO': 'Travis',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Rachel and Steven went to the office. Steven gave a drink to Rachel',
#   'IO': 'Rachel',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Steven and Rachel went to the office. Rachel gave a drink to Steven',
#   'IO': 'Steven',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Lindsey and Ryan went to the station. Ryan gave a basketball to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ryan and Lindsey went to the station. Lindsey gave a basketball to Ryan',
#   'IO': 'Ryan',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Elizabeth and Joshua went to the school. Joshua gave a computer to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Joshua and Elizabeth went to the school. Elizabeth gave a computer to Joshua',
#   'IO': 'Joshua',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, David and Benjamin went to the store. Benjamin gave a basketball to David',
#   'IO': 'David',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Benjamin and David went to the store. David gave a basketball to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'David',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Mark and Jamie went to the house. Jamie gave a basketball to Mark',
#   'IO': 'Mark',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jamie and Mark went to the house. Mark gave a basketball to Jamie',
#   'IO': 'Jamie',
#   'S': 'Mark',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Angela and Nicholas went to the school. Nicholas gave a ring to Angela',
#   'IO': 'Angela',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nicholas and Angela went to the school. Angela gave a ring to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Anthony and Kristen went to the restaurant. Kristen gave a bone to Anthony',
#   'IO': 'Anthony',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kristen and Anthony went to the restaurant. Anthony gave a bone to Kristen',
#   'IO': 'Kristen',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, William and Emily went to the house. Emily gave a necklace to William',
#   'IO': 'William',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Emily and William went to the house. William gave a necklace to Emily',
#   'IO': 'Emily',
#   'S': 'William',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Andrew and Jason went to the station. Jason gave a necklace to Andrew',
#   'IO': 'Andrew',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jason and Andrew went to the station. Andrew gave a necklace to Jason',
#   'IO': 'Jason',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Matthew and Danielle went to the store. Danielle gave a drink to Matthew',
#   'IO': 'Matthew',
#   'S': 'Danielle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Danielle and Matthew went to the store. Matthew gave a drink to Danielle',
#   'IO': 'Danielle',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Justin and Anthony went to the restaurant. Anthony gave a basketball to Justin',
#   'IO': 'Justin',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Anthony and Justin went to the restaurant. Justin gave a basketball to Anthony',
#   'IO': 'Anthony',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Bradley and Lindsay went to the hospital. Lindsay gave a bone to Bradley',
#   'IO': 'Bradley',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Lindsay and Bradley went to the hospital. Bradley gave a bone to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Michelle and Stephen went to the school. Stephen gave a ring to Michelle',
#   'IO': 'Michelle',
#   'S': 'Stephen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Stephen and Michelle went to the school. Michelle gave a ring to Stephen',
#   'IO': 'Stephen',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Scott and Brandon went to the hospital. Brandon gave a necklace to Scott',
#   'IO': 'Scott',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brandon and Scott went to the hospital. Scott gave a necklace to Brandon',
#   'IO': 'Brandon',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Adam and Katie went to the store. Katie gave a drink to Adam',
#   'IO': 'Adam',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Katie and Adam went to the store. Adam gave a drink to Katie',
#   'IO': 'Katie',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Melissa and Alexander went to the office. Alexander gave a ring to Melissa',
#   'IO': 'Melissa',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Alexander and Melissa went to the office. Melissa gave a ring to Alexander',
#   'IO': 'Alexander',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Andrea and Sara went to the office. Sara gave a bone to Andrea',
#   'IO': 'Andrea',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Sara and Andrea went to the office. Andrea gave a bone to Sara',
#   'IO': 'Sara',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jennifer and Stephen went to the store. Stephen gave a basketball to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Stephen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Stephen and Jennifer went to the store. Jennifer gave a basketball to Stephen',
#   'IO': 'Stephen',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Lindsay and Crystal went to the office. Crystal gave a drink to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Crystal and Lindsay went to the office. Lindsay gave a drink to Crystal',
#   'IO': 'Crystal',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Elizabeth and Kevin went to the house. Kevin gave a ring to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kevin and Elizabeth went to the house. Elizabeth gave a ring to Kevin',
#   'IO': 'Kevin',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Megan and Samantha went to the store. Samantha gave a necklace to Megan',
#   'IO': 'Megan',
#   'S': 'Samantha',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Samantha and Megan went to the store. Megan gave a necklace to Samantha',
#   'IO': 'Samantha',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Kimberly and Brittany went to the garden. Brittany gave a drink to Kimberly',
#   'IO': 'Kimberly',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brittany and Kimberly went to the garden. Kimberly gave a drink to Brittany',
#   'IO': 'Brittany',
#   'S': 'Kimberly',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Bryan and Ashley went to the house. Ashley gave a snack to Bryan',
#   'IO': 'Bryan',
#   'S': 'Ashley',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ashley and Bryan went to the house. Bryan gave a snack to Ashley',
#   'IO': 'Ashley',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jason and Vanessa went to the station. Vanessa gave a basketball to Jason',
#   'IO': 'Jason',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Vanessa and Jason went to the station. Jason gave a basketball to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Joseph and Adam went to the office. Adam gave a computer to Joseph',
#   'IO': 'Joseph',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Adam and Joseph went to the office. Joseph gave a computer to Adam',
#   'IO': 'Adam',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jonathan and James went to the store. James gave a snack to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'James',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, James and Jonathan went to the store. Jonathan gave a snack to James',
#   'IO': 'James',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jose and Richard went to the restaurant. Richard gave a snack to Jose',
#   'IO': 'Jose',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Richard and Jose went to the restaurant. Jose gave a snack to Richard',
#   'IO': 'Richard',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Michelle and Kevin went to the store. Kevin gave a bone to Michelle',
#   'IO': 'Michelle',
#   'S': 'Kevin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kevin and Michelle went to the store. Michelle gave a bone to Kevin',
#   'IO': 'Kevin',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Dustin and Stephen went to the garden. Stephen gave a kiss to Dustin',
#   'IO': 'Dustin',
#   'S': 'Stephen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Stephen and Dustin went to the garden. Dustin gave a kiss to Stephen',
#   'IO': 'Stephen',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Justin and Kelly went to the restaurant. Kelly gave a drink to Justin',
#   'IO': 'Justin',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kelly and Justin went to the restaurant. Justin gave a drink to Kelly',
#   'IO': 'Kelly',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Brandon and Jeremy went to the station. Jeremy gave a necklace to Brandon',
#   'IO': 'Brandon',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jeremy and Brandon went to the station. Brandon gave a necklace to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Christine and Heather went to the restaurant. Heather gave a kiss to Christine',
#   'IO': 'Christine',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Heather and Christine went to the restaurant. Christine gave a kiss to Heather',
#   'IO': 'Heather',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Scott and Kristen went to the house. Kristen gave a bone to Scott',
#   'IO': 'Scott',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kristen and Scott went to the house. Scott gave a bone to Kristen',
#   'IO': 'Kristen',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Emily and Benjamin went to the office. Benjamin gave a drink to Emily',
#   'IO': 'Emily',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Benjamin and Emily went to the office. Emily gave a drink to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Daniel and Timothy went to the garden. Timothy gave a kiss to Daniel',
#   'IO': 'Daniel',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Timothy and Daniel went to the garden. Daniel gave a kiss to Timothy',
#   'IO': 'Timothy',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Tyler and Paul went to the house. Paul gave a basketball to Tyler',
#   'IO': 'Tyler',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Paul and Tyler went to the house. Tyler gave a basketball to Paul',
#   'IO': 'Paul',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Ryan and Brian went to the hospital. Brian gave a kiss to Ryan',
#   'IO': 'Ryan',
#   'S': 'Brian',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brian and Ryan went to the hospital. Ryan gave a kiss to Brian',
#   'IO': 'Brian',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Courtney and Aaron went to the school. Aaron gave a necklace to Courtney',
#   'IO': 'Courtney',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Aaron and Courtney went to the school. Courtney gave a necklace to Aaron',
#   'IO': 'Aaron',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Paul and Thomas went to the station. Thomas gave a basketball to Paul',
#   'IO': 'Paul',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Thomas and Paul went to the station. Paul gave a basketball to Thomas',
#   'IO': 'Thomas',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Emily and Lindsay went to the office. Lindsay gave a kiss to Emily',
#   'IO': 'Emily',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Lindsay and Emily went to the office. Emily gave a kiss to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Timothy and Courtney went to the school. Courtney gave a computer to Timothy',
#   'IO': 'Timothy',
#   'S': 'Courtney',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Courtney and Timothy went to the school. Timothy gave a computer to Courtney',
#   'IO': 'Courtney',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Emily and Elizabeth went to the house. Elizabeth gave a basketball to Emily',
#   'IO': 'Emily',
#   'S': 'Elizabeth',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Elizabeth and Emily went to the house. Emily gave a basketball to Elizabeth',
#   'IO': 'Elizabeth',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Melissa and Sean went to the store. Sean gave a necklace to Melissa',
#   'IO': 'Melissa',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Sean and Melissa went to the store. Melissa gave a necklace to Sean',
#   'IO': 'Sean',
#   'S': 'Melissa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Rachel and Patrick went to the restaurant. Patrick gave a computer to Rachel',
#   'IO': 'Rachel',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Patrick and Rachel went to the restaurant. Rachel gave a computer to Patrick',
#   'IO': 'Patrick',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Amanda and Kenneth went to the house. Kenneth gave a necklace to Amanda',
#   'IO': 'Amanda',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kenneth and Amanda went to the house. Amanda gave a necklace to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Brittany and Paul went to the station. Paul gave a basketball to Brittany',
#   'IO': 'Brittany',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Paul and Brittany went to the station. Brittany gave a basketball to Paul',
#   'IO': 'Paul',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Amanda and James went to the school. James gave a ring to Amanda',
#   'IO': 'Amanda',
#   'S': 'James',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, James and Amanda went to the school. Amanda gave a ring to James',
#   'IO': 'James',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Erica and Bryan went to the office. Bryan gave a computer to Erica',
#   'IO': 'Erica',
#   'S': 'Bryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Bryan and Erica went to the office. Erica gave a computer to Bryan',
#   'IO': 'Bryan',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Matthew and Mark went to the office. Mark gave a computer to Matthew',
#   'IO': 'Matthew',
#   'S': 'Mark',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Mark and Matthew went to the office. Matthew gave a computer to Mark',
#   'IO': 'Mark',
#   'S': 'Matthew',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Christine and Michelle went to the office. Michelle gave a necklace to Christine',
#   'IO': 'Christine',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Michelle and Christine went to the office. Christine gave a necklace to Michelle',
#   'IO': 'Michelle',
#   'S': 'Christine',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Sean and Gregory went to the office. Gregory gave a bone to Sean',
#   'IO': 'Sean',
#   'S': 'Gregory',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Gregory and Sean went to the office. Sean gave a bone to Gregory',
#   'IO': 'Gregory',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Nathan and Nicole went to the store. Nicole gave a ring to Nathan',
#   'IO': 'Nathan',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nicole and Nathan went to the store. Nathan gave a ring to Nicole',
#   'IO': 'Nicole',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Christopher and Mary went to the restaurant. Mary gave a computer to Christopher',
#   'IO': 'Christopher',
#   'S': 'Mary',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Mary and Christopher went to the restaurant. Christopher gave a computer to Mary',
#   'IO': 'Mary',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Bradley and Eric went to the station. Eric gave a necklace to Bradley',
#   'IO': 'Bradley',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Eric and Bradley went to the station. Bradley gave a necklace to Eric',
#   'IO': 'Eric',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Daniel and Scott went to the hospital. Scott gave a snack to Daniel',
#   'IO': 'Daniel',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Scott and Daniel went to the hospital. Daniel gave a snack to Scott',
#   'IO': 'Scott',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Vanessa and Andrea went to the station. Andrea gave a kiss to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Andrea and Vanessa went to the station. Vanessa gave a kiss to Andrea',
#   'IO': 'Andrea',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Scott and Vanessa went to the office. Vanessa gave a necklace to Scott',
#   'IO': 'Scott',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Vanessa and Scott went to the office. Scott gave a necklace to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Timothy and Jennifer went to the office. Jennifer gave a drink to Timothy',
#   'IO': 'Timothy',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jennifer and Timothy went to the office. Timothy gave a drink to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Nicole and Samuel went to the house. Samuel gave a snack to Nicole',
#   'IO': 'Nicole',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Samuel and Nicole went to the house. Nicole gave a snack to Samuel',
#   'IO': 'Samuel',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Michelle and Erica went to the office. Erica gave a basketball to Michelle',
#   'IO': 'Michelle',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Erica and Michelle went to the office. Michelle gave a basketball to Erica',
#   'IO': 'Erica',
#   'S': 'Michelle',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Thomas and Lindsey went to the house. Lindsey gave a kiss to Thomas',
#   'IO': 'Thomas',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Lindsey and Thomas went to the house. Thomas gave a kiss to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Heather and Justin went to the restaurant. Justin gave a kiss to Heather',
#   'IO': 'Heather',
#   'S': 'Justin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Justin and Heather went to the restaurant. Heather gave a kiss to Justin',
#   'IO': 'Justin',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Samuel and Charles went to the office. Charles gave a ring to Samuel',
#   'IO': 'Samuel',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Charles and Samuel went to the office. Samuel gave a ring to Charles',
#   'IO': 'Charles',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Andrea and Erin went to the restaurant. Erin gave a ring to Andrea',
#   'IO': 'Andrea',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Erin and Andrea went to the restaurant. Andrea gave a ring to Erin',
#   'IO': 'Erin',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Paul and Jennifer went to the house. Jennifer gave a ring to Paul',
#   'IO': 'Paul',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jennifer and Paul went to the house. Paul gave a ring to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Paul',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Stephanie and Bradley went to the garden. Bradley gave a ring to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Bradley and Stephanie went to the garden. Stephanie gave a ring to Bradley',
#   'IO': 'Bradley',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Mark and Shannon went to the garden. Shannon gave a necklace to Mark',
#   'IO': 'Mark',
#   'S': 'Shannon',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Shannon and Mark went to the garden. Mark gave a necklace to Shannon',
#   'IO': 'Shannon',
#   'S': 'Mark',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, John and Jacob went to the garden. Jacob gave a drink to John',
#   'IO': 'John',
#   'S': 'Jacob',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jacob and John went to the garden. John gave a drink to Jacob',
#   'IO': 'Jacob',
#   'S': 'John',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Katherine and Cody went to the hospital. Cody gave a bone to Katherine',
#   'IO': 'Katherine',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Cody and Katherine went to the hospital. Katherine gave a bone to Cody',
#   'IO': 'Cody',
#   'S': 'Katherine',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Vanessa and Benjamin went to the station. Benjamin gave a bone to Vanessa',
#   'IO': 'Vanessa',
#   'S': 'Benjamin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Benjamin and Vanessa went to the station. Vanessa gave a bone to Benjamin',
#   'IO': 'Benjamin',
#   'S': 'Vanessa',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Stephen and Angela went to the station. Angela gave a drink to Stephen',
#   'IO': 'Stephen',
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Angela and Stephen went to the station. Stephen gave a drink to Angela',
#   'IO': 'Angela',
#   'S': 'Stephen',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Eric and Patrick went to the office. Patrick gave a basketball to Eric',
#   'IO': 'Eric',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Patrick and Eric went to the office. Eric gave a basketball to Patrick',
#   'IO': 'Patrick',
#   'S': 'Eric',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Scott and Jose went to the station. Jose gave a computer to Scott',
#   'IO': 'Scott',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jose and Scott went to the station. Scott gave a computer to Jose',
#   'IO': 'Jose',
#   'S': 'Scott',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Sara and Steven went to the hospital. Steven gave a snack to Sara',
#   'IO': 'Sara',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Steven and Sara went to the hospital. Sara gave a snack to Steven',
#   'IO': 'Steven',
#   'S': 'Sara',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Kristen and Heather went to the office. Heather gave a ring to Kristen',
#   'IO': 'Kristen',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Heather and Kristen went to the office. Kristen gave a ring to Heather',
#   'IO': 'Heather',
#   'S': 'Kristen',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Samuel and Steven went to the station. Steven gave a necklace to Samuel',
#   'IO': 'Samuel',
#   'S': 'Steven',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Steven and Samuel went to the station. Samuel gave a necklace to Steven',
#   'IO': 'Steven',
#   'S': 'Samuel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Charles and David went to the office. David gave a snack to Charles',
#   'IO': 'Charles',
#   'S': 'David',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, David and Charles went to the office. Charles gave a snack to David',
#   'IO': 'David',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0},
# ...
#   'S': 'Angela',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Angela and John went to the restaurant. John gave a necklace to Angela',
#   'IO': 'Angela',
#   'S': 'John',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Rachel and Nicholas went to the office. Nicholas gave a necklace to Rachel',
#   'IO': 'Rachel',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nicholas and Rachel went to the office. Rachel gave a necklace to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Rachel',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Emily and Crystal went to the hospital. Crystal gave a basketball to Emily',
#   'IO': 'Emily',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Crystal and Emily went to the hospital. Emily gave a basketball to Crystal',
#   'IO': 'Crystal',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Brandon and Emily went to the house. Emily gave a bone to Brandon',
#   'IO': 'Brandon',
#   'S': 'Emily',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Emily and Brandon went to the house. Brandon gave a bone to Emily',
#   'IO': 'Emily',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Aaron and Andrew went to the office. Andrew gave a basketball to Aaron',
#   'IO': 'Aaron',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Andrew and Aaron went to the office. Aaron gave a basketball to Andrew',
#   'IO': 'Andrew',
#   'S': 'Aaron',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Nicole and Erin went to the store. Erin gave a snack to Nicole',
#   'IO': 'Nicole',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Erin and Nicole went to the store. Nicole gave a snack to Erin',
#   'IO': 'Erin',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Erin and Jennifer went to the school. Jennifer gave a basketball to Erin',
#   'IO': 'Erin',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jennifer and Erin went to the school. Erin gave a basketball to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Erin',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Joseph and Ryan went to the house. Ryan gave a drink to Joseph',
#   'IO': 'Joseph',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ryan and Joseph went to the house. Joseph gave a drink to Ryan',
#   'IO': 'Ryan',
#   'S': 'Joseph',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Amber and Lindsay went to the house. Lindsay gave a basketball to Amber',
#   'IO': 'Amber',
#   'S': 'Lindsay',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Lindsay and Amber went to the house. Amber gave a basketball to Lindsay',
#   'IO': 'Lindsay',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Erica and David went to the house. David gave a drink to Erica',
#   'IO': 'Erica',
#   'S': 'David',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, David and Erica went to the house. Erica gave a drink to David',
#   'IO': 'David',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Bradley and Rebecca went to the restaurant. Rebecca gave a drink to Bradley',
#   'IO': 'Bradley',
#   'S': 'Rebecca',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Rebecca and Bradley went to the restaurant. Bradley gave a drink to Rebecca',
#   'IO': 'Rebecca',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jesse and Erica went to the office. Erica gave a basketball to Jesse',
#   'IO': 'Jesse',
#   'S': 'Erica',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Erica and Jesse went to the office. Jesse gave a basketball to Erica',
#   'IO': 'Erica',
#   'S': 'Jesse',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Anthony and Kelly went to the garden. Kelly gave a basketball to Anthony',
#   'IO': 'Anthony',
#   'S': 'Kelly',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Kelly and Anthony went to the garden. Anthony gave a basketball to Kelly',
#   'IO': 'Kelly',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Jeffrey and Nathan went to the garden. Nathan gave a basketball to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Nathan and Jeffrey went to the garden. Jeffrey gave a basketball to Nathan',
#   'IO': 'Nathan',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Timothy and Tiffany went to the garden. Tiffany gave a ring to Timothy',
#   'IO': 'Timothy',
#   'S': 'Tiffany',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Tiffany and Timothy went to the garden. Timothy gave a ring to Tiffany',
#   'IO': 'Tiffany',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jeffrey and Dustin went to the garden. Dustin gave a drink to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Dustin',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Dustin and Jeffrey went to the garden. Jeffrey gave a drink to Dustin',
#   'IO': 'Dustin',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Crystal and Megan went to the house. Megan gave a drink to Crystal',
#   'IO': 'Crystal',
#   'S': 'Megan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Megan and Crystal went to the house. Crystal gave a drink to Megan',
#   'IO': 'Megan',
#   'S': 'Crystal',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Nathan and Christopher went to the garden. Christopher gave a basketball to Nathan',
#   'IO': 'Nathan',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Christopher and Nathan went to the garden. Nathan gave a basketball to Christopher',
#   'IO': 'Christopher',
#   'S': 'Nathan',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Sean and Andrew went to the hospital. Andrew gave a kiss to Sean',
#   'IO': 'Sean',
#   'S': 'Andrew',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Andrew and Sean went to the hospital. Sean gave a kiss to Andrew',
#   'IO': 'Andrew',
#   'S': 'Sean',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jennifer and Alexander went to the house. Alexander gave a ring to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Alexander and Jennifer went to the house. Jennifer gave a ring to Alexander',
#   'IO': 'Alexander',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jennifer and Brandon went to the restaurant. Brandon gave a drink to Jennifer',
#   'IO': 'Jennifer',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brandon and Jennifer went to the restaurant. Jennifer gave a drink to Brandon',
#   'IO': 'Brandon',
#   'S': 'Jennifer',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Heather and Alexander went to the hospital. Alexander gave a drink to Heather',
#   'IO': 'Heather',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Alexander and Heather went to the hospital. Heather gave a drink to Alexander',
#   'IO': 'Alexander',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Lindsey and Jonathan went to the station. Jonathan gave a kiss to Lindsey',
#   'IO': 'Lindsey',
#   'S': 'Jonathan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jonathan and Lindsey went to the station. Lindsey gave a kiss to Jonathan',
#   'IO': 'Jonathan',
#   'S': 'Lindsey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Amy and Richard went to the garden. Richard gave a snack to Amy',
#   'IO': 'Amy',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Richard and Amy went to the garden. Amy gave a snack to Richard',
#   'IO': 'Richard',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jason and Tyler went to the school. Tyler gave a computer to Jason',
#   'IO': 'Jason',
#   'S': 'Tyler',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Tyler and Jason went to the school. Jason gave a computer to Tyler',
#   'IO': 'Tyler',
#   'S': 'Jason',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Heather and Allison went to the house. Allison gave a drink to Heather',
#   'IO': 'Heather',
#   'S': 'Allison',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Allison and Heather went to the house. Heather gave a drink to Allison',
#   'IO': 'Allison',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'basketball',
#   'text': 'Then, Nicole and Ryan went to the station. Ryan gave a basketball to Nicole',
#   'IO': 'Nicole',
#   'S': 'Ryan',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Ryan and Nicole went to the station. Nicole gave a basketball to Ryan',
#   'IO': 'Ryan',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Nicholas and Amanda went to the station. Amanda gave a bone to Nicholas',
#   'IO': 'Nicholas',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Amanda and Nicholas went to the station. Nicholas gave a bone to Amanda',
#   'IO': 'Amanda',
#   'S': 'Nicholas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Jeremy and Jose went to the hospital. Jose gave a snack to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Jose',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jose and Jeremy went to the hospital. Jeremy gave a snack to Jose',
#   'IO': 'Jose',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'store',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Kenneth and Amy went to the store. Amy gave a ring to Kenneth',
#   'IO': 'Kenneth',
#   'S': 'Amy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Amy and Kenneth went to the store. Kenneth gave a ring to Amy',
#   'IO': 'Amy',
#   'S': 'Kenneth',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Amanda and Timothy went to the office. Timothy gave a snack to Amanda',
#   'IO': 'Amanda',
#   'S': 'Timothy',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Timothy and Amanda went to the office. Amanda gave a snack to Timothy',
#   'IO': 'Timothy',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Patrick and Brittany went to the office. Brittany gave a kiss to Patrick',
#   'IO': 'Patrick',
#   'S': 'Brittany',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brittany and Patrick went to the office. Patrick gave a kiss to Brittany',
#   'IO': 'Brittany',
#   'S': 'Patrick',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Bradley and Michael went to the office. Michael gave a bone to Bradley',
#   'IO': 'Bradley',
#   'S': 'Michael',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Michael and Bradley went to the office. Bradley gave a bone to Michael',
#   'IO': 'Michael',
#   'S': 'Bradley',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Nicole and Amber went to the house. Amber gave a ring to Nicole',
#   'IO': 'Nicole',
#   'S': 'Amber',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Amber and Nicole went to the house. Nicole gave a ring to Amber',
#   'IO': 'Amber',
#   'S': 'Nicole',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'garden',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Joshua and Christina went to the garden. Christina gave a computer to Joshua',
#   'IO': 'Joshua',
#   'S': 'Christina',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Christina and Joshua went to the garden. Joshua gave a computer to Christina',
#   'IO': 'Christina',
#   'S': 'Joshua',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Amanda and Anthony went to the hospital. Anthony gave a ring to Amanda',
#   'IO': 'Amanda',
#   'S': 'Anthony',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Anthony and Amanda went to the hospital. Amanda gave a ring to Anthony',
#   'IO': 'Anthony',
#   'S': 'Amanda',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Stephanie and Charles went to the hospital. Charles gave a necklace to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Charles',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Charles and Stephanie went to the hospital. Stephanie gave a necklace to Charles',
#   'IO': 'Charles',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Allison and Jeffrey went to the hospital. Jeffrey gave a drink to Allison',
#   'IO': 'Allison',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Jeffrey and Allison went to the hospital. Allison gave a drink to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Allison',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'computer',
#   'text': 'Then, Jeremy and Heather went to the office. Heather gave a computer to Jeremy',
#   'IO': 'Jeremy',
#   'S': 'Heather',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Heather and Jeremy went to the office. Jeremy gave a computer to Heather',
#   'IO': 'Heather',
#   'S': 'Jeremy',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'station',
#   '[OBJECT]': 'drink',
#   'text': 'Then, Jeffrey and Daniel went to the station. Daniel gave a drink to Jeffrey',
#   'IO': 'Jeffrey',
#   'S': 'Daniel',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Daniel and Jeffrey went to the station. Jeffrey gave a drink to Daniel',
#   'IO': 'Daniel',
#   'S': 'Jeffrey',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Jessica and Stephanie went to the house. Stephanie gave a ring to Jessica',
#   'IO': 'Jessica',
#   'S': 'Stephanie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Stephanie and Jessica went to the house. Jessica gave a ring to Stephanie',
#   'IO': 'Stephanie',
#   'S': 'Jessica',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'restaurant',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Jamie and Brandon went to the restaurant. Brandon gave a kiss to Jamie',
#   'IO': 'Jamie',
#   'S': 'Brandon',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Brandon and Jamie went to the restaurant. Jamie gave a kiss to Brandon',
#   'IO': 'Brandon',
#   'S': 'Jamie',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'snack',
#   'text': 'Then, Alexander and Andrea went to the school. Andrea gave a snack to Alexander',
#   'IO': 'Alexander',
#   'S': 'Andrea',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Andrea and Alexander went to the school. Alexander gave a snack to Andrea',
#   'IO': 'Andrea',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'office',
#   '[OBJECT]': 'necklace',
#   'text': 'Then, Thomas and Richard went to the office. Richard gave a necklace to Thomas',
#   'IO': 'Thomas',
#   'S': 'Richard',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Richard and Thomas went to the office. Thomas gave a necklace to Richard',
#   'IO': 'Richard',
#   'S': 'Thomas',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'hospital',
#   '[OBJECT]': 'ring',
#   'text': 'Then, Adam and Travis went to the hospital. Travis gave a ring to Adam',
#   'IO': 'Adam',
#   'S': 'Travis',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Travis and Adam went to the hospital. Adam gave a ring to Travis',
#   'IO': 'Travis',
#   'S': 'Adam',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'house',
#   '[OBJECT]': 'bone',
#   'text': 'Then, Christopher and Katie went to the house. Katie gave a bone to Christopher',
#   'IO': 'Christopher',
#   'S': 'Katie',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Katie and Christopher went to the house. Christopher gave a bone to Katie',
#   'IO': 'Katie',
#   'S': 'Christopher',
#   'TEMPLATE_IDX': 0},
#  {'[PLACE]': 'school',
#   '[OBJECT]': 'kiss',
#   'text': 'Then, Cody and Alexander went to the school. Alexander gave a kiss to Cody',
#   'IO': 'Cody',
#   'S': 'Alexander',
#   'TEMPLATE_IDX': 0},
#  {'text': 'Then, Alexander and Cody went to the school. Cody gave a kiss to Alexander',
#   'IO': 'Alexander',
#   'S': 'Cody',
#   'TEMPLATE_IDX': 0},
#  ...]
