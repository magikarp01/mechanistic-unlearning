# %% [markdown]
# # Train mask over IOI edges and analyze mask vs known circuit

# %%
# %load_ext autoreload
# %autoreload 2
import os
os.chdir("/data/phillip_guo/circuit-breaking/ioi/")
from models import tokenizer
from data import retrieve_toxic_data, retrieve_owt_data, retrieve_toxic_data_low_loss, retrieve_toxic_filtered_data, FILTER_DEMO_LEN, CONTEXT_LENGTH
from inference import infer_batch_with_owt, infer_batch, prepare_fixed_demo, criterion
from torch.optim import AdamW
import torch
import pickle
import datasets
from tqdm import tqdm_notebook as tqdm
from itertools import cycle
# from eval import evaluate_model
from data import batch_text_to_tokens
import plotly.express as px
# Out:
# Using device: cuda:0

# %%
from weight_masked_transformer import DemoTransformer, Config
def load_demo_gpt2(means, mask_dict_superset=None):
    with open("models/gpt2_weights.pkl", "rb") as f:
        gpt2_weights = pickle.load(f)
    demo_gpt2 = DemoTransformer(Config(debug=False), means, mask_dict_superset=mask_dict_superset)
    demo_gpt2.load_state_dict(gpt2_weights, strict=False)
    demo_gpt2.cuda()
    return demo_gpt2

# %% [markdown]
# ## Train params of mask

# %%
toxic_batch_size = 10 # so that we can just access the last sequence position without worrying about padding
owt_batch_size = 10
context_length = CONTEXT_LENGTH


template_type = "single"
toxic_data_loader = retrieve_toxic_data(toxic_batch_size, context_length, tokenizer, tokenize=False, num_points=None, template_type=template_type)
# toxic_data_loader = retrieve_toxic_filtered_data(toxic_batch_size)
owt_data_loader = retrieve_owt_data(owt_batch_size)

# with open("data/gpt2_means.pkl", "rb") as f:
#     means = pickle.load(f)[0][0]
means_ioi = True
if means_ioi:
    with open("data/gpt2_ioi_abc_means.pkl", "rb") as f:
        means = pickle.load(f)[0]
else:
    with open("data/gpt2_means.pkl", "rb") as f:
        means = pickle.load(f)[0]

model = load_demo_gpt2(means=means)
epochs_left = 200
log_every = 10
lr = .05 # free
weight_decay = 0
clamp_every = 50 # 5 # free
threshold = 0.5
epochs_trained = 0
regularization_strength = 1 # free

mask_params = []
param_names = []
for name, p in model.named_parameters():
    if p.requires_grad:
        param_names.append(name)
        mask_params.append(p)
optimizer = AdamW(mask_params, lr=lr, weight_decay=weight_decay)

losses = []
num_ablated_edges = []
alpha = 0.2 # free
batch_size = toxic_batch_size + owt_batch_size
demos = prepare_fixed_demo(tokenizer, batch_size, demo="")
owt_iter = cycle(owt_data_loader)
edge_threshold = 100
max_steps_per_epoch = 100

# %%
old_mask_params = {}
def duplicate_mask_params(mask_params):
    new_mask_params = []
    for p in mask_params:
        new_mask_params.append(p.data.cpu())
    return new_mask_params

prev_params = None
while epochs_left >= 0:
    for e in tqdm(range(epochs_left)):
        for c, batch in enumerate(toxic_data_loader):
            if c > max_steps_per_epoch:
                break

            # print(batch["text"])
            total_preserving = 0
            ablated_edges = 0
            penalty = 0
            for p in mask_params:
                total_preserving += p.sum()
                ablated_edges += p[p.data < 0.5].shape[0]
                penalty += max(0, p.sum() * (epochs_trained-20) / 10000) # why 2000? free

            # demos = batch[:, :FILTER_DEMO_LEN]
            # completions = batch[:, FILTER_DEMO_LEN:]

            # tox_loss = infer_batch(model, criterion, completions, toxic_batch_size, demos)
            # owt_loss = infer_batch(model, criterion, next(owt_iter)['tokens'], owt_batch_size, fixed_demos)
            tox_loss, owt_loss = infer_batch_with_owt(model, criterion, batch, next(owt_iter), batch_size, demos, access_toxic_pos=-1)
            # print(f"{tox_loss=}, {owt_loss=}")
            loss = -1 * (regularization_strength * penalty + alpha * tox_loss) + owt_loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            losses.append(loss.item())
            num_ablated_edges.append(ablated_edges)
            for p in mask_params:
                p.data.clamp_(0,1)
        print(f"{loss.item()=}, {ablated_edges=}")
        epochs_trained += 1
        if epochs_trained % clamp_every == 0:
            ablated_edges = 0
            for p in mask_params:
                p.data[p.data < threshold] = 0
                p.data[p.data >= threshold] = 1
                ablated_edges += p[p.data < 0.5].shape[0]
        if epochs_trained % log_every == 0:
            print("Epochs trained: ", epochs_trained)
            print(f"Loss: {loss.item():.4f}")
            print(f"Total preserved: {total_preserving:.4f}")
            print("Edges ablated: ", ablated_edges)
            print("Toxic loss: ", tox_loss.item())
            print("OWT loss: ", owt_loss.item())
            print("Penalty: ", penalty)
            # if input('evaluate? (y)') == 'y':
            #     evaluate_model(model, toxic_batches=1, owt_batches=1)
            with torch.no_grad():
                test_ioi_sentences = ["While Alicia and Joshua were commuting to the restaurant, Joshua gave a snack to", "While Joshua and Alicia were commuting to the restaurant, Joshua gave a snack to"]
                for test_ioi_sentence in test_ioi_sentences:
                    correct_token_id = tokenizer.encode(" Alicia", return_tensors="pt").squeeze().item()
                    other_token_id = tokenizer.encode(" Joshua", return_tensors="pt").squeeze().item()
                    test_ioi_tokens = tokenizer.encode(test_ioi_sentence, return_tensors="pt").to('cuda')
                    generation = model(test_ioi_tokens)[0][:, -1]
                    probs = torch.softmax(generation, dim=-1)
                    print(f"Best Token: {tokenizer.batch_decode(torch.argmax(generation, dim=-1))}, P(Alicia) = {probs[:,correct_token_id].item()}, logit diff = {generation[:,correct_token_id].item() - generation[:,other_token_id].item()}")
            print("\n")

            old_mask_params[epochs_trained] = duplicate_mask_params(mask_params)
                
        if epochs_trained > 50 and ablated_edges < edge_threshold:
            break
        prev_params = mask_params
    # epochs_left = int(input('continue training for this number of epochs: '))
    epochs_left = -1
    # log_every = int(input('set log frequency'))
    # edge_threshold = int(input('set edge threshold'))
# Out:
# /tmp/ipykernel_176395/1929431303.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for e in tqdm(range(epochs_left)):
#   0%|          | 0/200 [00:00<?, ?it/s]
# loss.item()=-10.43911361694336, ablated_edges=1277
# loss.item()=-14.101018905639648, ablated_edges=2291
# loss.item()=-15.741912841796875, ablated_edges=2726
# loss.item()=-16.144386291503906, ablated_edges=3038
# loss.item()=-17.014699935913086, ablated_edges=3236
# loss.item()=-17.348852157592773, ablated_edges=3325
# loss.item()=-17.951414108276367, ablated_edges=3421
# loss.item()=-17.839527130126953, ablated_edges=3549
# loss.item()=-18.50194549560547, ablated_edges=3616
# loss.item()=-18.62908172607422, ablated_edges=3663
# Epochs trained:  10
# Loss: -18.6291
# Total preserved: 7561.0815
# Edges ablated:  3663
# Toxic loss:  114.5287094116211
# OWT loss:  4.276660919189453
# Penalty:  0
# Best Token: [' make'], P(Alicia) = 5.7655877753859386e-05, logit diff = -0.381317138671875
# Best Token: [' make'], P(Alicia) = 1.7017458958434872e-05, logit diff = -0.7539596557617188
#
#
# loss.item()=-18.398622512817383, ablated_edges=3712
# loss.item()=-18.490976333618164, ablated_edges=3759
# loss.item()=-18.431020736694336, ablated_edges=3839
# loss.item()=-19.00312042236328, ablated_edges=3928
# loss.item()=-19.13955307006836, ablated_edges=3995
# loss.item()=-18.30130386352539, ablated_edges=4082
# loss.item()=-19.389677047729492, ablated_edges=4154
# loss.item()=-19.250457763671875, ablated_edges=4198
# loss.item()=-19.156965255737305, ablated_edges=4235
# loss.item()=-19.512489318847656, ablated_edges=4281
# Epochs trained:  20
# Loss: -19.5125
# Total preserved: 7058.1777
# Edges ablated:  4281
# Toxic loss:  118.88633728027344
# OWT loss:  4.264777660369873
# Penalty:  0
# Best Token: [' make'], P(Alicia) = 1.9285093912913e-06, logit diff = 3.0665435791015625
# Best Token: [' make'], P(Alicia) = 1.6750204778759326e-08, logit diff = -7.155063629150391
#
#
# loss.item()=-19.50063705444336, ablated_edges=4325
# loss.item()=-20.229976654052734, ablated_edges=4280
# loss.item()=-20.92717170715332, ablated_edges=4053
# loss.item()=-21.88352394104004, ablated_edges=3750
# loss.item()=-22.8228759765625, ablated_edges=3386
# loss.item()=-22.886144638061523, ablated_edges=3100
# loss.item()=-24.594104766845703, ablated_edges=2904
# loss.item()=-25.92047691345215, ablated_edges=2616
# loss.item()=-23.342529296875, ablated_edges=2370
# loss.item()=-27.136762619018555, ablated_edges=2355
# Epochs trained:  30
# Loss: -27.1368
# Total preserved: 9025.6436
# Edges ablated:  2355
# Toxic loss:  117.23563385009766
# OWT loss:  4.433443069458008
# Penalty:  tensor(8.1231, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' make'], P(Alicia) = 8.626674571132753e-06, logit diff = 4.4121246337890625
# Best Token: [' make'], P(Alicia) = 1.2128113667131402e-05, logit diff = 0.5792350769042969
#
#
# loss.item()=-28.771926879882812, ablated_edges=2094
# loss.item()=-30.000322341918945, ablated_edges=1877
# loss.item()=-30.913686752319336, ablated_edges=1698
# loss.item()=-25.162368774414062, ablated_edges=1599
# loss.item()=-30.10703468322754, ablated_edges=2046
# loss.item()=-32.8121452331543, ablated_edges=1805
# loss.item()=-34.357627868652344, ablated_edges=1543
# loss.item()=-36.05180358886719, ablated_edges=1393
# loss.item()=-37.070709228515625, ablated_edges=1252
# loss.item()=-38.13800048828125, ablated_edges=1138
# Epochs trained:  40
# Loss: -38.1380
# Total preserved: 10267.5664
# Edges ablated:  1138
# Toxic loss:  114.73640441894531
# OWT loss:  4.3176589012146
# Penalty:  tensor(19.5084, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.21465758979320526, logit diff = 4.715904235839844
# Best Token: [' make'], P(Alicia) = 0.003675549291074276, logit diff = -1.0879287719726562
#
#
# loss.item()=-39.47089767456055, ablated_edges=1085
# loss.item()=-40.42157745361328, ablated_edges=1021
# loss.item()=-41.981204986572266, ablated_edges=980
# loss.item()=-42.92626190185547, ablated_edges=933
# loss.item()=-44.29749298095703, ablated_edges=905
# loss.item()=-45.01182556152344, ablated_edges=894
# loss.item()=-46.312679290771484, ablated_edges=849
# loss.item()=-47.53153610229492, ablated_edges=812
# loss.item()=-42.46607971191406, ablated_edges=965
# loss.item()=-46.149078369140625, ablated_edges=1218
# Epochs trained:  50
# Loss: -46.1491
# Total preserved: 10201.8760
# Edges ablated:  1213
# Toxic loss:  106.1601791381836
# OWT loss:  4.668397903442383
# Penalty:  tensor(29.5854, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' be'], P(Alicia) = 2.4578710178246865e-09, logit diff = -3.0911026000976562
# Best Token: [' be'], P(Alicia) = 4.19996437628356e-09, logit diff = -2.429981231689453
#
#
# loss.item()=-46.558128356933594, ablated_edges=1328
# loss.item()=-49.64617919921875, ablated_edges=1136
# loss.item()=-51.702816009521484, ablated_edges=938
# loss.item()=-53.32933044433594, ablated_edges=813
# loss.item()=-54.79868698120117, ablated_edges=722
# loss.item()=-55.83039474487305, ablated_edges=683
# loss.item()=-56.93011474609375, ablated_edges=631
# loss.item()=-58.660072326660156, ablated_edges=611
# loss.item()=-59.29399108886719, ablated_edges=579
# loss.item()=-60.42868423461914, ablated_edges=560
# Epochs trained:  60
# Loss: -60.4287
# Total preserved: 10917.7393
# Edges ablated:  560
# Toxic loss:  111.15705871582031
# OWT loss:  4.381906986236572
# Penalty:  tensor(42.5792, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.6209215521812439, logit diff = 2.6091766357421875
# Best Token: [' Joshua'], P(Alicia) = 0.04699796438217163, logit diff = -2.3830413818359375
#
#
# loss.item()=-62.08411407470703, ablated_edges=550
# loss.item()=-62.91202163696289, ablated_edges=531
# loss.item()=-63.96849822998047, ablated_edges=517
# loss.item()=-65.69673156738281, ablated_edges=501
# loss.item()=-66.98817443847656, ablated_edges=485
# loss.item()=-66.58914184570312, ablated_edges=546
# loss.item()=-68.34228515625, ablated_edges=520
# loss.item()=-69.70266723632812, ablated_edges=477
# loss.item()=-70.81651306152344, ablated_edges=473
# loss.item()=-71.2223892211914, ablated_edges=462
# Epochs trained:  70
# Loss: -71.2224
# Total preserved: 11026.2939
# Edges ablated:  462
# Toxic loss:  107.337158203125
# OWT loss:  4.273886203765869
# Penalty:  tensor(54.0288, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' her'], P(Alicia) = 0.08044551312923431, logit diff = 0.8730316162109375
# Best Token: [' the'], P(Alicia) = 0.12342806160449982, logit diff = 0.3984184265136719
#
#
# loss.item()=-73.16309356689453, ablated_edges=484
# loss.item()=-74.30897521972656, ablated_edges=459
# loss.item()=-75.54541778564453, ablated_edges=445
# loss.item()=-76.34232330322266, ablated_edges=433
# loss.item()=-77.57870483398438, ablated_edges=426
# loss.item()=-78.96788024902344, ablated_edges=414
# loss.item()=-74.79219818115234, ablated_edges=643
# loss.item()=-79.01317596435547, ablated_edges=570
# loss.item()=-81.99421691894531, ablated_edges=482
# loss.item()=-83.07486724853516, ablated_edges=432
# Epochs trained:  80
# Loss: -83.0749
# Total preserved: 11075.5273
# Edges ablated:  432
# Toxic loss:  110.05529022216797
# OWT loss:  4.281793117523193
# Penalty:  tensor(65.3456, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.44059064984321594, logit diff = 2.6200637817382812
# Best Token: [' the'], P(Alicia) = 0.08356641978025436, logit diff = 0.15734481811523438
#
#
# loss.item()=-84.45991516113281, ablated_edges=400
# loss.item()=-85.76603698730469, ablated_edges=383
# loss.item()=-84.11701202392578, ablated_edges=384
# loss.item()=-87.69469451904297, ablated_edges=418
# loss.item()=-89.14637756347656, ablated_edges=384
# loss.item()=-90.14088439941406, ablated_edges=358
# loss.item()=-91.28488159179688, ablated_edges=361
# loss.item()=-91.69306945800781, ablated_edges=353
# loss.item()=-93.7253646850586, ablated_edges=355
# loss.item()=-93.97825622558594, ablated_edges=358
# Epochs trained:  90
# Loss: -93.9783
# Total preserved: 11155.1328
# Edges ablated:  358
# Toxic loss:  107.3816909790039
# OWT loss:  4.468498229980469
# Penalty:  tensor(76.9704, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.3484005033969879, logit diff = 2.8673095703125
# Best Token: [' Joshua'], P(Alicia) = 0.13392125070095062, logit diff = -0.8197746276855469
#
#
# loss.item()=-96.24923706054688, ablated_edges=360
# loss.item()=-96.98969268798828, ablated_edges=352
# loss.item()=-98.30036163330078, ablated_edges=355
# loss.item()=-99.79169464111328, ablated_edges=345
# loss.item()=-100.3827133178711, ablated_edges=346
# loss.item()=-101.85686492919922, ablated_edges=338
# loss.item()=-102.448974609375, ablated_edges=344
# loss.item()=-103.99991607666016, ablated_edges=349
# loss.item()=-105.01061248779297, ablated_edges=339
# loss.item()=-106.27445220947266, ablated_edges=336
# Epochs trained:  100
# Loss: -106.2745
# Total preserved: 11185.1543
# Edges ablated:  335
# Toxic loss:  110.89505767822266
# OWT loss:  4.267279624938965
# Penalty:  tensor(88.3627, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.9759790301322937, logit diff = 4.105045318603516
# Best Token: [' Joshua'], P(Alicia) = 0.3254367411136627, logit diff = -0.6395988464355469
#
#
# loss.item()=-102.03355407714844, ablated_edges=454
# loss.item()=-107.86021423339844, ablated_edges=450
# loss.item()=-109.38754272460938, ablated_edges=410
# loss.item()=-111.92166137695312, ablated_edges=388
# loss.item()=-113.6866226196289, ablated_edges=386
# loss.item()=-115.2632064819336, ablated_edges=359
# loss.item()=-117.51727294921875, ablated_edges=350
# loss.item()=-118.53333282470703, ablated_edges=344
# loss.item()=-119.89543914794922, ablated_edges=325
# loss.item()=-120.54873657226562, ablated_edges=350
# Epochs trained:  110
# Loss: -120.5487
# Total preserved: 11165.3604
# Edges ablated:  350
# Toxic loss:  128.56419372558594
# OWT loss:  4.535819053649902
# Penalty:  tensor(99.3717, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' her'], P(Alicia) = 0.001555894035845995, logit diff = 2.6212730407714844
# Best Token: [' the'], P(Alicia) = 0.0018953363178297877, logit diff = 1.8548049926757812
#
#
# loss.item()=-122.21484375, ablated_edges=327
# loss.item()=-123.44478607177734, ablated_edges=320
# loss.item()=-124.01499938964844, ablated_edges=335
# loss.item()=-126.06985473632812, ablated_edges=311
# loss.item()=-126.61161041259766, ablated_edges=309
# loss.item()=-127.51283264160156, ablated_edges=303
# loss.item()=-128.38743591308594, ablated_edges=308
# loss.item()=-130.51223754882812, ablated_edges=303
# loss.item()=-130.9752960205078, ablated_edges=313
# loss.item()=-132.90916442871094, ablated_edges=299
# Epochs trained:  120
# Loss: -132.9092
# Total preserved: 11221.0732
# Edges ablated:  299
# Toxic loss:  130.6710205078125
# OWT loss:  4.313650608062744
# Penalty:  tensor(111.0886, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' her'], P(Alicia) = 0.1099543571472168, logit diff = 3.54840087890625
# Best Token: [' the'], P(Alicia) = 0.05706431716680527, logit diff = 0.5628395080566406
#
#
# loss.item()=-134.19931030273438, ablated_edges=297
# loss.item()=-134.49337768554688, ablated_edges=307
# loss.item()=-136.313720703125, ablated_edges=299
# loss.item()=-137.29324340820312, ablated_edges=299
# loss.item()=-137.77536010742188, ablated_edges=310
# loss.item()=-139.75527954101562, ablated_edges=301
# loss.item()=-140.8194122314453, ablated_edges=297
# loss.item()=-142.21429443359375, ablated_edges=295
# loss.item()=-143.28594970703125, ablated_edges=291
# loss.item()=-144.2927703857422, ablated_edges=293
# Epochs trained:  130
# Loss: -144.2928
# Total preserved: 11235.8672
# Edges ablated:  293
# Toxic loss:  131.6256561279297
# OWT loss:  4.503300666809082
# Penalty:  tensor(122.4709, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' Alicia'], P(Alicia) = 0.34382468461990356, logit diff = 3.3055267333984375
# Best Token: [' Joshua'], P(Alicia) = 0.014654610306024551, logit diff = -3.8411712646484375
#
#
# loss.item()=-144.48973083496094, ablated_edges=290
# loss.item()=-146.1677703857422, ablated_edges=315
# loss.item()=-147.85079956054688, ablated_edges=298
# loss.item()=-149.2473907470703, ablated_edges=293
# loss.item()=-150.24037170410156, ablated_edges=297
# loss.item()=-150.8931884765625, ablated_edges=296
# loss.item()=-152.50173950195312, ablated_edges=291
# loss.item()=-153.60101318359375, ablated_edges=290
# loss.item()=-155.05386352539062, ablated_edges=285
# loss.item()=-155.7353515625, ablated_edges=287
# Epochs trained:  140
# Loss: -155.7354
# Total preserved: 11255.3506
# Edges ablated:  287
# Toxic loss:  131.28610229492188
# OWT loss:  4.460533618927002
# Penalty:  tensor(133.9387, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 0.217549130320549, logit diff = 1.7796249389648438
# Best Token: [' Joshua'], P(Alicia) = 0.005122085567563772, logit diff = -4.820556640625
#
#
# loss.item()=-156.99755859375, ablated_edges=288
# loss.item()=-158.0867156982422, ablated_edges=285
# loss.item()=-159.4881591796875, ablated_edges=285
# loss.item()=-160.24884033203125, ablated_edges=276
# loss.item()=-161.1578369140625, ablated_edges=282
# loss.item()=-162.7354736328125, ablated_edges=279
# loss.item()=-164.05007934570312, ablated_edges=276
# loss.item()=-164.7161102294922, ablated_edges=279
# loss.item()=-166.15428161621094, ablated_edges=280
# loss.item()=-167.05419921875, ablated_edges=278
# Epochs trained:  150
# Loss: -167.0542
# Total preserved: 11269.7607
# Edges ablated:  279
# Toxic loss:  131.9045867919922
# OWT loss:  4.706644535064697
# Penalty:  tensor(145.3799, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 4.402767081046477e-05, logit diff = -1.4443016052246094
# Best Token: [' the'], P(Alicia) = 1.5731327948742546e-05, logit diff = -2.1846885681152344
#
#
# loss.item()=-156.05801391601562, ablated_edges=285
# loss.item()=-162.6443328857422, ablated_edges=292
# loss.item()=-165.55043029785156, ablated_edges=279
# loss.item()=-165.82052612304688, ablated_edges=257
# loss.item()=-167.038818359375, ablated_edges=316
# loss.item()=-170.34544372558594, ablated_edges=273
# loss.item()=-171.99822998046875, ablated_edges=258
# loss.item()=-173.33168029785156, ablated_edges=258
# loss.item()=-174.8601837158203, ablated_edges=245
# loss.item()=-176.00392150878906, ablated_edges=242
# Epochs trained:  160
# Loss: -176.0039
# Total preserved: 11288.5439
# Edges ablated:  242
# Toxic loss:  118.52904510498047
# OWT loss:  4.6126389503479
# Penalty:  tensor(156.9108, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' eat'], P(Alicia) = 1.58308366415838e-10, logit diff = -2.616497039794922
# Best Token: [' eat'], P(Alicia) = 8.236247101001126e-11, logit diff = -4.510181427001953
#
#
# loss.item()=-177.36106872558594, ablated_edges=223
# loss.item()=-178.44781494140625, ablated_edges=215
# loss.item()=-179.6891326904297, ablated_edges=216
# loss.item()=-179.0811004638672, ablated_edges=228
# loss.item()=-181.72581481933594, ablated_edges=228
# loss.item()=-183.16160583496094, ablated_edges=209
# loss.item()=-184.35699462890625, ablated_edges=215
# loss.item()=-185.14688110351562, ablated_edges=216
# loss.item()=-186.78672790527344, ablated_edges=219
# loss.item()=-187.66903686523438, ablated_edges=218
# Epochs trained:  170
# Loss: -187.6690
# Total preserved: 11322.1582
# Edges ablated:  218
# Toxic loss:  118.90465545654297
# OWT loss:  4.812045097351074
# Penalty:  tensor(168.7001, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' eat'], P(Alicia) = 1.3899333680456039e-05, logit diff = -4.0971832275390625
# Best Token: [' eat'], P(Alicia) = 1.7871743693831377e-05, logit diff = -4.012290954589844
#
#
# loss.item()=-189.3814697265625, ablated_edges=217
# loss.item()=-190.25808715820312, ablated_edges=229
# loss.item()=-191.07196044921875, ablated_edges=214
# loss.item()=-192.6087188720703, ablated_edges=217
# loss.item()=-192.420654296875, ablated_edges=216
# loss.item()=-194.93104553222656, ablated_edges=221
# loss.item()=-196.1099090576172, ablated_edges=216
# loss.item()=-196.87631225585938, ablated_edges=209
# loss.item()=-198.57229614257812, ablated_edges=212
# loss.item()=-197.87960815429688, ablated_edges=218
# Epochs trained:  180
# Loss: -197.8796
# Total preserved: 11321.0283
# Edges ablated:  218
# Toxic loss:  113.92915344238281
# OWT loss:  4.910554885864258
# Penalty:  tensor(180.0043, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' eat'], P(Alicia) = 7.885488884085134e-08, logit diff = -4.274177551269531
# Best Token: [' eat'], P(Alicia) = 5.631121879901002e-08, logit diff = -4.4898681640625
#
#
# loss.item()=-200.65625, ablated_edges=216
# loss.item()=-200.5044708251953, ablated_edges=210
# loss.item()=-202.6736297607422, ablated_edges=213
# loss.item()=-203.9647216796875, ablated_edges=207
# loss.item()=-204.72769165039062, ablated_edges=212
# loss.item()=-206.0562744140625, ablated_edges=209
# loss.item()=-207.37881469726562, ablated_edges=207
# loss.item()=-208.7313690185547, ablated_edges=200
# loss.item()=-209.65260314941406, ablated_edges=217
# loss.item()=-210.8632354736328, ablated_edges=206
# Epochs trained:  190
# Loss: -210.8632
# Total preserved: 11336.5664
# Edges ablated:  206
# Toxic loss:  119.23880767822266
# OWT loss:  4.572513103485107
# Penalty:  tensor(191.5880, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' eat'], P(Alicia) = 6.009631761116907e-06, logit diff = -3.7057723999023438
# Best Token: [' eat'], P(Alicia) = 7.218662858576863e-07, logit diff = -4.240058898925781
#
#
# loss.item()=-211.8028106689453, ablated_edges=206
# loss.item()=-210.44790649414062, ablated_edges=224
# loss.item()=-214.18325805664062, ablated_edges=210
# loss.item()=-215.36135864257812, ablated_edges=203
# loss.item()=-215.89566040039062, ablated_edges=199
# loss.item()=-217.88609313964844, ablated_edges=199
# loss.item()=-216.90621948242188, ablated_edges=190
# loss.item()=-215.09463500976562, ablated_edges=266
# loss.item()=-218.99623107910156, ablated_edges=234
# loss.item()=-221.55494689941406, ablated_edges=207
# Epochs trained:  200
# Loss: -221.5549
# Total preserved: 11321.0586
# Edges ablated:  208
# Toxic loss:  117.34549713134766
# OWT loss:  4.561111927032471
# Penalty:  tensor(202.6470, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' eat'], P(Alicia) = 0.0002222295879619196, logit diff = -2.959686279296875
# Best Token: [' him'], P(Alicia) = 0.00015407733735628426, logit diff = -2.4977645874023438

# %%
with open(f"models/params_dict_lambda={regularization_strength}_{alpha=}_{means_ioi=}_{template_type=}.pkl", "wb") as f:
    pickle.dump(old_mask_params, f)

# %% [markdown]
# ## Try circuit breaking over IOI-specific edges

# %%
from mask_utils import get_nodes_and_edges
with open("models/circuit_covering_mask_params.pkl", "rb") as f:
    circuit_covering_mask_params = pickle.load(f)

_, _, circuit_covering_edges, circuit_covering_mask_dict = get_nodes_and_edges(mask_params=circuit_covering_mask_params)
# circuit_covering_mask_dict # mostly 1s, 1s are frozen edges
# Circuit break only over the edges that are currently 0s in the circuit covering mask, ablate as few of them as possible

# %%
toxic_batch_size = 10 # so that we can just access the last sequence position without worrying about padding
owt_batch_size = 10
context_length = CONTEXT_LENGTH

template_type = "single"
toxic_data_loader = retrieve_toxic_data(toxic_batch_size, context_length, tokenizer, tokenize=False, num_points=None, template_type=template_type)
# toxic_data_loader = retrieve_toxic_filtered_data(toxic_batch_size)
owt_data_loader = retrieve_owt_data(owt_batch_size)

with open("data/gpt2_means.pkl", "rb") as f:
    means = pickle.load(f)[0]

model = load_demo_gpt2(means=means, mask_dict_superset=circuit_covering_mask_dict)
epochs_left = 200
log_every = 10
lr = .05 # free
weight_decay = 0
clamp_every = 50 # 5 # free
threshold = 0.5
epochs_trained = 0
regularization_strength = 1 # free

mask_params = []
param_names = []
for name, p in model.named_parameters():
    if p.requires_grad:
        param_names.append(name)
        mask_params.append(p)
optimizer = AdamW(mask_params, lr=lr, weight_decay=weight_decay)

losses = []
num_ablated_edges = []
alpha = 0.2 # free
batch_size = toxic_batch_size + owt_batch_size
demos = prepare_fixed_demo(tokenizer, batch_size, demo="")
owt_iter = cycle(owt_data_loader)
edge_threshold = 0 
max_steps_per_epoch = 50

# %%
old_mask_params = {}
def duplicate_mask_params(mask_params):
    new_mask_params = []
    for p in mask_params:
        new_mask_params.append(p.data.cpu())
    return new_mask_params

prev_params = None
while epochs_left >= 0:
    for e in tqdm(range(epochs_left)):
        for c, batch in enumerate(toxic_data_loader):
            if c > max_steps_per_epoch:
                break

            # print(batch["text"])
            total_preserving = 0
            ablated_edges = 0
            penalty = 0
            for p in mask_params:
                total_preserving += p.sum()
                ablated_edges += p[p.data < 0.5].shape[0]
                penalty += max(0, p.sum() * (epochs_trained-20) / 10000) # why 2000? free

            # demos = batch[:, :FILTER_DEMO_LEN]
            # completions = batch[:, FILTER_DEMO_LEN:]

            # tox_loss = infer_batch(model, criterion, completions, toxic_batch_size, demos)
            # owt_loss = infer_batch(model, criterion, next(owt_iter)['tokens'], owt_batch_size, fixed_demos)
            tox_loss, owt_loss = infer_batch_with_owt(model, criterion, batch, next(owt_iter), batch_size, demos, access_toxic_pos=-1)
            # print(f"{tox_loss=}, {owt_loss=}")
            loss = -1 * (regularization_strength * penalty + alpha * tox_loss) + owt_loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            losses.append(loss.item())
            num_ablated_edges.append(ablated_edges)
            for p in mask_params:
                p.data.clamp_(0,1)
        print(f"{loss.item()=}, {ablated_edges=}")
        epochs_trained += 1
        if epochs_trained % clamp_every == 0:
            ablated_edges = 0
            for p in mask_params:
                p.data[p.data < threshold] = 0
                p.data[p.data >= threshold] = 1
                ablated_edges += p[p.data < 0.5].shape[0]
        if epochs_trained % log_every == 0:
            print("Epochs trained: ", epochs_trained)
            print(f"Loss: {loss.item():.4f}")
            print(f"Total preserved: {total_preserving:.4f}")
            print("Edges ablated: ", ablated_edges)
            print("Toxic loss: ", tox_loss.item())
            print("OWT loss: ", owt_loss.item())
            print("Penalty: ", penalty)
            # if input('evaluate? (y)') == 'y':
            #     evaluate_model(model, toxic_batches=1, owt_batches=1)
            with torch.no_grad():
                test_ioi_sentences = ["While Alicia and Joshua were commuting to the restaurant, Joshua gave a snack to", "While Joshua and Alicia were commuting to the restaurant, Joshua gave a snack to"]
                for test_ioi_sentence in test_ioi_sentences:
                    correct_token_id = tokenizer.encode(" Alicia", return_tensors="pt").squeeze().item()
                    other_token_id = tokenizer.encode(" Joshua", return_tensors="pt").squeeze().item()
                    test_ioi_tokens = tokenizer.encode(test_ioi_sentence, return_tensors="pt").to('cuda')
                    generation = model(test_ioi_tokens)[0][:, -1]
                    probs = torch.softmax(generation, dim=-1)
                    print(f"Best Token: {tokenizer.batch_decode(torch.argmax(generation, dim=-1))}, P(Alicia) = {probs[:,correct_token_id].item()}, logit diff = {generation[:,correct_token_id].item() - generation[:,other_token_id].item()}")
            print("\n")

            old_mask_params[epochs_trained] = duplicate_mask_params(mask_params)
                
        if epochs_trained > 50 and ablated_edges < edge_threshold:
            break
        prev_params = mask_params
    # epochs_left = int(input('continue training for this number of epochs: '))
    epochs_left = -1
    # log_every = int(input('set log frequency'))
    # edge_threshold = int(input('set edge threshold'))
# Out:
# /tmp/ipykernel_240270/1929431303.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for e in tqdm(range(epochs_left)):
#   0%|          | 0/200 [00:00<?, ?it/s]
# loss.item()=1.5367424488067627, ablated_edges=182
# loss.item()=1.2619993686676025, ablated_edges=185
# loss.item()=1.2599594593048096, ablated_edges=181
# loss.item()=1.3758959770202637, ablated_edges=178
# loss.item()=2.59861421585083, ablated_edges=176
# loss.item()=1.2927062511444092, ablated_edges=174
# loss.item()=2.2666947841644287, ablated_edges=174
# loss.item()=1.613863468170166, ablated_edges=175
# loss.item()=1.552971601486206, ablated_edges=172
# loss.item()=1.3392136096954346, ablated_edges=174
# Epochs trained:  10
# Loss: 1.3392
# Total preserved: 11434.6025
# Edges ablated:  174
# Toxic loss:  12.350775718688965
# OWT loss:  3.809368848800659
# Penalty:  0
# Best Token: [' the'], P(Alicia) = 6.447839382417442e-07, logit diff = -4.6201324462890625
# Best Token: [' the'], P(Alicia) = 6.147521958155266e-07, logit diff = -3.2760467529296875
#
#
# loss.item()=1.8121588230133057, ablated_edges=174
# loss.item()=2.0960686206817627, ablated_edges=175
# loss.item()=1.0074710845947266, ablated_edges=172
# loss.item()=1.985715627670288, ablated_edges=175
# loss.item()=2.3218538761138916, ablated_edges=175
# loss.item()=0.8389346599578857, ablated_edges=176
# loss.item()=1.17350172996521, ablated_edges=177
# loss.item()=1.4434564113616943, ablated_edges=178
# loss.item()=1.1889371871948242, ablated_edges=175
# loss.item()=1.8444175720214844, ablated_edges=173
# Epochs trained:  20
# Loss: 1.8444
# Total preserved: 11433.4053
# Edges ablated:  173
# Toxic loss:  12.273588180541992
# OWT loss:  4.299135208129883
# Penalty:  0
# Best Token: [' the'], P(Alicia) = 6.891082762194856e-07, logit diff = -4.499732971191406
# Best Token: [' the'], P(Alicia) = 5.715113502446911e-07, logit diff = -3.3913040161132812
#
#
# loss.item()=2.1504287719726562, ablated_edges=173
# loss.item()=0.4383268356323242, ablated_edges=172
# loss.item()=-0.9403500556945801, ablated_edges=166
# loss.item()=-1.892807960510254, ablated_edges=159
# loss.item()=-2.8604211807250977, ablated_edges=155
# loss.item()=-4.659048080444336, ablated_edges=154
# loss.item()=-5.550614356994629, ablated_edges=146
# loss.item()=-6.2468132972717285, ablated_edges=141
# loss.item()=-7.342950820922852, ablated_edges=130
# loss.item()=-8.9207181930542, ablated_edges=132
# Epochs trained:  30
# Loss: -8.9207
# Total preserved: 11479.6553
# Edges ablated:  132
# Toxic loss:  13.237716674804688
# OWT loss:  4.058514595031738
# Penalty:  tensor(10.3317, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 7.351677595579531e-07, logit diff = -4.469657897949219
# Best Token: [' the'], P(Alicia) = 6.777901262466912e-07, logit diff = -3.1939697265625
#
#
# loss.item()=-9.383305549621582, ablated_edges=126
# loss.item()=-11.090410232543945, ablated_edges=123
# loss.item()=-12.401179313659668, ablated_edges=121
# loss.item()=-13.417054176330566, ablated_edges=118
# loss.item()=-14.825174331665039, ablated_edges=115
# loss.item()=-14.692070007324219, ablated_edges=112
# loss.item()=-16.846235275268555, ablated_edges=111
# loss.item()=-18.220996856689453, ablated_edges=108
# loss.item()=-19.056373596191406, ablated_edges=106
# loss.item()=-20.99625015258789, ablated_edges=104
# Epochs trained:  40
# Loss: -20.9963
# Total preserved: 11507.4863
# Edges ablated:  104
# Toxic loss:  12.447504043579102
# OWT loss:  3.3574724197387695
# Penalty:  tensor(21.8642, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 1.0074036254081875e-06, logit diff = -4.1859130859375
# Best Token: [' the'], P(Alicia) = 8.8428663502782e-07, logit diff = -2.90911865234375
#
#
# loss.item()=-21.332643508911133, ablated_edges=102
# loss.item()=-22.634166717529297, ablated_edges=101
# loss.item()=-23.87643051147461, ablated_edges=102
# loss.item()=-24.788795471191406, ablated_edges=100
# loss.item()=-25.446664810180664, ablated_edges=102
# loss.item()=-27.60162353515625, ablated_edges=98
# loss.item()=-28.51734161376953, ablated_edges=97
# loss.item()=-29.356998443603516, ablated_edges=97
# loss.item()=-30.43706703186035, ablated_edges=95
# loss.item()=-31.724010467529297, ablated_edges=90
# Epochs trained:  50
# Loss: -31.7240
# Total preserved: 11519.7793
# Edges ablated:  90
# Toxic loss:  12.047073364257812
# OWT loss:  4.092766284942627
# Penalty:  tensor(33.4074, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 1.4016247860126896e-06, logit diff = -4.05218505859375
# Best Token: [' the'], P(Alicia) = 1.2889843219454633e-06, logit diff = -2.5432357788085938
#
#
# loss.item()=-32.84813690185547, ablated_edges=89
# loss.item()=-34.07821273803711, ablated_edges=86
# loss.item()=-35.20469284057617, ablated_edges=83
# loss.item()=-36.98383331298828, ablated_edges=78
# loss.item()=-36.63981628417969, ablated_edges=77
# loss.item()=-38.40050506591797, ablated_edges=73
# loss.item()=-40.14759826660156, ablated_edges=71
# loss.item()=-39.09939193725586, ablated_edges=71
# loss.item()=-42.260990142822266, ablated_edges=70
# loss.item()=-43.6458854675293, ablated_edges=66
# Epochs trained:  60
# Loss: -43.6459
# Total preserved: 11545.2920
# Edges ablated:  66
# Toxic loss:  11.807247161865234
# OWT loss:  3.7422029972076416
# Penalty:  tensor(45.0266, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' them'], P(Alicia) = 1.4809967296969262e-06, logit diff = -4.1462860107421875
# Best Token: [' the'], P(Alicia) = 1.5505308965657605e-06, logit diff = -2.8220977783203125
#
#
# loss.item()=-44.564395904541016, ablated_edges=67
# loss.item()=-45.84644317626953, ablated_edges=65
# loss.item()=-46.51844024658203, ablated_edges=63
# loss.item()=-47.74746322631836, ablated_edges=62
# loss.item()=-49.49787902832031, ablated_edges=60
# loss.item()=-50.093963623046875, ablated_edges=57
# loss.item()=-51.48754119873047, ablated_edges=57
# loss.item()=-52.714420318603516, ablated_edges=56
# loss.item()=-53.667449951171875, ablated_edges=53
# loss.item()=-54.999420166015625, ablated_edges=52
# Epochs trained:  70
# Loss: -54.9994
# Total preserved: 11559.3994
# Edges ablated:  52
# Toxic loss:  12.55378532409668
# OWT loss:  4.1523942947387695
# Penalty:  tensor(56.6411, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' them'], P(Alicia) = 1.8113605619873852e-06, logit diff = -3.9824371337890625
# Best Token: [' the'], P(Alicia) = 1.7175171933558886e-06, logit diff = -2.8585739135742188
#
#
# loss.item()=-55.645118713378906, ablated_edges=50
# loss.item()=-57.46319580078125, ablated_edges=50
# loss.item()=-58.40773010253906, ablated_edges=51
# loss.item()=-59.6435661315918, ablated_edges=47
# loss.item()=-60.804664611816406, ablated_edges=48
# loss.item()=-61.096527099609375, ablated_edges=48
# loss.item()=-62.73634338378906, ablated_edges=45
# loss.item()=-64.1303939819336, ablated_edges=44
# loss.item()=-64.51573181152344, ablated_edges=44
# loss.item()=-66.3364028930664, ablated_edges=41
# Epochs trained:  80
# Loss: -66.3364
# Total preserved: 11568.4316
# Edges ablated:  41
# Toxic loss:  11.494344711303711
# OWT loss:  4.216207504272461
# Penalty:  tensor(68.2537, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' them'], P(Alicia) = 1.8504020999898785e-06, logit diff = -3.9539413452148438
# Best Token: [' the'], P(Alicia) = 1.9640929167508148e-06, logit diff = -2.9145889282226562
#
#
# loss.item()=-67.93811798095703, ablated_edges=41
# loss.item()=-68.72235107421875, ablated_edges=42
# loss.item()=-70.51973724365234, ablated_edges=41
# loss.item()=-71.44669342041016, ablated_edges=42
# loss.item()=-72.28714752197266, ablated_edges=40
# loss.item()=-73.22037506103516, ablated_edges=42
# loss.item()=-74.61117553710938, ablated_edges=40
# loss.item()=-75.0332260131836, ablated_edges=39
# loss.item()=-76.5303726196289, ablated_edges=39
# loss.item()=-77.72875213623047, ablated_edges=38
# Epochs trained:  90
# Loss: -77.7288
# Total preserved: 11573.3291
# Edges ablated:  38
# Toxic loss:  11.956944465637207
# OWT loss:  4.518609046936035
# Penalty:  tensor(79.8560, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 2.436036311337375e-06, logit diff = -3.8441925048828125
# Best Token: [' the'], P(Alicia) = 2.15177556128765e-06, logit diff = -2.9417495727539062
#
#
# loss.item()=-78.84445190429688, ablated_edges=39
# loss.item()=-80.50643157958984, ablated_edges=37
# loss.item()=-81.45945739746094, ablated_edges=37
# loss.item()=-82.48026275634766, ablated_edges=35
# loss.item()=-83.37468719482422, ablated_edges=35
# loss.item()=-84.33324432373047, ablated_edges=33
# loss.item()=-86.35102081298828, ablated_edges=32
# loss.item()=-86.98362731933594, ablated_edges=32
# loss.item()=-88.3546371459961, ablated_edges=32
# loss.item()=-89.80631256103516, ablated_edges=33
# Epochs trained:  100
# Loss: -89.8063
# Total preserved: 11577.3047
# Edges ablated:  33
# Toxic loss:  11.40868854522705
# OWT loss:  3.9361331462860107
# Penalty:  tensor(91.4607, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 3.1688091439718846e-06, logit diff = -3.6669692993164062
# Best Token: [' the'], P(Alicia) = 2.2231949969864218e-06, logit diff = -3.052978515625
#
#
# loss.item()=-90.833740234375, ablated_edges=32
# loss.item()=-92.35493469238281, ablated_edges=32
# loss.item()=-93.10646057128906, ablated_edges=32
# loss.item()=-93.94319152832031, ablated_edges=32
# loss.item()=-94.83021545410156, ablated_edges=32
# loss.item()=-96.15564727783203, ablated_edges=31
# loss.item()=-97.86309814453125, ablated_edges=31
# loss.item()=-98.66466522216797, ablated_edges=31
# loss.item()=-99.74299621582031, ablated_edges=30
# loss.item()=-101.70378875732422, ablated_edges=31
# Epochs trained:  110
# Loss: -101.7038
# Total preserved: 11580.7119
# Edges ablated:  31
# Toxic loss:  10.806747436523438
# OWT loss:  3.525886058807373
# Penalty:  tensor(103.0683, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 3.117429287158302e-06, logit diff = -3.7639541625976562
# Best Token: [' the'], P(Alicia) = 2.465461875544861e-06, logit diff = -3.06793212890625
#
#
# loss.item()=-102.470947265625, ablated_edges=31
# loss.item()=-103.21913146972656, ablated_edges=29
# loss.item()=-104.30377197265625, ablated_edges=28
# loss.item()=-105.69766998291016, ablated_edges=29
# loss.item()=-107.26316833496094, ablated_edges=29
# loss.item()=-107.57110595703125, ablated_edges=27
# loss.item()=-109.13591766357422, ablated_edges=26
# loss.item()=-110.48607635498047, ablated_edges=26
# loss.item()=-111.60969543457031, ablated_edges=27
# loss.item()=-112.74044036865234, ablated_edges=27
# Epochs trained:  120
# Loss: -112.7404
# Total preserved: 11583.9512
# Edges ablated:  27
# Toxic loss:  11.424020767211914
# OWT loss:  4.225475788116455
# Penalty:  tensor(114.6811, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 3.6108290260017384e-06, logit diff = -3.775360107421875
# Best Token: [' the'], P(Alicia) = 2.6200389129371615e-06, logit diff = -3.0569305419921875
#
#
# loss.item()=-113.88419342041016, ablated_edges=27
# loss.item()=-115.45813751220703, ablated_edges=27
# loss.item()=-116.50716400146484, ablated_edges=26
# loss.item()=-117.1535873413086, ablated_edges=25
# loss.item()=-118.59122467041016, ablated_edges=26
# loss.item()=-119.77714538574219, ablated_edges=25
# loss.item()=-121.41586303710938, ablated_edges=22
# loss.item()=-120.8614273071289, ablated_edges=23
# loss.item()=-123.01470184326172, ablated_edges=24
# loss.item()=-124.27417755126953, ablated_edges=23
# Epochs trained:  130
# Loss: -124.2742
# Total preserved: 11587.8584
# Edges ablated:  23
# Toxic loss:  11.530961990356445
# OWT loss:  4.339665412902832
# Penalty:  tensor(126.3077, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 4.080245616933098e-06, logit diff = -3.65777587890625
# Best Token: [' the'], P(Alicia) = 2.7278683774056844e-06, logit diff = -3.3149795532226562
#
#
# loss.item()=-125.3916244506836, ablated_edges=23
# loss.item()=-126.84842681884766, ablated_edges=23
# loss.item()=-127.41018676757812, ablated_edges=22
# loss.item()=-128.3299102783203, ablated_edges=23
# loss.item()=-130.50723266601562, ablated_edges=22
# loss.item()=-131.9279327392578, ablated_edges=21
# loss.item()=-131.5559844970703, ablated_edges=22
# loss.item()=-132.1207275390625, ablated_edges=22
# loss.item()=-135.1486358642578, ablated_edges=20
# loss.item()=-136.13995361328125, ablated_edges=21
# Epochs trained:  140
# Loss: -136.1400
# Total preserved: 11589.8506
# Edges ablated:  21
# Toxic loss:  10.503313064575195
# OWT loss:  3.879924774169922
# Penalty:  tensor(137.9192, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 5.212324595049722e-06, logit diff = -3.4917984008789062
# Best Token: [' the'], P(Alicia) = 3.4062927625200246e-06, logit diff = -3.3022689819335938
#
#
# loss.item()=-136.25631713867188, ablated_edges=20
# loss.item()=-137.5171661376953, ablated_edges=20
# loss.item()=-139.5790557861328, ablated_edges=20
# loss.item()=-140.99037170410156, ablated_edges=21
# loss.item()=-141.60276794433594, ablated_edges=21
# loss.item()=-142.5446319580078, ablated_edges=21
# loss.item()=-143.63470458984375, ablated_edges=19
# loss.item()=-145.439453125, ablated_edges=20
# loss.item()=-146.02963256835938, ablated_edges=19
# loss.item()=-146.7775421142578, ablated_edges=20
# Epochs trained:  150
# Loss: -146.7775
# Total preserved: 11591.5898
# Edges ablated:  20
# Toxic loss:  10.390040397644043
# OWT loss:  4.831991672515869
# Penalty:  tensor(149.5315, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 7.288570031960262e-06, logit diff = -3.2609786987304688
# Best Token: [' the'], P(Alicia) = 4.535285825113533e-06, logit diff = -3.148773193359375
#
#
# loss.item()=-148.2272491455078, ablated_edges=18
# loss.item()=-149.91140747070312, ablated_edges=19
# loss.item()=-151.07730102539062, ablated_edges=19
# loss.item()=-152.11764526367188, ablated_edges=17
# loss.item()=-153.2642364501953, ablated_edges=17
# loss.item()=-153.62094116210938, ablated_edges=17
# loss.item()=-154.96775817871094, ablated_edges=17
# loss.item()=-156.176513671875, ablated_edges=17
# loss.item()=-157.92799377441406, ablated_edges=17
# loss.item()=-159.02049255371094, ablated_edges=17
# Epochs trained:  160
# Loss: -159.0205
# Total preserved: 11592.9629
# Edges ablated:  17
# Toxic loss:  10.409658432006836
# OWT loss:  4.20361852645874
# Penalty:  tensor(161.1422, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 6.691823273285991e-06, logit diff = -3.3889236450195312
# Best Token: [' the'], P(Alicia) = 3.923931672034087e-06, logit diff = -3.5029678344726562
#
#
# loss.item()=-159.65306091308594, ablated_edges=17
# loss.item()=-161.48316955566406, ablated_edges=17
# loss.item()=-162.7029571533203, ablated_edges=17
# loss.item()=-163.85546875, ablated_edges=17
# loss.item()=-164.98252868652344, ablated_edges=18
# loss.item()=-166.28810119628906, ablated_edges=17
# loss.item()=-166.53616333007812, ablated_edges=17
# loss.item()=-168.70579528808594, ablated_edges=17
# loss.item()=-169.8007354736328, ablated_edges=17
# loss.item()=-170.70401000976562, ablated_edges=17
# Epochs trained:  170
# Loss: -170.7040
# Total preserved: 11593.5273
# Edges ablated:  17
# Toxic loss:  10.495579719543457
# OWT loss:  4.138669490814209
# Penalty:  tensor(172.7436, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 7.107476449164096e-06, logit diff = -3.459381103515625
# Best Token: [' the'], P(Alicia) = 4.046598860441009e-06, logit diff = -3.5622787475585938
#
#
# loss.item()=-171.8513641357422, ablated_edges=17
# loss.item()=-173.60946655273438, ablated_edges=17
# loss.item()=-172.4976348876953, ablated_edges=17
# loss.item()=-175.70570373535156, ablated_edges=16
# loss.item()=-175.94215393066406, ablated_edges=18
# loss.item()=-177.80165100097656, ablated_edges=16
# loss.item()=-178.56500244140625, ablated_edges=15
# loss.item()=-180.1150665283203, ablated_edges=16
# loss.item()=-180.78994750976562, ablated_edges=15
# loss.item()=-181.79617309570312, ablated_edges=16
# Epochs trained:  180
# Loss: -181.7962
# Total preserved: 11594.5117
# Edges ablated:  16
# Toxic loss:  11.165010452270508
# OWT loss:  4.789548873901367
# Penalty:  tensor(184.3527, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 7.377211204584455e-06, logit diff = -3.3583526611328125
# Best Token: [' the'], P(Alicia) = 4.079739937878912e-06, logit diff = -3.55419921875
#
#
# loss.item()=-183.34552001953125, ablated_edges=17
# loss.item()=-185.043701171875, ablated_edges=16
# loss.item()=-185.69921875, ablated_edges=15
# loss.item()=-187.0985107421875, ablated_edges=16
# loss.item()=-187.49913024902344, ablated_edges=16
# loss.item()=-189.41775512695312, ablated_edges=16
# loss.item()=-190.14817810058594, ablated_edges=15
# loss.item()=-191.7379150390625, ablated_edges=15
# loss.item()=-193.0317840576172, ablated_edges=15
# loss.item()=-194.04483032226562, ablated_edges=15
# Epochs trained:  190
# Loss: -194.0448
# Total preserved: 11594.8301
# Edges ablated:  15
# Toxic loss:  10.203085899353027
# OWT loss:  3.9484307765960693
# Penalty:  tensor(195.9526, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 6.270903668337269e-06, logit diff = -3.4954452514648438
# Best Token: [' the'], P(Alicia) = 3.7266659091983456e-06, logit diff = -3.5976028442382812
#
#
# loss.item()=-194.8538818359375, ablated_edges=15
# loss.item()=-196.7275848388672, ablated_edges=15
# loss.item()=-196.592041015625, ablated_edges=15
# loss.item()=-198.3710479736328, ablated_edges=15
# loss.item()=-200.05584716796875, ablated_edges=16
# loss.item()=-200.67298889160156, ablated_edges=15
# loss.item()=-202.506591796875, ablated_edges=15
# loss.item()=-203.36546325683594, ablated_edges=16
# loss.item()=-204.32960510253906, ablated_edges=16
# loss.item()=-205.69747924804688, ablated_edges=15
# Epochs trained:  200
# Loss: -205.6975
# Total preserved: 11595.4277
# Edges ablated:  15
# Toxic loss:  10.906166076660156
# OWT loss:  4.041903972625732
# Penalty:  tensor(207.5582, device='cuda:0', grad_fn=<AddBackward0>)
# Best Token: [' the'], P(Alicia) = 7.741498848190531e-06, logit diff = -3.6055374145507812
# Best Token: [' the'], P(Alicia) = 4.266330051905243e-06, logit diff = -3.624969482421875

# %%
with open(f"models/circuit_covering_circuit_breaking_params_dict_lambda={regularization_strength}_{alpha=}_means_ioi=False_{template_type=}.pkl", "wb") as f:
    pickle.dump(old_mask_params, f)

# %% [markdown]
# ## Test model before and after circuit breaking

# %%
import pickle
with open("data/ioi_prompts_test.pkl", "rb") as f:
    ioi_prompts_test = pickle.load(f)
    # ioi_sentences_test = [t[2] for t in ioi_sentences_test]

with open("data/eval_uniform.pkl", "rb") as f:
    uniform_samples = pickle.load(f)
    uniform_sentences = [t[2] for t in uniform_samples]

original_model = load_demo_gpt2(means=False)

with open("models/masked_gpt2_mean_ablation_v6.pkl", "rb") as f:
    model.state_dict = pickle.load(f)

# %%
ioi_prompts_test

# %%
# Run inference on an ioi_sentence
ioi_prompt = ioi_prompts_test[0]
print(ioi_prompt)

original_model.eval()
original_model.to('cuda')
def get_last_token(model, prompt, topk=5, sentence=False):
    # generate last token
    if not sentence:
        prompt_sentence = prompt['text']
    else:
        prompt_sentence = prompt

    tokens = tokenizer(prompt_sentence, return_tensors='pt').input_ids[:, :-1]

    # generate one token, decode original_model(ioi_tokens[:, :-1])
    model_outputs = model(tokens)[0]
    model_outputs = model_outputs.squeeze(0)[-1]
    probs = torch.nn.functional.softmax(model_outputs, dim=-1)

    topk_outputs = torch.topk(model_outputs, topk)
    topk_tokens = topk_outputs.indices
    topk_probs = probs[topk_outputs.indices]
    
    topk_tokens_decoded = tokenizer.batch_decode(topk_tokens)
    
    if not sentence:
        # Get logit diff by finding difference between logit of 
        io_token = tokenizer(" " + prompt['IO'], return_tensors='pt').input_ids[:, -1]
        s_token = tokenizer(" " + prompt['S'], return_tensors='pt').input_ids[:, -1]
        logit_diff = model_outputs[io_token][0] - model_outputs[s_token][0]
        return topk_tokens_decoded, topk_probs, logit_diff
    return topk_tokens_decoded, topk_probs

print(get_last_token(original_model, ioi_prompt))


for idx in range(3):
    print(uniform_sentences[idx])
    print("Before ablation")
    print(get_last_token(original_model, uniform_sentences[idx], sentence=True)[0])
    print()
    print("After ablation")
    print(get_last_token(model, uniform_sentences[idx], sentence=True)[0])
    print("\n\n")

# %%
# Try on uniform samples
def get_ioi_score(model, num_samples):
    ave_logit_diffs = []
    for idx in range(num_samples):
        prompt = ioi_prompts_test[idx]
        ave_logit_diffs.append(get_last_token(model, prompt)[2])
    return sum(ave_logit_diffs) / len(ave_logit_diffs)

get_ioi_score(original_model, 20)

# %% [markdown]
# ## Visualize mask
# Create the computational graphs in edge attribution patching paper

# %% [markdown]
# ### Load mask and calculate what edges are present

# %%
with open("models/params_dict_lambda=2.pkl", "rb") as f:
    mask_params = pickle.load(f)
    mask_params = mask_params[200]

# %%
def get_nodes_and_edges(mask_params, edge_0=True):
    """
    If edge_0 is True, then edges are between nodes with mask value 0. Else, edges are between nodes with mask value 1.
    """
    # calculate which nodes will be in the graph
    connected_nodes = set()
    # add embed node at position
    # connected_nodes.add((-1, "embed"))
    n_heads = 12
    n_layers = 12

    # associate each node with a position
    all_possible_nodes = [(-1, "embed")]
    mask_dict = {}
    # empty tensor
    mask_dict["embed"] = torch.zeros(size=(0,))
    for idx in range(len(mask_params)):
        if "attention" in param_names[idx]:
            layer = int(param_names[idx].split(".")[1])
            for i in range(n_heads):
                all_possible_nodes.append((layer, f"a{layer}.{i}"))
                mask_dict[f"a{layer}.{i}"] = mask_params[idx][:,i].detach().cpu()
        elif "mlp" in param_names[idx]:
            layer = int(param_names[idx].split(".")[1])
            all_possible_nodes.append((layer, f"m{layer}"))
            mask_dict[f"m{layer}"] = mask_params[idx].detach().cpu()
    all_possible_nodes.append((n_heads, "output"))
    mask_dict["output"] = mask_params[0]

    # Calculate where edges are based on the mask
    # Edge between node i and node j if mask_dict[i][all_possible_nodes.index(j)] == 0
    edges = set()
    for i in range(len(all_possible_nodes)):
        for j in range(len(all_possible_nodes)):
            j_index = all_possible_nodes.index(all_possible_nodes[j])
            if j_index < len(mask_dict[all_possible_nodes[i][1]]) and mask_dict[all_possible_nodes[i][1]][all_possible_nodes.index(all_possible_nodes[j])] == (0 if edge_0 else 1):
                edges.add((all_possible_nodes[i], all_possible_nodes[j]))
    
    nodes_with_edges = set([node for edge in edges for node in edge])

    return all_possible_nodes, nodes_with_edges, edges, mask_dict
all_possible_nodes, nodes_with_edges, edges, mask_dict = get_nodes_and_edges(mask_params)

# %% [markdown]
# ### Analyze ACDC and Compare
# I separately used ACDC++ (EAP from "Attribution Patching Outperforms Automated Circuit Discovery" paper) to get the known circuit edges. I want to compare my various learned masks (from different losses) to the known circuit edges.

# %%
with open("models/acdcpp_edges_original.pkl", "rb") as f:
    acdcpp_edges_long = pickle.load(f)
acdcpp_edges_long
# Out:
# ({0.08: {'blocks.0.attn.hook_k[:, :, 10]blocks.0.hook_k_input[:, :, 10]',
#    'blocks.0.attn.hook_q[:, :, 10]blocks.0.hook_q_input[:, :, 10]',
#    'blocks.0.attn.hook_q[:, :, 2]blocks.0.hook_q_input[:, :, 2]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_k[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_q[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_v[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_k[:, :, 1]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_q[:, :, 1]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_v[:, :, 1]',
#    'blocks.0.attn.hook_result[:, :, 3]blocks.0.attn.hook_k[:, :, 3]',
#    'blocks.0.attn.hook_result[:, :, 3]blocks.0.attn.hook_q[:, :, 3]',
#    'blocks.0.attn.hook_result[:, :, 3]blocks.0.attn.hook_v[:, :, 3]',
#    'blocks.0.attn.hook_result[:, :, 6]blocks.0.attn.hook_k[:, :, 6]',
#    'blocks.0.attn.hook_result[:, :, 6]blocks.0.attn.hook_q[:, :, 6]',
#    'blocks.0.attn.hook_result[:, :, 6]blocks.0.attn.hook_v[:, :, 6]',
#    'blocks.0.attn.hook_v[:, :, 10]blocks.0.hook_v_input[:, :, 10]',
#    'blocks.0.attn.hook_v[:, :, 1]blocks.0.hook_v_input[:, :, 1]',
#    'blocks.0.attn.hook_v[:, :, 3]blocks.0.hook_v_input[:, :, 3]',
#    'blocks.0.attn.hook_v[:, :, 6]blocks.0.hook_v_input[:, :, 6]',
#    'blocks.0.hook_k_input[:, :, 10]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.0.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 1]',
#    'blocks.0.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 4]',
#    'blocks.0.hook_mlp_in[:]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_mlp_out[:]blocks.0.hook_mlp_in[:]',
#    'blocks.0.hook_q_input[:, :, 10]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_v_input[:, :, 1]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_v_input[:, :, 3]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_v_input[:, :, 5]blocks.0.hook_resid_pre[:]',
#    'blocks.1.attn.hook_k[:, :, 11]blocks.1.hook_k_input[:, :, 11]',
#    'blocks.1.attn.hook_q[:, :, 11]blocks.1.hook_q_input[:, :, 11]',
#    'blocks.1.attn.hook_result[:, :, 7]blocks.1.attn.hook_k[:, :, 7]',
#    'blocks.1.attn.hook_result[:, :, 7]blocks.1.attn.hook_q[:, :, 7]',
#    'blocks.1.attn.hook_result[:, :, 7]blocks.1.attn.hook_v[:, :, 7]',
#    'blocks.1.attn.hook_v[:, :, 7]blocks.1.hook_v_input[:, :, 7]',
#    'blocks.1.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.1.hook_mlp_out[:]blocks.1.hook_mlp_in[:]',
#    'blocks.10.attn.hook_k[:, :, 1]blocks.10.hook_k_input[:, :, 1]',
#    'blocks.10.attn.hook_k[:, :, 3]blocks.10.hook_k_input[:, :, 3]',
#    'blocks.10.attn.hook_k[:, :, 6]blocks.10.hook_k_input[:, :, 6]',
#    'blocks.10.attn.hook_k[:, :, 7]blocks.10.hook_k_input[:, :, 7]',
#    'blocks.10.attn.hook_q[:, :, 0]blocks.10.hook_q_input[:, :, 0]',
#    'blocks.10.attn.hook_q[:, :, 10]blocks.10.hook_q_input[:, :, 10]',
#    'blocks.10.attn.hook_q[:, :, 1]blocks.10.hook_q_input[:, :, 1]',
#    'blocks.10.attn.hook_q[:, :, 2]blocks.10.hook_q_input[:, :, 2]',
#    'blocks.10.attn.hook_q[:, :, 6]blocks.10.hook_q_input[:, :, 6]',
#    'blocks.10.attn.hook_q[:, :, 7]blocks.10.hook_q_input[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_k[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_q[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_v[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_k[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_q[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_v[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_k[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_q[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_v[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 3]blocks.10.attn.hook_k[:, :, 3]',
#    'blocks.10.attn.hook_result[:, :, 3]blocks.10.attn.hook_q[:, :, 3]',
#    'blocks.10.attn.hook_result[:, :, 3]blocks.10.attn.hook_v[:, :, 3]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_k[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_q[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_v[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_k[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_q[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_v[:, :, 7]',
#    'blocks.10.attn.hook_v[:, :, 0]blocks.10.hook_v_input[:, :, 0]',
#    'blocks.10.attn.hook_v[:, :, 1]blocks.10.hook_v_input[:, :, 1]',
#    'blocks.10.attn.hook_v[:, :, 2]blocks.10.hook_v_input[:, :, 2]',
#    'blocks.10.attn.hook_v[:, :, 3]blocks.10.hook_v_input[:, :, 3]',
#    'blocks.10.attn.hook_v[:, :, 6]blocks.10.hook_v_input[:, :, 6]',
#    'blocks.10.attn.hook_v[:, :, 7]blocks.10.hook_v_input[:, :, 7]',
#    'blocks.10.hook_k_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 2]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.0.attn.hook_result[:, :, 1]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.1.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.2.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.3.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.4.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.6.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.7.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.8.hook_mlp_out[:]',
#    'blocks.10.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_mlp_in[:]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_mlp_out[:]blocks.10.hook_mlp_in[:]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.7.attn.hook_result[:, :, 3]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 10]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 1]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 2]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_q_input[:, :, 6]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 6]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 6]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_v_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_v_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.11.attn.hook_k[:, :, 10]blocks.11.hook_k_input[:, :, 10]',
#    'blocks.11.attn.hook_k[:, :, 2]blocks.11.hook_k_input[:, :, 2]',
#    'blocks.11.attn.hook_k[:, :, 9]blocks.11.hook_k_input[:, :, 9]',
#    'blocks.11.attn.hook_q[:, :, 10]blocks.11.hook_q_input[:, :, 10]',
#    'blocks.11.attn.hook_q[:, :, 2]blocks.11.hook_q_input[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_k[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_q[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_v[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_k[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_q[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_v[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 3]blocks.11.attn.hook_k[:, :, 3]',
#    'blocks.11.attn.hook_result[:, :, 3]blocks.11.attn.hook_q[:, :, 3]',
#    'blocks.11.attn.hook_result[:, :, 3]blocks.11.attn.hook_v[:, :, 3]',
#    'blocks.11.attn.hook_v[:, :, 10]blocks.11.hook_v_input[:, :, 10]',
#    'blocks.11.attn.hook_v[:, :, 2]blocks.11.hook_v_input[:, :, 2]',
#    'blocks.11.attn.hook_v[:, :, 3]blocks.11.hook_v_input[:, :, 3]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.0.attn.hook_result[:, :, 1]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.0.attn.hook_result[:, :, 5]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.1.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.2.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.3.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.4.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.6.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.7.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.8.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 2]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_mlp_in[:]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_mlp_in[:]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_mlp_out[:]blocks.11.hook_mlp_in[:]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 1]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.hook_mlp_out[:]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.9.hook_mlp_out[:]',
#    'blocks.11.hook_q_input[:, :, 6]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 1]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 3]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_resid_post[:]blocks.10.hook_mlp_out[:]',
#    'blocks.11.hook_resid_post[:]blocks.11.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.11.attn.hook_result[:, :, 2]',
#    'blocks.11.hook_resid_post[:]blocks.11.attn.hook_result[:, :, 3]',
#    'blocks.11.hook_resid_post[:]blocks.11.hook_mlp_out[:]',
#    'blocks.11.hook_resid_post[:]blocks.7.attn.hook_result[:, :, 3]',
#    'blocks.11.hook_resid_post[:]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_resid_post[:]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.8.attn.hook_result[:, :, 2]',
#    'blocks.11.hook_resid_post[:]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 5]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 8]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_resid_post[:]blocks.9.hook_mlp_out[:]',
#    'blocks.11.hook_v_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_v_input[:, :, 2]blocks.0.hook_mlp_out[:]',
#    'blocks.2.attn.hook_result[:, :, 1]blocks.2.attn.hook_k[:, :, 1]',
#    'blocks.2.attn.hook_result[:, :, 1]blocks.2.attn.hook_q[:, :, 1]',
#    'blocks.2.attn.hook_result[:, :, 1]blocks.2.attn.hook_v[:, :, 1]',
#    'blocks.2.attn.hook_v[:, :, 1]blocks.2.hook_v_input[:, :, 1]',
#    'blocks.2.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.2.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.2.hook_mlp_in[:]blocks.0.hook_resid_pre[:]',
#    'blocks.2.hook_mlp_in[:]blocks.1.attn.hook_result[:, :, 11]',
#    'blocks.2.hook_mlp_out[:]blocks.2.hook_mlp_in[:]',
#    'blocks.2.hook_q_input[:, :, 11]blocks.0.hook_mlp_out[:]',
#    'blocks.3.attn.hook_k[:, :, 0]blocks.3.hook_k_input[:, :, 0]',
#    'blocks.3.attn.hook_q[:, :, 0]blocks.3.hook_q_input[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_k[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_q[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_v[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 10]blocks.3.attn.hook_k[:, :, 10]',
#    'blocks.3.attn.hook_result[:, :, 10]blocks.3.attn.hook_q[:, :, 10]',
#    'blocks.3.attn.hook_result[:, :, 10]blocks.3.attn.hook_v[:, :, 10]',
#    'blocks.3.hook_k_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.3.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.3.hook_mlp_in[:]blocks.2.hook_mlp_out[:]',
#    'blocks.3.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.3.hook_mlp_out[:]blocks.3.hook_mlp_in[:]',
#    'blocks.3.hook_q_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.3.hook_q_input[:, :, 0]blocks.1.hook_mlp_out[:]',
#    'blocks.3.hook_q_input[:, :, 0]blocks.2.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.1.attn.hook_result[:, :, 11]',
#    'blocks.4.hook_mlp_in[:]blocks.1.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.4.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 9]',
#    'blocks.4.hook_mlp_in[:]blocks.2.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.4.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 10]',
#    'blocks.4.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 3]',
#    'blocks.4.hook_mlp_in[:]blocks.3.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.4.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 3]',
#    'blocks.4.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 4]',
#    'blocks.4.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 7]',
#    'blocks.5.attn.hook_k[:, :, 5]blocks.5.hook_k_input[:, :, 5]',
#    'blocks.5.attn.hook_k[:, :, 9]blocks.5.hook_k_input[:, :, 9]',
#    'blocks.5.attn.hook_q[:, :, 5]blocks.5.hook_q_input[:, :, 5]',
#    'blocks.5.attn.hook_q[:, :, 9]blocks.5.hook_q_input[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 10]blocks.5.attn.hook_k[:, :, 10]',
#    'blocks.5.attn.hook_result[:, :, 10]blocks.5.attn.hook_q[:, :, 10]',
#    'blocks.5.attn.hook_result[:, :, 10]blocks.5.attn.hook_v[:, :, 10]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_k[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_q[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_v[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 8]blocks.5.attn.hook_k[:, :, 8]',
#    'blocks.5.attn.hook_result[:, :, 8]blocks.5.attn.hook_q[:, :, 8]',
#    'blocks.5.attn.hook_result[:, :, 8]blocks.5.attn.hook_v[:, :, 8]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_k[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_q[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_v[:, :, 9]',
#    'blocks.5.attn.hook_v[:, :, 9]blocks.5.hook_v_input[:, :, 9]',
#    'blocks.5.hook_k_input[:, :, 5]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.5.hook_k_input[:, :, 5]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.5.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.1.attn.hook_result[:, :, 0]',
#    'blocks.5.hook_mlp_in[:]blocks.1.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.5.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 9]',
#    'blocks.5.hook_mlp_in[:]blocks.2.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.5.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 3]',
#    'blocks.5.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 6]',
#    'blocks.5.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 7]',
#    'blocks.5.hook_mlp_in[:]blocks.3.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.5.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 3]',
#    'blocks.5.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 7]',
#    'blocks.5.hook_mlp_in[:]blocks.4.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 10]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 6]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 8]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.5.hook_mlp_out[:]blocks.5.hook_mlp_in[:]',
#    'blocks.5.hook_q_input[:, :, 5]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_q_input[:, :, 5]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.5.hook_q_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_q_input[:, :, 9]blocks.1.hook_mlp_out[:]',
#    'blocks.5.hook_q_input[:, :, 9]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.attn.hook_k[:, :, 6]blocks.6.hook_k_input[:, :, 6]',
#    'blocks.6.attn.hook_k[:, :, 9]blocks.6.hook_k_input[:, :, 9]',
#    'blocks.6.attn.hook_q[:, :, 6]blocks.6.hook_q_input[:, :, 6]',
#    'blocks.6.attn.hook_q[:, :, 9]blocks.6.hook_q_input[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_k[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_q[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_v[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 1]blocks.6.attn.hook_k[:, :, 1]',
#    'blocks.6.attn.hook_result[:, :, 1]blocks.6.attn.hook_q[:, :, 1]',
#    'blocks.6.attn.hook_result[:, :, 1]blocks.6.attn.hook_v[:, :, 1]',
#    'blocks.6.attn.hook_result[:, :, 4]blocks.6.attn.hook_k[:, :, 4]',
#    'blocks.6.attn.hook_result[:, :, 4]blocks.6.attn.hook_q[:, :, 4]',
#    'blocks.6.attn.hook_result[:, :, 4]blocks.6.attn.hook_v[:, :, 4]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_k[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_q[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_v[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_k[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_q[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_v[:, :, 9]',
#    'blocks.6.attn.hook_v[:, :, 0]blocks.6.hook_v_input[:, :, 0]',
#    'blocks.6.attn.hook_v[:, :, 4]blocks.6.hook_v_input[:, :, 4]',
#    'blocks.6.attn.hook_v[:, :, 6]blocks.6.hook_v_input[:, :, 6]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.2.attn.hook_result[:, :, 9]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.3.attn.hook_result[:, :, 3]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.3.attn.hook_result[:, :, 7]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.4.attn.hook_result[:, :, 3]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.4.attn.hook_result[:, :, 7]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.4.hook_mlp_out[:]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.5.attn.hook_result[:, :, 6]',
#    'blocks.6.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.6.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.1.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.hook_mlp_in[:]blocks.3.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 10]',
#    'blocks.6.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.6.hook_mlp_in[:]blocks.5.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 6]',
#    'blocks.6.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 7]',
#    'blocks.6.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.6.hook_mlp_out[:]blocks.6.hook_mlp_in[:]',
#    'blocks.6.hook_q_input[:, :, 6]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.hook_q_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.6.hook_q_input[:, :, 6]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.0.attn.hook_result[:, :, 1]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.1.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.3.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.4.attn.hook_result[:, :, 4]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.4.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.5.hook_mlp_out[:]',
#    'blocks.6.hook_v_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.attn.hook_k[:, :, 1]blocks.7.hook_k_input[:, :, 1]',
#    'blocks.7.attn.hook_k[:, :, 3]blocks.7.hook_k_input[:, :, 3]',
#    'blocks.7.attn.hook_k[:, :, 9]blocks.7.hook_k_input[:, :, 9]',
#    'blocks.7.attn.hook_q[:, :, 1]blocks.7.hook_q_input[:, :, 1]',
#    'blocks.7.attn.hook_result[:, :, 1]blocks.7.attn.hook_k[:, :, 1]',
#    'blocks.7.attn.hook_result[:, :, 1]blocks.7.attn.hook_q[:, :, 1]',
#    'blocks.7.attn.hook_result[:, :, 1]blocks.7.attn.hook_v[:, :, 1]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_k[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_q[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_v[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_k[:, :, 9]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_q[:, :, 9]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_v[:, :, 9]',
#    'blocks.7.attn.hook_v[:, :, 3]blocks.7.hook_v_input[:, :, 3]',
#    'blocks.7.attn.hook_v[:, :, 9]blocks.7.hook_v_input[:, :, 9]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.0.attn.hook_result[:, :, 1]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.3.hook_mlp_out[:]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.4.hook_mlp_out[:]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.6.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.2.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.7.hook_mlp_in[:]blocks.5.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 6]',
#    'blocks.7.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.7.hook_mlp_in[:]blocks.6.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.7.hook_mlp_out[:]blocks.7.hook_mlp_in[:]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.3.hook_mlp_out[:]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.6.attn.hook_result[:, :, 6]',
#    'blocks.7.hook_v_input[:, :, 3]blocks.4.attn.hook_result[:, :, 3]',
#    'blocks.7.hook_v_input[:, :, 3]blocks.6.attn.hook_result[:, :, 0]',
#    'blocks.7.hook_v_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.7.hook_v_input[:, :, 9]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.hook_v_input[:, :, 9]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.8.attn.hook_k[:, :, 10]blocks.8.hook_k_input[:, :, 10]',
#    'blocks.8.attn.hook_k[:, :, 6]blocks.8.hook_k_input[:, :, 6]',
#    'blocks.8.attn.hook_q[:, :, 3]blocks.8.hook_q_input[:, :, 3]',
#    'blocks.8.attn.hook_q[:, :, 6]blocks.8.hook_q_input[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_k[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_q[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_v[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 2]blocks.8.attn.hook_k[:, :, 2]',
#    'blocks.8.attn.hook_result[:, :, 2]blocks.8.attn.hook_q[:, :, 2]',
#    'blocks.8.attn.hook_result[:, :, 2]blocks.8.attn.hook_v[:, :, 2]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_k[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_q[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_v[:, :, 6]',
#    'blocks.8.attn.hook_v[:, :, 10]blocks.8.hook_v_input[:, :, 10]',
#    'blocks.8.attn.hook_v[:, :, 2]blocks.8.hook_v_input[:, :, 2]',
#    'blocks.8.attn.hook_v[:, :, 3]blocks.8.hook_v_input[:, :, 3]',
#    'blocks.8.attn.hook_v[:, :, 6]blocks.8.hook_v_input[:, :, 6]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.3.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.4.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.6.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.0.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.3.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.5.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.6.attn.hook_result[:, :, 6]',
#    'blocks.8.hook_mlp_in[:]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.8.hook_mlp_out[:]blocks.8.hook_mlp_in[:]',
#    'blocks.8.hook_q_input[:, :, 10]blocks.7.attn.hook_result[:, :, 3]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.5.hook_mlp_out[:]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.5.hook_mlp_out[:]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.6.hook_mlp_out[:]',
#    'blocks.9.attn.hook_k[:, :, 9]blocks.9.hook_k_input[:, :, 9]',
#    'blocks.9.attn.hook_q[:, :, 6]blocks.9.hook_q_input[:, :, 6]',
#    'blocks.9.attn.hook_q[:, :, 9]blocks.9.hook_q_input[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 3]blocks.9.attn.hook_k[:, :, 3]',
#    'blocks.9.attn.hook_result[:, :, 3]blocks.9.attn.hook_q[:, :, 3]',
#    'blocks.9.attn.hook_result[:, :, 3]blocks.9.attn.hook_v[:, :, 3]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_k[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_q[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_v[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 5]blocks.9.attn.hook_k[:, :, 5]',
#    'blocks.9.attn.hook_result[:, :, 5]blocks.9.attn.hook_q[:, :, 5]',
#    'blocks.9.attn.hook_result[:, :, 5]blocks.9.attn.hook_v[:, :, 5]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_k[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_q[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_v[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_k[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_q[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_v[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 8]blocks.9.attn.hook_k[:, :, 8]',
#    'blocks.9.attn.hook_result[:, :, 8]blocks.9.attn.hook_q[:, :, 8]',
#    'blocks.9.attn.hook_result[:, :, 8]blocks.9.attn.hook_v[:, :, 8]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_k[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_q[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_v[:, :, 9]',
#    'blocks.9.attn.hook_v[:, :, 3]blocks.9.hook_v_input[:, :, 3]',
#    'blocks.9.attn.hook_v[:, :, 4]blocks.9.hook_v_input[:, :, 4]',
#    'blocks.9.attn.hook_v[:, :, 5]blocks.9.hook_v_input[:, :, 5]',
#    'blocks.9.attn.hook_v[:, :, 6]blocks.9.hook_v_input[:, :, 6]',
#    'blocks.9.attn.hook_v[:, :, 7]blocks.9.hook_v_input[:, :, 7]',
#    'blocks.9.attn.hook_v[:, :, 9]blocks.9.hook_v_input[:, :, 9]',
#    'blocks.9.hook_k_input[:, :, 7]blocks.4.hook_mlp_out[:]',
#    'blocks.9.hook_k_input[:, :, 7]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.9.hook_k_input[:, :, 7]blocks.8.hook_mlp_out[:]',
#    'blocks.9.hook_k_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.9.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.9.hook_mlp_in[:]blocks.8.hook_mlp_out[:]',
#    'blocks.9.hook_mlp_in[:]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.9.hook_mlp_out[:]blocks.9.hook_mlp_in[:]',
#    'blocks.9.hook_q_input[:, :, 4]blocks.8.hook_mlp_out[:]',
#    'blocks.9.hook_q_input[:, :, 7]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.7.attn.hook_result[:, :, 3]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.9.hook_v_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.9.hook_v_input[:, :, 9]blocks.0.hook_mlp_out[:]'},
#   0.15: {'blocks.0.attn.hook_k[:, :, 10]blocks.0.hook_k_input[:, :, 10]',
#    'blocks.0.attn.hook_q[:, :, 10]blocks.0.hook_q_input[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_k[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_q[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 10]blocks.0.attn.hook_v[:, :, 10]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_k[:, :, 1]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_q[:, :, 1]',
#    'blocks.0.attn.hook_result[:, :, 1]blocks.0.attn.hook_v[:, :, 1]',
#    'blocks.0.attn.hook_v[:, :, 1]blocks.0.hook_v_input[:, :, 1]',
#    'blocks.0.hook_k_input[:, :, 10]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_mlp_in[:]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_mlp_out[:]blocks.0.hook_mlp_in[:]',
#    'blocks.0.hook_q_input[:, :, 10]blocks.0.hook_resid_pre[:]',
#    'blocks.1.hook_mlp_out[:]blocks.1.hook_mlp_in[:]',
#    'blocks.10.attn.hook_k[:, :, 7]blocks.10.hook_k_input[:, :, 7]',
#    'blocks.10.attn.hook_q[:, :, 0]blocks.10.hook_q_input[:, :, 0]',
#    'blocks.10.attn.hook_q[:, :, 10]blocks.10.hook_q_input[:, :, 10]',
#    'blocks.10.attn.hook_q[:, :, 2]blocks.10.hook_q_input[:, :, 2]',
#    'blocks.10.attn.hook_q[:, :, 6]blocks.10.hook_q_input[:, :, 6]',
#    'blocks.10.attn.hook_q[:, :, 7]blocks.10.hook_q_input[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_k[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_q[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_v[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_k[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_q[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 1]blocks.10.attn.hook_v[:, :, 1]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_k[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_q[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 2]blocks.10.attn.hook_v[:, :, 2]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_k[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_q[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 6]blocks.10.attn.hook_v[:, :, 6]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_k[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_q[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_v[:, :, 7]',
#    'blocks.10.attn.hook_v[:, :, 0]blocks.10.hook_v_input[:, :, 0]',
#    'blocks.10.attn.hook_v[:, :, 1]blocks.10.hook_v_input[:, :, 1]',
#    'blocks.10.attn.hook_v[:, :, 6]blocks.10.hook_v_input[:, :, 6]',
#    'blocks.10.attn.hook_v[:, :, 7]blocks.10.hook_v_input[:, :, 7]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.6.hook_mlp_out[:]',
#    'blocks.10.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_mlp_out[:]blocks.10.hook_mlp_in[:]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_v_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.11.attn.hook_k[:, :, 10]blocks.11.hook_k_input[:, :, 10]',
#    'blocks.11.attn.hook_k[:, :, 2]blocks.11.hook_k_input[:, :, 2]',
#    'blocks.11.attn.hook_q[:, :, 10]blocks.11.hook_q_input[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_k[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_q[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_v[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_k[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_q[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_v[:, :, 2]',
#    'blocks.11.attn.hook_v[:, :, 10]blocks.11.hook_v_input[:, :, 10]',
#    'blocks.11.attn.hook_v[:, :, 2]blocks.11.hook_v_input[:, :, 2]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.3.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.6.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.7.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 2]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 1]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 1]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 3]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_resid_post[:]blocks.10.hook_mlp_out[:]',
#    'blocks.11.hook_resid_post[:]blocks.11.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.11.attn.hook_result[:, :, 2]',
#    'blocks.11.hook_resid_post[:]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_resid_post[:]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_resid_post[:]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_v_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.2.hook_mlp_in[:]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.2.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.2.hook_mlp_out[:]blocks.2.hook_mlp_in[:]',
#    'blocks.3.attn.hook_k[:, :, 0]blocks.3.hook_k_input[:, :, 0]',
#    'blocks.3.attn.hook_q[:, :, 0]blocks.3.hook_q_input[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_k[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_q[:, :, 0]',
#    'blocks.3.attn.hook_result[:, :, 0]blocks.3.attn.hook_v[:, :, 0]',
#    'blocks.3.hook_k_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.3.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.3.hook_mlp_out[:]blocks.3.hook_mlp_in[:]',
#    'blocks.3.hook_q_input[:, :, 0]blocks.0.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.1.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.4.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.4.hook_mlp_in[:]blocks.3.hook_mlp_out[:]',
#    'blocks.4.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.5.attn.hook_k[:, :, 5]blocks.5.hook_k_input[:, :, 5]',
#    'blocks.5.attn.hook_k[:, :, 9]blocks.5.hook_k_input[:, :, 9]',
#    'blocks.5.attn.hook_q[:, :, 5]blocks.5.hook_q_input[:, :, 5]',
#    'blocks.5.attn.hook_q[:, :, 9]blocks.5.hook_q_input[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_k[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_q[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 5]blocks.5.attn.hook_v[:, :, 5]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_k[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_q[:, :, 9]',
#    'blocks.5.attn.hook_result[:, :, 9]blocks.5.attn.hook_v[:, :, 9]',
#    'blocks.5.hook_k_input[:, :, 5]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.5.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.5.hook_mlp_in[:]blocks.2.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.5.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.5.hook_mlp_in[:]blocks.4.attn.hook_result[:, :, 3]',
#    'blocks.5.hook_mlp_in[:]blocks.4.hook_mlp_out[:]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 6]',
#    'blocks.5.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 9]',
#    'blocks.5.hook_q_input[:, :, 5]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_q_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.5.hook_q_input[:, :, 9]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.attn.hook_k[:, :, 9]blocks.6.hook_k_input[:, :, 9]',
#    'blocks.6.attn.hook_q[:, :, 9]blocks.6.hook_q_input[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_k[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_q[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 0]blocks.6.attn.hook_v[:, :, 0]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_k[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_q[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 6]blocks.6.attn.hook_v[:, :, 6]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_k[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_q[:, :, 9]',
#    'blocks.6.attn.hook_result[:, :, 9]blocks.6.attn.hook_v[:, :, 9]',
#    'blocks.6.attn.hook_v[:, :, 0]blocks.6.hook_v_input[:, :, 0]',
#    'blocks.6.attn.hook_v[:, :, 6]blocks.6.hook_v_input[:, :, 6]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.2.attn.hook_result[:, :, 2]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.4.attn.hook_result[:, :, 11]',
#    'blocks.6.hook_k_input[:, :, 9]blocks.5.attn.hook_result[:, :, 6]',
#    'blocks.6.hook_mlp_in[:]blocks.3.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.6.hook_mlp_in[:]blocks.5.hook_mlp_out[:]',
#    'blocks.6.hook_mlp_in[:]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.6.hook_mlp_out[:]blocks.6.hook_mlp_in[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.1.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.4.hook_mlp_out[:]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.6.hook_q_input[:, :, 9]blocks.5.hook_mlp_out[:]',
#    'blocks.7.attn.hook_k[:, :, 9]blocks.7.hook_k_input[:, :, 9]',
#    'blocks.7.attn.hook_q[:, :, 1]blocks.7.hook_q_input[:, :, 1]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_k[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_q[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 3]blocks.7.attn.hook_v[:, :, 3]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_k[:, :, 9]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_q[:, :, 9]',
#    'blocks.7.attn.hook_result[:, :, 9]blocks.7.attn.hook_v[:, :, 9]',
#    'blocks.7.attn.hook_v[:, :, 3]blocks.7.hook_v_input[:, :, 3]',
#    'blocks.7.attn.hook_v[:, :, 9]blocks.7.hook_v_input[:, :, 9]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.0.attn.hook_result[:, :, 10]',
#    'blocks.7.hook_k_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.5.hook_mlp_out[:]',
#    'blocks.7.hook_mlp_in[:]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.7.hook_mlp_out[:]blocks.7.hook_mlp_in[:]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.7.hook_q_input[:, :, 1]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.7.hook_v_input[:, :, 3]blocks.6.attn.hook_result[:, :, 0]',
#    'blocks.7.hook_v_input[:, :, 9]blocks.0.hook_mlp_out[:]',
#    'blocks.7.hook_v_input[:, :, 9]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.attn.hook_k[:, :, 10]blocks.8.hook_k_input[:, :, 10]',
#    'blocks.8.attn.hook_k[:, :, 6]blocks.8.hook_k_input[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_k[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_q[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 10]blocks.8.attn.hook_v[:, :, 10]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_k[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_q[:, :, 6]',
#    'blocks.8.attn.hook_result[:, :, 6]blocks.8.attn.hook_v[:, :, 6]',
#    'blocks.8.attn.hook_v[:, :, 10]blocks.8.hook_v_input[:, :, 10]',
#    'blocks.8.attn.hook_v[:, :, 6]blocks.8.hook_v_input[:, :, 6]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.4.hook_mlp_out[:]',
#    'blocks.8.hook_k_input[:, :, 10]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_k_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_mlp_in[:]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.8.hook_mlp_out[:]blocks.8.hook_mlp_in[:]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.3.attn.hook_result[:, :, 0]',
#    'blocks.8.hook_v_input[:, :, 10]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.5.attn.hook_result[:, :, 5]',
#    'blocks.8.hook_v_input[:, :, 6]blocks.6.attn.hook_result[:, :, 9]',
#    'blocks.9.attn.hook_k[:, :, 9]blocks.9.hook_k_input[:, :, 9]',
#    'blocks.9.attn.hook_q[:, :, 6]blocks.9.hook_q_input[:, :, 6]',
#    'blocks.9.attn.hook_q[:, :, 9]blocks.9.hook_q_input[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_k[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_q[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 4]blocks.9.attn.hook_v[:, :, 4]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_k[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_q[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 6]blocks.9.attn.hook_v[:, :, 6]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_k[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_q[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 7]blocks.9.attn.hook_v[:, :, 7]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_k[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_q[:, :, 9]',
#    'blocks.9.attn.hook_result[:, :, 9]blocks.9.attn.hook_v[:, :, 9]',
#    'blocks.9.attn.hook_v[:, :, 4]blocks.9.hook_v_input[:, :, 4]',
#    'blocks.9.attn.hook_v[:, :, 7]blocks.9.hook_v_input[:, :, 7]',
#    'blocks.9.attn.hook_v[:, :, 9]blocks.9.hook_v_input[:, :, 9]',
#    'blocks.9.hook_mlp_in[:]blocks.0.hook_mlp_out[:]',
#    'blocks.9.hook_mlp_out[:]blocks.9.hook_mlp_in[:]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.7.attn.hook_result[:, :, 9]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.9.hook_q_input[:, :, 9]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.9.hook_v_input[:, :, 9]blocks.0.hook_mlp_out[:]'},
#   0.2: {'blocks.0.attn.hook_k[:, :, 10]blocks.0.hook_k_input[:, :, 10]',
#    'blocks.0.attn.hook_q[:, :, 10]blocks.0.hook_q_input[:, :, 10]',
#    'blocks.0.hook_mlp_in[:]blocks.0.hook_resid_pre[:]',
#    'blocks.0.hook_mlp_out[:]blocks.0.hook_mlp_in[:]',
#    'blocks.1.hook_mlp_out[:]blocks.1.hook_mlp_in[:]',
#    'blocks.10.attn.hook_k[:, :, 7]blocks.10.hook_k_input[:, :, 7]',
#    'blocks.10.attn.hook_q[:, :, 0]blocks.10.hook_q_input[:, :, 0]',
#    'blocks.10.attn.hook_q[:, :, 6]blocks.10.hook_q_input[:, :, 6]',
#    'blocks.10.attn.hook_q[:, :, 7]blocks.10.hook_q_input[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_k[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_q[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 0]blocks.10.attn.hook_v[:, :, 0]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_k[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_q[:, :, 7]',
#    'blocks.10.attn.hook_result[:, :, 7]blocks.10.attn.hook_v[:, :, 7]',
#    'blocks.10.attn.hook_v[:, :, 0]blocks.10.hook_v_input[:, :, 0]',
#    'blocks.10.attn.hook_v[:, :, 7]blocks.10.hook_v_input[:, :, 7]',
#    'blocks.10.hook_k_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.10.hook_mlp_out[:]blocks.10.hook_mlp_in[:]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.8.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 0]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.10.hook_q_input[:, :, 7]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.10.hook_v_input[:, :, 7]blocks.0.hook_mlp_out[:]',
#    'blocks.11.attn.hook_k[:, :, 10]blocks.11.hook_k_input[:, :, 10]',
#    'blocks.11.attn.hook_k[:, :, 2]blocks.11.hook_k_input[:, :, 2]',
#    'blocks.11.attn.hook_q[:, :, 10]blocks.11.hook_q_input[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_k[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_q[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 10]blocks.11.attn.hook_v[:, :, 10]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_k[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_q[:, :, 2]',
#    'blocks.11.attn.hook_result[:, :, 2]blocks.11.attn.hook_v[:, :, 2]',
#    'blocks.11.attn.hook_v[:, :, 10]blocks.11.hook_v_input[:, :, 10]',
#    'blocks.11.attn.hook_v[:, :, 2]blocks.11.hook_v_input[:, :, 2]',
#    'blocks.11.hook_k_input[:, :, 10]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_k_input[:, :, 2]blocks.0.hook_mlp_out[:]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 0]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.10.attn.hook_result[:, :, 7]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_q_input[:, :, 10]blocks.9.attn.hook_result[:, :, 9]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.8.attn.hook_result[:, :, 10]',
#    'blocks.11.hook_q_input[:, :, 2]blocks.9.attn.hook_result[:, :, 6]',
#    'blocks.11.hook_resid_post[:]blocks.10.attn.hook_result[:, :, 0]',
# ...
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 9]': -0.00011929870379390195,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 2]': -8.555874228477478e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 0]': 0.0007341399323195219,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 8]': 9.66096340562217e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.hook_mlp_out[:]': -0.0017216125270351768,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 6]': 1.0607418516883627e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 1]': 0.0002198025758843869,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 11]': -0.00012434885138645768,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 9]': 0.00020940901595167816,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 0]': -0.0002003611734835431,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 2]': -3.600712807383388e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 4]': -8.103283471427858e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 9]': -0.00013016400043852627,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 1]': -0.004052750300616026,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 11]': -0.0003237246419303119,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 7]': -0.0003650993457995355,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 10]': 0.0030633185524493456,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 5]': -0.0006944234482944012,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 2]': 0.00027936178958043456,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 5]': -0.0004600189859047532,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 11]': -9.33982664719224e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 2]': -0.0009751206962391734,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 0]': 0.00013354634575080127,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 3]': 0.00017502265109214932,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.hook_mlp_out[:]': 0.003312853164970875,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 4]': -1.5284902474377304e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 4]': -0.00011033673217752948,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 6]': 4.792910840478726e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 11]': -0.0012138832826167345,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 0]': 3.0461675123660825e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 11]': 0.0007863563951104879,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 4]': 0.0002453018678352237,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.hook_mlp_out[:]': -0.001561851124279201,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 6]': 0.00042909238254651427,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 10]': 2.8043828933732584e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 3]': 0.004371178802102804,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 3]': 0.0003070835955440998,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 10]': -0.0007751388475298882,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 6]': 0.00014252614346332848,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.hook_mlp_out[:]': 0.0006124211358837783,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 1]': -0.00012046600750181824,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.hook_mlp_out[:]': 0.0012092981487512589,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 11]': 4.200810508336872e-07,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 11]': 0.0006665698019787669,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 8]': -0.0007158624939620495,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 8]': -0.0006999583565630019,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 0]': 0.0011987648904323578,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 5]': -5.524058360606432e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 4]': 0.0003245069528929889,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.hook_resid_pre[:]': -0.0011710913386195898,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 2]': -0.0019453766290098429,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 5]': -0.00039523455779999495,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 10]': 0.00021220615599304438,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 5]': 4.766805795952678e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 6]': 5.107701872475445e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 4]': -0.00012176750897197053,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 8]': -0.00021361303515732288,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 11]': -2.7210891857976094e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 3]': -3.3470059861429036e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 7]': 4.5945707825012505e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 2]': -0.0005814858013764024,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 0]': -0.0013666419545188546,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 0]': -0.0008207611972466111,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 1]': 3.4058422897942364e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 4]': -0.00015532242832705379,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 4]': -1.4481192920356989e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 10]': 0.0001688182819634676,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 10]': -0.0001548848522361368,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 1]': -6.754549394827336e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 6]': 0.00011073685891460627,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 2]': -3.954959538532421e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 3]': 0.00036490539787337184,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.hook_mlp_out[:]': 0.0021542166359722614,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 6]': 0.0004517940687946975,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 0]': -0.0017137594986706972,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 9]': -0.00012495857663452625,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 3]': 0.00012074620462954044,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 2]': 0.00020520217367447913,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 1]': 0.0001333255786448717,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 1]': -8.34223028505221e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 1]': -0.00028785032918676734,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 11]': 0.00023200637951958925,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 0]': 0.00024337299691978842,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.hook_mlp_out[:]': 0.0014753134455531836,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 3]': 4.569083102978766e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 9]': 0.0002126628824044019,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 6]': -0.000347640278050676,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 5]': -0.0001431784767191857,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 5]': 0.0013462563510984182,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 10]': -0.00047749464283697307,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 8]': -0.00020477348880376667,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.hook_mlp_out[:]': -0.00028060225304216146,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 5]': -8.702360355528072e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 9]': 0.010331833735108376,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 9]': -0.0055160075426101685,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 3]': -0.00026021734811365604,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 2]': 0.00040156394243240356,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 4]': -6.831925020378549e-06,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 8]': 3.112395643256605e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 11]': -3.19748796755448e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 10]': 6.249380385270342e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 10]': -0.0005752434954047203,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 9]': 3.404125163797289e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 6]': -0.0002901279367506504,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 10]': -0.00025599804939702153,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 9]': -0.0006974852876737714,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 3]': -0.0003139996842946857,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.hook_mlp_out[:]': 0.0006730312015861273,
#    'blocks.11.hook_v_input[:, :, 8]blocks.8.attn.hook_result[:, :, 7]': 0.0001280527503695339,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.hook_mlp_out[:]': -0.0006352319032885134,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 7]': 0.00020077219232916832,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.hook_mlp_out[:]': -0.0015960698947310448,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 0]': 7.533915049862117e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.1.attn.hook_result[:, :, 5]': -0.00038909996510483325,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 3]': -5.787474219687283e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.5.attn.hook_result[:, :, 7]': 7.213717617560178e-05,
#    'blocks.11.hook_v_input[:, :, 8]blocks.2.attn.hook_result[:, :, 7]': 0.00035570451291278005,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 4]': -0.0002735261805355549,
#    'blocks.11.hook_v_input[:, :, 8]blocks.7.attn.hook_result[:, :, 9]': 0.002334142103791237,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 11]': 0.00013055421004537493,
#    'blocks.11.hook_v_input[:, :, 8]blocks.3.attn.hook_result[:, :, 7]': 0.0001340608869213611,
#    'blocks.11.hook_v_input[:, :, 8]blocks.9.attn.hook_result[:, :, 4]': 0.0008831252343952656,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 3]': -0.00034346370375715196,
#    'blocks.11.hook_v_input[:, :, 8]blocks.6.attn.hook_result[:, :, 7]': 0.00010750321962404996,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 8]': 0.0001928911660797894,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 1]': -0.000545149901881814,
#    'blocks.11.hook_v_input[:, :, 8]blocks.10.attn.hook_result[:, :, 7]': -0.00379289872944355,
#    'blocks.11.hook_v_input[:, :, 8]blocks.4.attn.hook_result[:, :, 7]': -0.00022026068472769111,
#    'blocks.11.hook_v_input[:, :, 8]blocks.0.attn.hook_result[:, :, 8]': 0.00011293149145785719,
#    'blocks.11.hook_v_input[:, :, 7]blocks.7.attn.hook_result[:, :, 1]': 7.534113683504984e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.10.attn.hook_result[:, :, 6]': -0.0018236625473946333,
#    'blocks.11.hook_v_input[:, :, 7]blocks.4.attn.hook_result[:, :, 9]': 2.2124640963738784e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.4.attn.hook_result[:, :, 2]': 6.872981612104923e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 0]': 0.0001658777182456106,
#    'blocks.11.hook_v_input[:, :, 7]blocks.3.attn.hook_result[:, :, 5]': -0.0001661204732954502,
#    'blocks.11.hook_v_input[:, :, 7]blocks.5.attn.hook_result[:, :, 10]': 0.00017226606723852456,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 5]': -0.00019083538791164756,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 1]': -1.9867613445967436e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.9.attn.hook_result[:, :, 7]': -0.000636942801065743,
#    'blocks.11.hook_v_input[:, :, 7]blocks.3.attn.hook_result[:, :, 2]': 0.000363808823749423,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 8]': -3.8633341318927705e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 8]': -0.00018706812988966703,
#    'blocks.11.hook_v_input[:, :, 7]blocks.9.attn.hook_result[:, :, 6]': 0.0017083457205444574,
#    'blocks.11.hook_v_input[:, :, 7]blocks.3.attn.hook_result[:, :, 8]': 8.06625175755471e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 9]': 0.00027857592795044184,
#    'blocks.11.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 2]': 4.2391347960801795e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.10.attn.hook_result[:, :, 0]': 0.00614590710029006,
#    'blocks.11.hook_v_input[:, :, 7]blocks.7.attn.hook_result[:, :, 8]': 0.00019705950398929417,
#    'blocks.11.hook_v_input[:, :, 7]blocks.8.hook_mlp_out[:]': -0.0015802974812686443,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 6]': 2.0785610104212537e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 1]': 3.1146337278187275e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.3.attn.hook_result[:, :, 11]': 7.928669219836593e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 9]': 7.236462261062115e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.7.attn.hook_result[:, :, 0]': -1.9870938558597118e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.0.attn.hook_result[:, :, 2]': 0.00014321703929454088,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 4]': 0.00015167720266617835,
#    'blocks.11.hook_v_input[:, :, 7]blocks.3.attn.hook_result[:, :, 9]': -1.3802336980006658e-05,
#    'blocks.11.hook_v_input[:, :, 7]blocks.10.attn.hook_result[:, :, 1]': 0.0005062926793470979,
#    'blocks.11.hook_v_input[:, :, 7]blocks.4.attn.hook_result[:, :, 11]': 0.0004977817879989743,
#    'blocks.11.hook_v_input[:, :, 7]blocks.1.attn.hook_result[:, :, 7]': 1.4493707567453384e-08,
#    'blocks.11.hook_v_input[:, :, 7]blocks.8.attn.hook_result[:, :, 10]': 0.0001926087716128677,
#    'blocks.11.hook_v_input[:, :, 7]blocks.8.attn.hook_result[:, :, 5]': 0.0005507856840267777,
#    'blocks.11.hook_v_input[:, :, 7]blocks.5.attn.hook_result[:, :, 2]': -0.0001991859608097002,
#    'blocks.11.hook_v_input[:, :, 7]blocks.5.attn.hook_result[:, :, 5]': -0.0006448387866839767,
#    'blocks.11.hook_v_input[:, :, 7]blocks.5.attn.hook_result[:, :, 11]': -0.00014296740118879825,
#    'blocks.11.hook_v_input[:, :, 7]blocks.10.attn.hook_result[:, :, 2]': 0.0003505362547002733,
#    'blocks.11.hook_v_input[:, :, 7]blocks.2.attn.hook_result[:, :, 0]': -0.00015875960525590926,
#    ...}})

# %%
# acdcpp edges are in format 'blocks.1.attn.hook_result[:, :, 10]blocks.0.hook_mlp_in[:]', convert to format of ((1, 'a1.10'), (0, 'm0'))

def get_node_name(node_name, show_full_index=False):
    """Node name for use in pretty graphs"""

    def get_index(node_name_long):
        # Get the index by looking for number in brackets
        # e.g. blocks.1.attn.hook_result[:, :, 10] -> 10
        index = node_name_long.split("[")[-1].split("]")[0]
        index = index.split(", ")[-1]
        return int(index)

    if not show_full_index:
        name = ""
        qkv_substrings = [f"hook_{letter}" for letter in ["q", "k", "v"]]
        qkv_input_substrings = [f"hook_{letter}_input" for letter in ["q", "k", "v"]]

        # Handle embedz
        if "resid_pre" in node_name:
            assert "0" in node_name and not any([str(i) in node_name for i in range(1, 10)])
            name += "embed"
            layer = -1
            # if len(node.index.hashable_tuple) > 2:
            #     name += f"_[{node.index.hashable_tuple[2]}]"
            # return name

        elif "embed" in node_name:
            # name = "pos_embeds" if "pos" in node_name else "token_embeds"
            name = "embed"
            layer = -1

        # Handle q_input and hook_q etc
        elif any([node_name.endswith(qkv_input_substring) for qkv_input_substring in qkv_input_substrings]):
            relevant_letter = None
            for letter, qkv_substring in zip(["q", "k", "v"], qkv_substrings):
                if qkv_substring in node_name:
                    assert relevant_letter is None
                    relevant_letter = letter
            name += "a" + node_name.split(".")[1] + "." + str(get_index(node_name)) + "_" + relevant_letter
            layer = int(node_name.split(".")[1])

        # Handle attention hook_result
        elif "hook_result" in node_name or any([qkv_substring in node_name for qkv_substring in qkv_substrings]):
            name = "a" + node_name.split(".")[1] + "." + str(get_index(node_name))
            layer = int(node_name.split(".")[1])

        # Handle MLPs
        elif node_name.endswith("resid_mid"):
            raise ValueError("We removed resid_mid annotations. Call these mlp_in now.")
        elif "mlp" in node_name:
            name = "m" + node_name.split(".")[1]
            layer = int(node_name.split(".")[1])

        # Handle resid_post
        elif "resid_post" in node_name:
            name += "output"
            layer = 12

        # elif "mlp" in node_name:
        #     name += "m" + node_name.split(".")[1]
        else:
            raise ValueError(f"Unrecognized node name {node_name}")

    else:
        name = node_name
        # name = node_name + str(node.index.graphviz_index(use_actual_colon=True))

    # get layer by looking for number before first dot
    

    return layer, name

acdcpp_edges = set()
for edge in acdcpp_edges_long[0][0.08]:
    # split the edge into two nodes, e.g. blocks.1.attn.hook_result[:, :, 10]blocks.0.hook_mlp_in[:] into blocks.1.attn.hook_result[:, :, 10] and blocks.0.hook_mlp_in[:]
    node_1 = get_node_name(edge.split("]")[0]+"]", show_full_index=False)
    node_2 = get_node_name(edge.split("]")[1]+"]", show_full_index=False)
    if node_1 != node_2:
        acdcpp_edges.add((node_1, node_2))

# %%
acdcpp_edges
# Out:
# {((0, 'a0.1'), (-1, 'embed')),
#  ((0, 'a0.10'), (-1, 'embed')),
#  ((0, 'a0.3'), (-1, 'embed')),
#  ((0, 'a0.5'), (-1, 'embed')),
#  ((0, 'm0'), (-1, 'embed')),
#  ((0, 'm0'), (0, 'a0.1')),
#  ((0, 'm0'), (0, 'a0.10')),
#  ((0, 'm0'), (0, 'a0.4')),
#  ((1, 'm1'), (0, 'm0')),
#  ((2, 'a2.11'), (0, 'm0')),
#  ((2, 'm2'), (-1, 'embed')),
#  ((2, 'm2'), (0, 'a0.10')),
#  ((2, 'm2'), (0, 'm0')),
#  ((2, 'm2'), (1, 'a1.11')),
#  ((3, 'a3.0'), (0, 'm0')),
#  ((3, 'a3.0'), (1, 'm1')),
#  ((3, 'a3.0'), (2, 'm2')),
#  ((3, 'm3'), (0, 'm0')),
#  ((3, 'm3'), (2, 'm2')),
#  ((3, 'm3'), (3, 'a3.0')),
#  ((4, 'm4'), (0, 'm0')),
#  ((4, 'm4'), (1, 'a1.11')),
#  ((4, 'm4'), (1, 'm1')),
#  ((4, 'm4'), (2, 'a2.2')),
#  ((4, 'm4'), (2, 'a2.9')),
#  ((4, 'm4'), (2, 'm2')),
#  ((4, 'm4'), (3, 'a3.0')),
#  ((4, 'm4'), (3, 'a3.10')),
#  ((4, 'm4'), (3, 'a3.3')),
#  ((4, 'm4'), (3, 'm3')),
#  ((4, 'm4'), (4, 'a4.11')),
#  ((4, 'm4'), (4, 'a4.3')),
#  ((4, 'm4'), (4, 'a4.4')),
#  ((4, 'm4'), (4, 'a4.7')),
#  ((5, 'a5.5'), (0, 'm0')),
#  ((5, 'a5.5'), (2, 'a2.2')),
#  ((5, 'a5.5'), (3, 'a3.0')),
#  ((5, 'a5.5'), (4, 'a4.11')),
#  ((5, 'a5.9'), (0, 'm0')),
#  ((5, 'a5.9'), (1, 'm1')),
#  ((5, 'a5.9'), (3, 'a3.0')),
#  ((5, 'm5'), (0, 'm0')),
#  ((5, 'm5'), (1, 'a1.0')),
#  ((5, 'm5'), (1, 'm1')),
#  ((5, 'm5'), (2, 'a2.2')),
#  ((5, 'm5'), (2, 'a2.9')),
#  ((5, 'm5'), (2, 'm2')),
#  ((5, 'm5'), (3, 'a3.0')),
#  ((5, 'm5'), (3, 'a3.3')),
#  ((5, 'm5'), (3, 'a3.6')),
#  ((5, 'm5'), (3, 'a3.7')),
#  ((5, 'm5'), (3, 'm3')),
#  ((5, 'm5'), (4, 'a4.11')),
#  ((5, 'm5'), (4, 'a4.3')),
#  ((5, 'm5'), (4, 'a4.7')),
#  ((5, 'm5'), (4, 'm4')),
#  ((5, 'm5'), (5, 'a5.10')),
#  ((5, 'm5'), (5, 'a5.5')),
#  ((5, 'm5'), (5, 'a5.6')),
#  ((5, 'm5'), (5, 'a5.8')),
#  ((5, 'm5'), (5, 'a5.9')),
#  ((6, 'a6.6'), (3, 'a3.0')),
#  ((6, 'a6.6'), (5, 'a5.5')),
#  ((6, 'a6.6'), (5, 'a5.9')),
#  ((6, 'a6.9'), (0, 'a0.1')),
#  ((6, 'a6.9'), (0, 'm0')),
#  ((6, 'a6.9'), (1, 'm1')),
#  ((6, 'a6.9'), (2, 'a2.2')),
#  ((6, 'a6.9'), (2, 'a2.9')),
#  ((6, 'a6.9'), (3, 'a3.0')),
#  ((6, 'a6.9'), (3, 'a3.3')),
#  ((6, 'a6.9'), (3, 'a3.7')),
#  ((6, 'a6.9'), (3, 'm3')),
#  ((6, 'a6.9'), (4, 'a4.11')),
#  ((6, 'a6.9'), (4, 'a4.3')),
#  ((6, 'a6.9'), (4, 'a4.4')),
#  ((6, 'a6.9'), (4, 'a4.7')),
#  ((6, 'a6.9'), (4, 'm4')),
#  ((6, 'a6.9'), (5, 'a5.5')),
#  ((6, 'a6.9'), (5, 'a5.6')),
#  ((6, 'a6.9'), (5, 'm5')),
#  ((6, 'm6'), (0, 'a0.10')),
#  ((6, 'm6'), (0, 'm0')),
#  ((6, 'm6'), (1, 'm1')),
#  ((6, 'm6'), (3, 'a3.0')),
#  ((6, 'm6'), (3, 'm3')),
#  ((6, 'm6'), (5, 'a5.10')),
#  ((6, 'm6'), (5, 'a5.5')),
#  ((6, 'm6'), (5, 'm5')),
#  ((6, 'm6'), (6, 'a6.6')),
#  ((6, 'm6'), (6, 'a6.7')),
#  ((6, 'm6'), (6, 'a6.9')),
#  ((7, 'a7.1'), (3, 'a3.0')),
#  ((7, 'a7.1'), (3, 'm3')),
#  ((7, 'a7.1'), (5, 'a5.5')),
#  ((7, 'a7.1'), (5, 'a5.9')),
#  ((7, 'a7.1'), (6, 'a6.6')),
#  ((7, 'a7.3'), (4, 'a4.3')),
#  ((7, 'a7.3'), (6, 'a6.0')),
#  ((7, 'a7.9'), (0, 'a0.1')),
#  ((7, 'a7.9'), (0, 'a0.10')),
#  ((7, 'a7.9'), (0, 'm0')),
#  ((7, 'a7.9'), (3, 'a3.0')),
#  ((7, 'a7.9'), (3, 'm3')),
#  ((7, 'a7.9'), (4, 'm4')),
#  ((7, 'a7.9'), (5, 'a5.5')),
#  ((7, 'a7.9'), (6, 'a6.9')),
#  ((7, 'a7.9'), (6, 'm6')),
#  ((7, 'm7'), (0, 'm0')),
#  ((7, 'm7'), (2, 'm2')),
#  ((7, 'm7'), (5, 'a5.5')),
#  ((7, 'm7'), (5, 'a5.9')),
#  ((7, 'm7'), (5, 'm5')),
#  ((7, 'm7'), (6, 'a6.6')),
#  ((7, 'm7'), (6, 'a6.9')),
#  ((7, 'm7'), (6, 'm6')),
#  ((7, 'm7'), (7, 'a7.9')),
#  ((8, 'a8.10'), (0, 'a0.10')),
#  ((8, 'a8.10'), (0, 'm0')),
#  ((8, 'a8.10'), (3, 'a3.0')),
#  ((8, 'a8.10'), (3, 'm3')),
#  ((8, 'a8.10'), (4, 'm4')),
#  ((8, 'a8.10'), (5, 'a5.5')),
#  ((8, 'a8.10'), (5, 'a5.9')),
#  ((8, 'a8.10'), (5, 'm5')),
#  ((8, 'a8.10'), (6, 'm6')),
#  ((8, 'a8.10'), (7, 'a7.3')),
#  ((8, 'a8.6'), (0, 'm0')),
#  ((8, 'a8.6'), (3, 'a3.0')),
#  ((8, 'a8.6'), (3, 'm3')),
#  ((8, 'a8.6'), (5, 'a5.5')),
#  ((8, 'a8.6'), (5, 'm5')),
#  ((8, 'a8.6'), (6, 'a6.6')),
#  ((8, 'a8.6'), (6, 'a6.9')),
#  ((8, 'a8.6'), (6, 'm6')),
#  ((8, 'm8'), (8, 'a8.6')),
#  ((9, 'a9.4'), (8, 'm8')),
#  ((9, 'a9.7'), (0, 'm0')),
#  ((9, 'a9.7'), (4, 'm4')),
#  ((9, 'a9.7'), (5, 'a5.5')),
#  ((9, 'a9.7'), (8, 'a8.10')),
#  ((9, 'a9.7'), (8, 'm8')),
#  ((9, 'a9.9'), (0, 'm0')),
#  ((9, 'a9.9'), (7, 'a7.3')),
#  ((9, 'a9.9'), (7, 'a7.9')),
#  ((9, 'a9.9'), (8, 'a8.10')),
#  ((9, 'a9.9'), (8, 'a8.6')),
#  ((9, 'm9'), (0, 'm0')),
#  ((9, 'm9'), (8, 'm8')),
#  ((9, 'm9'), (9, 'a9.9')),
#  ((10, 'a10.0'), (0, 'm0')),
#  ((10, 'a10.0'), (7, 'a7.3')),
#  ((10, 'a10.0'), (7, 'a7.9')),
#  ((10, 'a10.0'), (8, 'a8.10')),
#  ((10, 'a10.0'), (8, 'a8.6')),
#  ((10, 'a10.0'), (9, 'a9.6')),
#  ((10, 'a10.1'), (8, 'a8.6')),
#  ((10, 'a10.10'), (8, 'a8.6')),
#  ((10, 'a10.2'), (0, 'm0')),
#  ((10, 'a10.2'), (8, 'a8.10')),
#  ((10, 'a10.2'), (9, 'a9.6')),
#  ((10, 'a10.2'), (9, 'a9.9')),
#  ((10, 'a10.6'), (8, 'a8.10')),
#  ((10, 'a10.6'), (8, 'a8.6')),
#  ((10, 'a10.6'), (9, 'a9.6')),
#  ((10, 'a10.7'), (0, 'a0.1')),
#  ((10, 'a10.7'), (0, 'm0')),
#  ((10, 'a10.7'), (1, 'm1')),
#  ((10, 'a10.7'), (2, 'm2')),
#  ((10, 'a10.7'), (3, 'm3')),
#  ((10, 'a10.7'), (4, 'm4')),
#  ((10, 'a10.7'), (5, 'a5.5')),
#  ((10, 'a10.7'), (6, 'm6')),
#  ((10, 'a10.7'), (7, 'm7')),
#  ((10, 'a10.7'), (8, 'a8.10')),
#  ((10, 'a10.7'), (8, 'm8')),
#  ((10, 'a10.7'), (9, 'a9.6')),
#  ((10, 'a10.7'), (9, 'a9.9')),
#  ((10, 'm10'), (0, 'm0')),
#  ((10, 'm10'), (9, 'a9.9')),
#  ((11, 'a11.10'), (0, 'a0.1')),
#  ((11, 'a11.10'), (0, 'a0.5')),
#  ((11, 'a11.10'), (0, 'm0')),
#  ((11, 'a11.10'), (1, 'm1')),
#  ((11, 'a11.10'), (2, 'm2')),
#  ((11, 'a11.10'), (3, 'm3')),
#  ((11, 'a11.10'), (4, 'm4')),
#  ((11, 'a11.10'), (5, 'a5.5')),
#  ((11, 'a11.10'), (6, 'm6')),
#  ((11, 'a11.10'), (7, 'm7')),
#  ((11, 'a11.10'), (8, 'a8.10')),
#  ((11, 'a11.10'), (8, 'm8')),
#  ((11, 'a11.10'), (9, 'a9.6')),
#  ((11, 'a11.10'), (9, 'a9.9')),
#  ((11, 'a11.10'), (9, 'm9')),
#  ((11, 'a11.10'), (10, 'a10.0')),
#  ((11, 'a11.10'), (10, 'a10.1')),
#  ((11, 'a11.10'), (10, 'a10.10')),
#  ((11, 'a11.10'), (10, 'a10.6')),
#  ((11, 'a11.10'), (10, 'a10.7')),
#  ((11, 'a11.2'), (0, 'm0')),
#  ((11, 'a11.2'), (7, 'a7.9')),
#  ((11, 'a11.2'), (8, 'a8.10')),
#  ((11, 'a11.2'), (9, 'a9.6')),
#  ((11, 'a11.2'), (9, 'a9.9')),
#  ((11, 'a11.2'), (9, 'm9')),
#  ((11, 'a11.2'), (10, 'a10.0')),
#  ((11, 'a11.6'), (8, 'a8.10')),
#  ((11, 'm11'), (8, 'a8.6')),
#  ((11, 'm11'), (10, 'a10.7')),
#  ((12, 'output'), (7, 'a7.3')),
#  ((12, 'output'), (7, 'a7.9')),
#  ((12, 'output'), (8, 'a8.10')),
#  ((12, 'output'), (8, 'a8.2')),
#  ((12, 'output'), (8, 'a8.6')),
#  ((12, 'output'), (9, 'a9.5')),
#  ((12, 'output'), (9, 'a9.6')),
#  ((12, 'output'), (9, 'a9.7')),
#  ((12, 'output'), (9, 'a9.8')),
#  ((12, 'output'), (9, 'a9.9')),
#  ((12, 'output'), (9, 'm9')),
#  ((12, 'output'), (10, 'a10.0')),
#  ((12, 'output'), (10, 'a10.1')),
#  ((12, 'output'), (10, 'a10.10')),
#  ((12, 'output'), (10, 'a10.3')),
#  ((12, 'output'), (10, 'a10.6')),
#  ((12, 'output'), (10, 'a10.7')),
#  ((12, 'output'), (10, 'm10')),
#  ((12, 'output'), (11, 'a11.10')),
#  ((12, 'output'), (11, 'a11.2')),
#  ((12, 'output'), (11, 'a11.3')),
#  ((12, 'output'), (11, 'm11'))}

# %%
# Convert edges back to weight mask
def get_mask_from_edges(edges, weight_mask_template=mask_dict, all_possible_nodes=all_possible_nodes, edge_0=True):
    new_mask_dict = {}
    for node_name in weight_mask_template:
        new_mask_dict[node_name] = torch.ones_like(weight_mask_template[node_name]) if edge_0 else torch.zeros_like(weight_mask_template[node_name])
    
    node_indices = {node_name: idx for idx, node_name in enumerate(all_possible_nodes)}
    for edge in edges:
        try:
            new_mask_dict[edge[0][1]][node_indices[edge[1]]] = 0 if edge_0 else 1
        except:
            continue
    
    return new_mask_dict

def convert_mask_dict_to_params(mask_dict):
    mask_params = []
    # first output_mask
    mask_params.append(mask_dict["output"])
    for layer in range(12):
        attn_tensors = []
        for head in range(12):
            attn_tensors.append(mask_dict[f"a{layer}.{head}"])
        mask_params.append(torch.stack(attn_tensors, dim=1))
        mask_params.append(mask_dict[f"m{layer}"])
    return mask_params
acdcpp_mask_dict = get_mask_from_edges(acdcpp_edges, edge_0=False)
acdcpp_mask_params = convert_mask_dict_to_params(acdcpp_mask_dict)

# %%
with open("models/acdcpp_mask_params.pkl", "wb") as f:
    pickle.dump(acdcpp_mask_params, f)

# %%
# Verify that edges are the same
_, _, acdcpp_edges_2, _ = get_nodes_and_edges(acdcpp_mask_params, edge_0=False)
print(len(acdcpp_edges_2))
print(len(acdcpp_edges))
print(len(acdcpp_edges_2.intersection(acdcpp_edges)))
# Out:
# 232
# 232
# 232

# %% [markdown]
# ### Analyze overlaps between different edges

# %%
with open("models/alternative_necessary_masks_params_dict_lambda=1.pkl", "rb") as f:
    alternative_necessary_mask_params = pickle.load(f)
    alternative_necessary_mask_params = alternative_necessary_mask_params[200]
with open("models/alternative_sufficient_masks_params_dict_lambda=1.pkl", "rb") as f:
    alternative_sufficient_mask_params = pickle.load(f)
    alternative_sufficient_mask_params = alternative_sufficient_mask_params[200]
_, _, alternative_necessary_edges, _ = get_nodes_and_edges(alternative_necessary_mask_params)
_, _, alternative_sufficient_edges, _ = get_nodes_and_edges(alternative_sufficient_mask_params, edge_0=False)

# %%
get_nodes_and_edges(alternative_sufficient_mask_params, edge_0=False)

# %%
print(f"{len(edges)=}, {len(acdcpp_edges)=}, {len(edges.intersection(acdcpp_edges))=}")
print(edges.intersection(acdcpp_edges))

# %%
# Get overlaps between all edges (regular edges, necessary, sufficient, acdcpp) (make a table with tabulate)
edges_dict = {"circuit_breaking":edges, "ioi_necessary":alternative_necessary_edges, "ioi_sufficient":alternative_sufficient_edges, "acdcpp":acdcpp_edges}
for edge_type in edges_dict:
    for second_edge_type in edges_dict:
        print(f"{edge_type} and {second_edge_type}: {len(edges_dict[edge_type].intersection(edges_dict[second_edge_type]))} edges in common")#, {edges_dict[edge_type].intersection(edges_dict[second_edge_type])}")

# %% [markdown]
# ### Visualizations

# %%
def create_aligned_graph(all_possible_nodes, edges):
    G = pgv.AGraph(strict=False, directed=True)

    # Find the maximum layer number for adjusting the graph
    max_layer = max(layer for layer, _ in all_possible_nodes if isinstance(layer, int))
    nodes_with_edges = set([node for edge in edges for node in edge])

    # Add nodes and edges to the graph
    for node in all_possible_nodes:
        if node in [edge[0] for edge in edges] or node in [edge[1] for edge in edges]:
            G.add_node(node[1], layer=str(max_layer - node[0]))

    for edge in edges:
        G.add_edge(edge[1][1], edge[0][1])

    # Create subgraphs to ensure nodes of the same layer have the same rank
    for layer in range(max_layer, -2, -1):
        with G.subgraph(name=f'cluster_{layer}') as s:
            s.graph_attr['rank'] = 'same'
            for node in nodes_with_edges:
                if node[0] == layer:
                    s.add_node(node[1])

    # Apply layout and render the graph
    G.layout(prog='dot')
    G.draw('aligned_graph.png')
    return Image('aligned_graph.png')

# Call the function with your nodes and edges
flipped_graph_image = create_aligned_graph(all_possible_nodes, edges)

# To display the graph in Jupyter Notebook
flipped_graph_image

# %%
# intersecting edges graph
for edge_type in edges_dict:
    for second_edge_type in edges_dict:
        if edge_type == second_edge_type:
            continue
        # make a graph with just the intersecting edges, title it with the two edge types
        print(f"Intersection between {edge_type} and {second_edge_type}: {len(edges_dict[edge_type].intersection(edges_dict[second_edge_type]))} edges in common, {edges_dict[edge_type].intersection(edges_dict[second_edge_type])}")
        
        intersecting_edges_graph = create_aligned_graph(all_possible_nodes, edges_dict[edge_type].intersection(edges_dict[second_edge_type]))
        display(intersecting_edges_graph)
        # intersecting_edges_graph.render(f"intersecting_edges_graph_{edge_type}_{second_edge_type}", format="png", cleanup=True)
# intersecting_edges_graph = create_aligned_graph(all_possible_nodes, edges.intersection(acdcpp_edges))
# intersecting_edges_graph

# %%
import pygraphviz as pgv
from pathlib import Path
from IPython.display import Image

def show(nodes, edges, fname=None):
    g = pgv.AGraph(strict=True, directed=True)
    g.graph_attr.update(ranksep='0.1', nodesep='0.1', compound=True)
    g.node_attr.update(fixedsize='true', width='1.5', height='.5')
    
    layer_to_subgraph = {}

    # Create a subgraph for each layer
    for node in nodes:
        layer = node[0]
        if layer not in layer_to_subgraph:
            # Each layer has its own subgraph with 'rank=same' to ensure they are on the same level
            layer_to_subgraph[layer] = g.add_subgraph(name=f'cluster_{layer}', rank='same')
            
        # Here you add the node to the appropriate subgraph
        layer_to_subgraph[layer].add_node(node, label=str(node[1]))

    # Now, add the edges to the graph
    for edge in edges:
        g.add_edge(edge[0], edge[1])
    
    # If a filename is provided, write the file and optionally render to an image
    if fname:
        fpath = Path(fname)
        base_fname = fpath.stem
        base_path = fpath.parent
        base_path.mkdir(exist_ok=True, parents=True)
        
        # Write the dot file
        g.write(path=base_path / f"{base_fname}.gv")
        
        # Render to an image
        g.layout(prog='dot')
        g.draw(path=base_path / f"{base_fname}.png")
        
    return g


g = show(nodes_with_edges, edges, fname="graph.gv")
Image(g.draw(format='png', prog='dot'))
